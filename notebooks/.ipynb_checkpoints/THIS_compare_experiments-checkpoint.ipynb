# %%
import psycopg2

import numpy as np
import pandas as pd
import itertools

import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [16, 8]

from pprint import pprint
from collections import OrderedDict

try:
  con
except NameError:
  con = psycopg2.connect(user="postgres", dbname="noattackdb", password="coap")
  con.set_session(readonly=True, autocommit=True)

# %%
# %%time 

exp_data_sql = """
SELECT
	ex.*
FROM
	experiment ex
"""
exp_df = pd.read_sql_query(exp_data_sql, con)
print("\n".join(exp_df.exp_id.unique().tolist()))
print()
exp_df
# Out:
# unsecureclienttest3_dtlson_httpson
# unsecureclienttest3_httpson
# cloud_proxy_and_attacker_noattacker
# unsecureclienttest3
# cloud_proxy_and_attacker_noattacker_dtlson
# unsecureclienttest3_dtlson
# cloud_proxy_and_attacker_noattacker_httpson
# cloud_proxy_and_attacker_noattacker_dtlson_httpson
#
# CPU times: user 9.53 ms, sys: 3.08 ms, total: 12.6 ms
# Wall time: 13.1 ms
# /home/ubuntu/.local/lib/python3.8/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#                                               exp_id attacker_rate  \
# 0                 unsecureclienttest3_dtlson_httpson       100mbps
# 1                        unsecureclienttest3_httpson       100mbps
# 2                cloud_proxy_and_attacker_noattacker       100mbps
# 3                                unsecureclienttest3       100mbps
# 4         cloud_proxy_and_attacker_noattacker_dtlson       100mbps
# 5                         unsecureclienttest3_dtlson       100mbps
# 6        cloud_proxy_and_attacker_noattacker_httpson       100mbps
# 7  cloud_proxy_and_attacker_noattacker_dtlson_htt...       100mbps
#
#    server_connections  max_keep_alive_requests  num_clients  num_trials  \
# 0                 256                        0            1           1
# 1                 256                        0            1           1
# 2                 256                        0            1           3
# 3                 256                        0            1           1
# 4                 256                        0            1           3
# 5                 256                        0            1           1
# 6                 256                        0            1           3
# 7                 256                        0            1           3
#
#    origin_server_duration  attacker_duration  receiver_duration  \
# 0                     120                 20                120
# 1                     120                 20                120
# 2                     120                 20                120
# 3                     120                 20                120
# 4                     120                 20                120
# 5                     120                 20                120
# 6                     120                 20                120
# 7                     120                 20                120
#
#    proxy_duration  ...               topology_name  num_proxy_connections  \
# 0             120  ...                    newrealA                     50
# 1             120  ...                    newrealA                     50
# 2             120  ...  cloud_proxy_cloud_attacker                     50
# 3             120  ...                    newrealA                     50
# 4             120  ...  cloud_proxy_cloud_attacker                     50
# 5             120  ...                    newrealA                     50
# 6             120  ...  cloud_proxy_cloud_attacker                     50
# 7             120  ...  cloud_proxy_cloud_attacker                     50
#
#   request_timeout  max_retries keep_alive_duration  request_retry_interval  \
# 0               5            2                   5                       1
# 1               5            2                   5                       1
# 2               5            2                   5                       1
# 3               5            2                   5                       1
# 4               5            2                   5                       1
# 5               5            2                   5                       1
# 6               5            2                   5                       1
# 7               5            2                   5                       1
#
#   reuse_connections run_proxy_with_dtls  run_proxy_with_https  run_attacker
# 0              True                True                  True         False
# 1              True               False                  True         False
# 2              True               False                 False         False
# 3              True               False                 False         False
# 4              True                True                 False         False
# 5              True                True                 False         False
# 6              True               False                  True         False
# 7              True                True                  True         False
#
# [8 rows x 22 columns]

# %%
exp_df[(exp_df["run_attacker"] == False)]
# Out:
#                                               exp_id attacker_rate  \
# 0                 unsecureclienttest3_dtlson_httpson       100mbps
# 1                        unsecureclienttest3_httpson       100mbps
# 2                cloud_proxy_and_attacker_noattacker       100mbps
# 3                                unsecureclienttest3       100mbps
# 4         cloud_proxy_and_attacker_noattacker_dtlson       100mbps
# 5                         unsecureclienttest3_dtlson       100mbps
# 6        cloud_proxy_and_attacker_noattacker_httpson       100mbps
# 7  cloud_proxy_and_attacker_noattacker_dtlson_htt...       100mbps
#
#    server_connections  max_keep_alive_requests  num_clients  num_trials  \
# 0                 256                        0            1           1
# 1                 256                        0            1           1
# 2                 256                        0            1           3
# 3                 256                        0            1           1
# 4                 256                        0            1           3
# 5                 256                        0            1           1
# 6                 256                        0            1           3
# 7                 256                        0            1           3
#
#    origin_server_duration  attacker_duration  receiver_duration  \
# 0                     120                 20                120
# 1                     120                 20                120
# 2                     120                 20                120
# 3                     120                 20                120
# 4                     120                 20                120
# 5                     120                 20                120
# 6                     120                 20                120
# 7                     120                 20                120
#
#    proxy_duration  ...               topology_name  num_proxy_connections  \
# 0             120  ...                    newrealA                     50
# 1             120  ...                    newrealA                     50
# 2             120  ...  cloud_proxy_cloud_attacker                     50
# 3             120  ...                    newrealA                     50
# 4             120  ...  cloud_proxy_cloud_attacker                     50
# 5             120  ...                    newrealA                     50
# 6             120  ...  cloud_proxy_cloud_attacker                     50
# 7             120  ...  cloud_proxy_cloud_attacker                     50
#
#   request_timeout  max_retries keep_alive_duration  request_retry_interval  \
# 0               5            2                   5                       1
# 1               5            2                   5                       1
# 2               5            2                   5                       1
# 3               5            2                   5                       1
# 4               5            2                   5                       1
# 5               5            2                   5                       1
# 6               5            2                   5                       1
# 7               5            2                   5                       1
#
#   reuse_connections run_proxy_with_dtls  run_proxy_with_https  run_attacker
# 0              True                True                  True         False
# 1              True               False                  True         False
# 2              True               False                 False         False
# 3              True               False                 False         False
# 4              True                True                 False         False
# 5              True                True                 False         False
# 6              True               False                  True         False
# 7              True                True                  True         False
#
# [8 rows x 22 columns]

# %%
exp_id_map_config = dict()
for config_dict in exp_df.to_dict(orient="records"):
  exp_id_map_config[config_dict["exp_id"]] = {**config_dict}
  
exp_id_map_config
# Out:
# {'unsecureclienttest3_dtlson_httpson': {'exp_id': 'unsecureclienttest3_dtlson_httpson',
#   'attacker_rate': '100mbps',
#   'server_connections': 256,
#   'max_keep_alive_requests': 0,
#   'num_clients': 1,
#   'num_trials': 1,
#   'origin_server_duration': 120,
#   'attacker_duration': 20,
#   'receiver_duration': 120,
#   'proxy_duration': 120,
#   'client_duration': 100,
#   'attacker_start_lag_duration': 20,
#   'topology_name': 'newrealA',
#   'num_proxy_connections': 50,
#   'request_timeout': '5',
#   'max_retries': 2,
#   'keep_alive_duration': '5',
#   'request_retry_interval': '1',
#   'reuse_connections': True,
#   'run_proxy_with_dtls': True,
#   'run_proxy_with_https': True,
#   'run_attacker': False},
#  'unsecureclienttest3_httpson': {'exp_id': 'unsecureclienttest3_httpson',
#   'attacker_rate': '100mbps',
#   'server_connections': 256,
#   'max_keep_alive_requests': 0,
#   'num_clients': 1,
#   'num_trials': 1,
#   'origin_server_duration': 120,
#   'attacker_duration': 20,
#   'receiver_duration': 120,
#   'proxy_duration': 120,
#   'client_duration': 100,
#   'attacker_start_lag_duration': 20,
#   'topology_name': 'newrealA',
#   'num_proxy_connections': 50,
#   'request_timeout': '5',
#   'max_retries': 2,
#   'keep_alive_duration': '5',
#   'request_retry_interval': '1',
#   'reuse_connections': True,
#   'run_proxy_with_dtls': False,
#   'run_proxy_with_https': True,
#   'run_attacker': False},
#  'cloud_proxy_and_attacker_noattacker': {'exp_id': 'cloud_proxy_and_attacker_noattacker',
#   'attacker_rate': '100mbps',
#   'server_connections': 256,
#   'max_keep_alive_requests': 0,
#   'num_clients': 1,
#   'num_trials': 3,
#   'origin_server_duration': 120,
#   'attacker_duration': 20,
#   'receiver_duration': 120,
#   'proxy_duration': 120,
#   'client_duration': 100,
#   'attacker_start_lag_duration': 20,
#   'topology_name': 'cloud_proxy_cloud_attacker',
#   'num_proxy_connections': 50,
#   'request_timeout': '5',
#   'max_retries': 2,
#   'keep_alive_duration': '5',
#   'request_retry_interval': '1',
#   'reuse_connections': True,
#   'run_proxy_with_dtls': False,
#   'run_proxy_with_https': False,
#   'run_attacker': False},
#  'unsecureclienttest3': {'exp_id': 'unsecureclienttest3',
#   'attacker_rate': '100mbps',
#   'server_connections': 256,
#   'max_keep_alive_requests': 0,
#   'num_clients': 1,
#   'num_trials': 1,
#   'origin_server_duration': 120,
#   'attacker_duration': 20,
#   'receiver_duration': 120,
#   'proxy_duration': 120,
#   'client_duration': 100,
#   'attacker_start_lag_duration': 20,
#   'topology_name': 'newrealA',
#   'num_proxy_connections': 50,
#   'request_timeout': '5',
#   'max_retries': 2,
#   'keep_alive_duration': '5',
#   'request_retry_interval': '1',
#   'reuse_connections': True,
#   'run_proxy_with_dtls': False,
#   'run_proxy_with_https': False,
#   'run_attacker': False},
#  'cloud_proxy_and_attacker_noattacker_dtlson': {'exp_id': 'cloud_proxy_and_attacker_noattacker_dtlson',
#   'attacker_rate': '100mbps',
#   'server_connections': 256,
#   'max_keep_alive_requests': 0,
#   'num_clients': 1,
#   'num_trials': 3,
#   'origin_server_duration': 120,
#   'attacker_duration': 20,
#   'receiver_duration': 120,
#   'proxy_duration': 120,
#   'client_duration': 100,
#   'attacker_start_lag_duration': 20,
#   'topology_name': 'cloud_proxy_cloud_attacker',
#   'num_proxy_connections': 50,
#   'request_timeout': '5',
#   'max_retries': 2,
#   'keep_alive_duration': '5',
#   'request_retry_interval': '1',
#   'reuse_connections': True,
#   'run_proxy_with_dtls': True,
#   'run_proxy_with_https': False,
#   'run_attacker': False},
#  'unsecureclienttest3_dtlson': {'exp_id': 'unsecureclienttest3_dtlson',
#   'attacker_rate': '100mbps',
#   'server_connections': 256,
#   'max_keep_alive_requests': 0,
#   'num_clients': 1,
#   'num_trials': 1,
#   'origin_server_duration': 120,
#   'attacker_duration': 20,
#   'receiver_duration': 120,
#   'proxy_duration': 120,
#   'client_duration': 100,
#   'attacker_start_lag_duration': 20,
#   'topology_name': 'newrealA',
#   'num_proxy_connections': 50,
#   'request_timeout': '5',
#   'max_retries': 2,
#   'keep_alive_duration': '5',
#   'request_retry_interval': '1',
#   'reuse_connections': True,
#   'run_proxy_with_dtls': True,
#   'run_proxy_with_https': False,
#   'run_attacker': False},
#  'cloud_proxy_and_attacker_noattacker_httpson': {'exp_id': 'cloud_proxy_and_attacker_noattacker_httpson',
#   'attacker_rate': '100mbps',
#   'server_connections': 256,
#   'max_keep_alive_requests': 0,
#   'num_clients': 1,
#   'num_trials': 3,
#   'origin_server_duration': 120,
#   'attacker_duration': 20,
#   'receiver_duration': 120,
#   'proxy_duration': 120,
#   'client_duration': 100,
#   'attacker_start_lag_duration': 20,
#   'topology_name': 'cloud_proxy_cloud_attacker',
#   'num_proxy_connections': 50,
#   'request_timeout': '5',
#   'max_retries': 2,
#   'keep_alive_duration': '5',
#   'request_retry_interval': '1',
#   'reuse_connections': True,
#   'run_proxy_with_dtls': False,
#   'run_proxy_with_https': True,
#   'run_attacker': False},
#  'cloud_proxy_and_attacker_noattacker_dtlson_httpson': {'exp_id': 'cloud_proxy_and_attacker_noattacker_dtlson_httpson',
#   'attacker_rate': '100mbps',
#   'server_connections': 256,
#   'max_keep_alive_requests': 0,
#   'num_clients': 1,
#   'num_trials': 3,
#   'origin_server_duration': 120,
#   'attacker_duration': 20,
#   'receiver_duration': 120,
#   'proxy_duration': 120,
#   'client_duration': 100,
#   'attacker_start_lag_duration': 20,
#   'topology_name': 'cloud_proxy_cloud_attacker',
#   'num_proxy_connections': 50,
#   'request_timeout': '5',
#   'max_retries': 2,
#   'keep_alive_duration': '5',
#   'request_retry_interval': '1',
#   'reuse_connections': True,
#   'run_proxy_with_dtls': True,
#   'run_proxy_with_https': True,
#   'run_attacker': False}}

# %%
# %%time 

fetch_metadata_sql = """
SELECT
	n.node_name,
	dn.dnid,
	dn.node_id
FROM 
	deployed_node dn
	JOIN node n ON n.node_id = dn.node_id
"""

metadata_df = pd.read_sql_query(fetch_metadata_sql, con)

dnid_map_node_name = dict()
node_id_map_node_name = dict()

for record in metadata_df.to_dict(orient="records"):
  dnid = record["dnid"]
  node_id = record["node_id"]
  node_name = record["node_name"]
  
  assert dnid not in dnid_map_node_name
  dnid_map_node_name[dnid] = node_name
  
  assert node_id not in node_id_map_node_name
  node_id_map_node_name[node_id] = node_name
  
client_dnids = set(dnid for dnid, node_name in dnid_map_node_name.items() if node_name.startswith("client"))
attacker_dnids = set(dnid for dnid, node_name in dnid_map_node_name.items() if node_name.startswith("attacker"))
print(f"{client_dnids=}")
print(f"{attacker_dnids=}")

metadata_df
# Out:
# client_dnids={32, 2, 37, 7, 12, 17, 22, 27}
# attacker_dnids={1, 36, 6, 11, 16, 21, 26, 31}
# CPU times: user 9 ms, sys: 4.23 ms, total: 13.2 ms
# Wall time: 10.5 ms
# /home/ubuntu/.local/lib/python3.8/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#        node_name  dnid  node_id
# 0       attacker     1        1
# 1        client1     2        2
# 2   originserver     3        3
# 3          proxy     4        4
# 4       receiver     5        5
# 5       attacker     6        6
# 6        client1     7        7
# 7   originserver     8        8
# 8          proxy     9        9
# 9       receiver    10       10
# 10      attacker    11        1
# 11       client1    12        2
# 12  originserver    13        3
# 13         proxy    14        4
# 14      receiver    15        5
# 15      attacker    16        1
# 16       client1    17        2
# 17  originserver    18        3
# 18         proxy    19        4
# 19      receiver    20        5
# 20      attacker    21        1
# 21       client1    22        2
# 22  originserver    23        3
# 23         proxy    24        4
# 24      receiver    25        5
# 25      attacker    26        1
# 26       client1    27        2
# 27  originserver    28        3
# 28         proxy    29        4
# 29      receiver    30        5
# 30      attacker    31        1
# 31       client1    32        2
# 32  originserver    33        3
# 33         proxy    34        4
# 34      receiver    35        5
# 35      attacker    36        1
# 36       client1    37        2
# 37  originserver    38        3
# 38         proxy    39        4
# 39      receiver    40        5

# %%
# %%time

client_messages_sql = f"""
SELECT
	dn.exp_id,
	client_sends.trial,
	client_sends.observer_id,
	client_sends.message_marker,
	MIN(client_sends.observe_timestamp) AS send_time_sec,
	MIN(client_recvs.observe_timestamp) AS recv_time_sec,
	MIN(client_sends.observe_timestamp) AS first_send_time_sec,
	MAX(client_sends.observe_timestamp) AS last_send_time_sec,
	MIN(client_recvs.observe_timestamp) AS first_recv_time_sec,
	MAX(client_recvs.observe_timestamp) AS last_recv_time_sec,
	1e3 * (MIN(client_recvs.observe_timestamp) - MIN(client_sends.observe_timestamp)) AS rtt_ms_first_transmission,
	1e3 * (MIN(client_recvs.observe_timestamp) - MAX(client_sends.observe_timestamp)) AS rtt_ms_last_transmission,
	COUNT(client_sends.*) AS num_send_observations,
	COUNT(client_recvs.*) AS num_recv_observations,
	SUM(CASE WHEN cm_send.coap_retransmitted = true THEN 1 ELSE 0 END) AS num_retransmissions
FROM
	event client_sends
		JOIN message m_sends ON m_sends.message_id = client_sends.message_id
			JOIN coap_message cm_send ON cm_send.cmci = m_sends.coap_message
	JOIN event client_recvs
		ON client_recvs.trial = client_sends.trial
		AND client_recvs.observer_id = client_sends.observer_id
		AND client_recvs.message_marker = client_sends.message_marker
		JOIN message m_recvs ON m_recvs.message_id = client_recvs.message_id
	JOIN deployed_node dn 
		ON (dn.dnid = client_sends.observer_id AND dn.dnid = client_recvs.observer_id)
WHERE
	client_sends.observer_id IN ({','.join(map(str, client_dnids))})     -- clients senders are observers (observer ID)
		AND m_sends.src_id != {proxy_node_id}                            -- proxy is not the sender (node ID)
	AND client_recvs.observer_id IN ({','.join(map(str, client_dnids))}) -- clients receivers are observers (observer ID)
		AND m_recvs.src_id = {proxy_node_id}                             -- proxy is the sender (node ID)
GROUP BY
	dn.exp_id, client_sends.trial, client_sends.observer_id, client_sends.message_marker
ORDER BY
	dn.exp_id, client_sends.trial, client_sends.observer_id, client_sends.message_marker
"""

rtts_df = pd.read_sql_query(client_messages_sql, con)
rtts_df.observer_id.replace(dnid_map_node, inplace=True)

# Compute RTT stats and merge into the df
stats_df = (
  rtts_df
  .groupby(by=["exp_id", "trial", "observer_id"])
  .agg(
    num_messages=("message_marker", pd.Series.nunique),
    global_first_send_time_sec=("send_time_sec", "min"),
    global_last_recv_time_sec=("recv_time_sec", "max"),
  )
  .reset_index()
)
stats_df["average_rps"] = stats_df["num_messages"] / (stats_df["global_last_recv_time_sec"] - stats_df["global_first_send_time_sec"])
rtts_df = rtts_df.merge(stats_df, on=["exp_id", "trial", "observer_id"])

rtts_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File <timed exec>:31, in <module>
#
# NameError: name 'proxy_node_id' is not defined

# %%
# %%time

aggregate_client_rps_sql = f"""
SELECT
	dn.exp_id,
	e.observer_id,
	e.trial,
	(MAX(e.observe_timestamp) - MIN(e.observe_timestamp)) AS active_time_sec,
	COUNT(DISTINCT e.message_marker) AS num_messages,
	(COUNT(DISTINCT e.message_marker) / (MAX(e.observe_timestamp) - MIN(e.observe_timestamp))) AS average_rps
FROM
	event e
	JOIN deployed_node dn ON dn.dnid = e.observer_id
WHERE
	e.observer_id IN ({", ".join(map(str, client_dnids))})
GROUP BY
	dn.exp_id, e.observer_id, e.trial
"""

client_rps_df = pd.read_sql_query(aggregate_client_rps_sql, con)
client_rps_df["observer_id"].replace(dnid_map_node_name, inplace=True)

client_rps_df = client_rps_df.merge(exp_df, on="exp_id")

client_rps_df
# Out:
# CPU times: user 17.6 ms, sys: 2.5 ms, total: 20.1 ms
# Wall time: 160 ms
# /home/ubuntu/.local/lib/python3.8/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#                                                exp_id observer_id  trial  \
# 0                 cloud_proxy_and_attacker_noattacker     client1      1
# 1                 cloud_proxy_and_attacker_noattacker     client1      2
# 2                 cloud_proxy_and_attacker_noattacker     client1      3
# 3          cloud_proxy_and_attacker_noattacker_dtlson     client1      1
# 4          cloud_proxy_and_attacker_noattacker_dtlson     client1      2
# 5          cloud_proxy_and_attacker_noattacker_dtlson     client1      3
# 6   cloud_proxy_and_attacker_noattacker_dtlson_htt...     client1      1
# 7   cloud_proxy_and_attacker_noattacker_dtlson_htt...     client1      2
# 8   cloud_proxy_and_attacker_noattacker_dtlson_htt...     client1      3
# 9         cloud_proxy_and_attacker_noattacker_httpson     client1      1
# 10        cloud_proxy_and_attacker_noattacker_httpson     client1      2
# 11        cloud_proxy_and_attacker_noattacker_httpson     client1      3
# 12                                unsecureclienttest3     client1      1
# 13                         unsecureclienttest3_dtlson     client1      1
# 14                 unsecureclienttest3_dtlson_httpson     client1      1
# 15                        unsecureclienttest3_httpson     client1      1
#
#     active_time_sec  num_messages  average_rps attacker_rate  \
# 0         98.650324          1822    18.469275       100mbps
# 1         98.629379          1822    18.473198       100mbps
# 2         98.668993          1823    18.475916       100mbps
# 3         98.220411          1795    18.275224       100mbps
# 4         98.349433          1797    18.271585       100mbps
# 5         98.394524          1799    18.283538       100mbps
# 6         98.376741          1788    18.175028       100mbps
# 7         98.384224          1787    18.163481       100mbps
# 8         98.331799          1786    18.162995       100mbps
# 9         98.669738          1808    18.323754       100mbps
# 10        98.608420          1811    18.365572       100mbps
# 11        98.663025          1809    18.335136       100mbps
# 12        98.679497          1837    18.615823       100mbps
# 13        98.500080          1812    18.395924       100mbps
# 14        98.498942          1806    18.335222       100mbps
# 15        98.657332          1822    18.467963       100mbps
#
#     server_connections  max_keep_alive_requests  num_clients  ...  \
# 0                  256                        0            1  ...
# 1                  256                        0            1  ...
# 2                  256                        0            1  ...
# 3                  256                        0            1  ...
# 4                  256                        0            1  ...
# 5                  256                        0            1  ...
# 6                  256                        0            1  ...
# 7                  256                        0            1  ...
# 8                  256                        0            1  ...
# 9                  256                        0            1  ...
# 10                 256                        0            1  ...
# 11                 256                        0            1  ...
# 12                 256                        0            1  ...
# 13                 256                        0            1  ...
# 14                 256                        0            1  ...
# 15                 256                        0            1  ...
#
#                  topology_name  num_proxy_connections  request_timeout  \
# 0   cloud_proxy_cloud_attacker                     50                5
# 1   cloud_proxy_cloud_attacker                     50                5
# 2   cloud_proxy_cloud_attacker                     50                5
# 3   cloud_proxy_cloud_attacker                     50                5
# 4   cloud_proxy_cloud_attacker                     50                5
# 5   cloud_proxy_cloud_attacker                     50                5
# 6   cloud_proxy_cloud_attacker                     50                5
# 7   cloud_proxy_cloud_attacker                     50                5
# 8   cloud_proxy_cloud_attacker                     50                5
# 9   cloud_proxy_cloud_attacker                     50                5
# 10  cloud_proxy_cloud_attacker                     50                5
# 11  cloud_proxy_cloud_attacker                     50                5
# 12                    newrealA                     50                5
# 13                    newrealA                     50                5
# 14                    newrealA                     50                5
# 15                    newrealA                     50                5
#
#     max_retries  keep_alive_duration  request_retry_interval  \
# 0             2                    5                       1
# 1             2                    5                       1
# 2             2                    5                       1
# 3             2                    5                       1
# 4             2                    5                       1
# 5             2                    5                       1
# 6             2                    5                       1
# 7             2                    5                       1
# 8             2                    5                       1
# 9             2                    5                       1
# 10            2                    5                       1
# 11            2                    5                       1
# 12            2                    5                       1
# 13            2                    5                       1
# 14            2                    5                       1
# 15            2                    5                       1
#
#     reuse_connections run_proxy_with_dtls  run_proxy_with_https run_attacker
# 0                True               False                 False        False
# 1                True               False                 False        False
# 2                True               False                 False        False
# 3                True                True                 False        False
# 4                True                True                 False        False
# 5                True                True                 False        False
# 6                True                True                  True        False
# 7                True                True                  True        False
# 8                True                True                  True        False
# 9                True               False                  True        False
# 10               True               False                  True        False
# 11               True               False                  True        False
# 12               True               False                 False        False
# 13               True                True                 False        False
# 14               True                True                  True        False
# 15               True               False                  True        False
#
# [16 rows x 27 columns]

# %%
df = client_rps_df
param_comparison_scope = ["run_proxy_with_dtls", "run_proxy_with_https"]

df.boxplot("average_rps", by=param_comparison_scope)
plt.show()

# %%
# total_client_df = tdf.groupby(by=["exp_id"]).agg(
#     total_client_rps=("average_rps", "sum"),
#     nodes_in_experiment=("nodes_in_experiment", "first"),
# ).reset_index()

# total_client_df.boxplot(by="nodes_in_experiment", column="total_client_rps")

# total_client_df

total_client_df = tdf.groupby(by=["exp_id", "trial"]).agg(
    total_client_rps=("average_rps", "sum"),
    nodes_in_experiment=("nodes_in_experiment", "first"),
    other_nodes_in_experiment=("other_nodes_in_experiment", "first"),
).reset_index()

total_client_df.boxplot(by="other_nodes_in_experiment", column="total_client_rps")
plt.show()

total_client_df
# Out:
#                                                exp_id  trial  \
# 0        cloud_proxy_and_500mbpsattacker_withattacker      1
# 1        cloud_proxy_and_500mbpsattacker_withattacker      2
# 2        cloud_proxy_and_500mbpsattacker_withattacker      3
# 3   cloud_proxy_and_500mbpsattacker_withattacker_d...      1
# 4   cloud_proxy_and_500mbpsattacker_withattacker_d...      2
# 5   cloud_proxy_and_500mbpsattacker_withattacker_d...      3
# 6   cloud_proxy_and_500mbpsattacker_withattacker_d...      1
# 7   cloud_proxy_and_500mbpsattacker_withattacker_d...      2
# 8   cloud_proxy_and_500mbpsattacker_withattacker_d...      3
# 9   cloud_proxy_and_500mbpsattacker_withattacker_h...      1
# 10  cloud_proxy_and_500mbpsattacker_withattacker_h...      2
# 11  cloud_proxy_and_500mbpsattacker_withattacker_h...      3
# 12                cloud_proxy_and_attacker_noattacker      1
# 13                cloud_proxy_and_attacker_noattacker      2
# 14                cloud_proxy_and_attacker_noattacker      3
# 15         cloud_proxy_and_attacker_noattacker_dtlson      1
# 16         cloud_proxy_and_attacker_noattacker_dtlson      2
# 17         cloud_proxy_and_attacker_noattacker_dtlson      3
# 18  cloud_proxy_and_attacker_noattacker_dtlson_htt...      1
# 19  cloud_proxy_and_attacker_noattacker_dtlson_htt...      2
# 20  cloud_proxy_and_attacker_noattacker_dtlson_htt...      3
# 21        cloud_proxy_and_attacker_noattacker_httpson      1
# 22        cloud_proxy_and_attacker_noattacker_httpson      2
# 23        cloud_proxy_and_attacker_noattacker_httpson      3
# 24              cloud_proxy_and_attacker_withattacker      1
# 25              cloud_proxy_and_attacker_withattacker      2
# 26              cloud_proxy_and_attacker_withattacker      3
# 27       cloud_proxy_and_attacker_withattacker_dtlson      1
# 28       cloud_proxy_and_attacker_withattacker_dtlson      2
# 29       cloud_proxy_and_attacker_withattacker_dtlson      3
# 30  cloud_proxy_and_attacker_withattacker_dtlson_h...      1
# 31  cloud_proxy_and_attacker_withattacker_dtlson_h...      2
# 32  cloud_proxy_and_attacker_withattacker_dtlson_h...      3
# 33      cloud_proxy_and_attacker_withattacker_httpson      1
# 34      cloud_proxy_and_attacker_withattacker_httpson      2
# 35      cloud_proxy_and_attacker_withattacker_httpson      3
#
#     total_client_rps nodes_in_experiment other_nodes_in_experiment
# 0          13.853784   1attacker_1client         1client_1attacker
# 1          13.930996   1attacker_1client         1client_1attacker
# 2          13.917575   1attacker_1client         1client_1attacker
# 3          16.283771   1attacker_1client         1client_1attacker
# 4          15.742232   1attacker_1client         1client_1attacker
# 5          16.051369   1attacker_1client         1client_1attacker
# 6          16.221391   1attacker_1client         1client_1attacker
# 7          15.717846   1attacker_1client         1client_1attacker
# 8          15.819780   1attacker_1client         1client_1attacker
# 9          15.813546   1attacker_1client         1client_1attacker
# 10         15.750899   1attacker_1client         1client_1attacker
# 11         16.099280   1attacker_1client         1client_1attacker
# 12         18.469275   0attacker_1client         1client_0attacker
# 13         18.473198   0attacker_1client         1client_0attacker
# 14         18.475916   0attacker_1client         1client_0attacker
# 15         18.275224   0attacker_1client         1client_0attacker
# 16         18.271585   0attacker_1client         1client_0attacker
# 17         18.283538   0attacker_1client         1client_0attacker
# 18         18.175028   0attacker_1client         1client_0attacker
# 19         18.163481   0attacker_1client         1client_0attacker
# 20         18.162995   0attacker_1client         1client_0attacker
# 21         18.323754   0attacker_1client         1client_0attacker
# 22         18.365572   0attacker_1client         1client_0attacker
# 23         18.335136   0attacker_1client         1client_0attacker
# 24         13.930282   1attacker_1client         1client_1attacker
# 25         13.915169   1attacker_1client         1client_1attacker
# 26         13.917826   1attacker_1client         1client_1attacker
# 27         16.474904   1attacker_1client         1client_1attacker
# 28         16.223950   1attacker_1client         1client_1attacker
# 29         15.883620   1attacker_1client         1client_1attacker
# 30         16.000842   1attacker_1client         1client_1attacker
# 31         15.670041   1attacker_1client         1client_1attacker
# 32         16.130791   1attacker_1client         1client_1attacker
# 33         13.837861   1attacker_1client         1client_1attacker
# 34         13.821028   1attacker_1client         1client_1attacker
# 35         13.867141   1attacker_1client         1client_1attacker
