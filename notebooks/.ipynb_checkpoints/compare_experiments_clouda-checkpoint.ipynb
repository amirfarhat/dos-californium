# %%
import psycopg2

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [16, 8]

from pprint import pprint

try:
  con
except NameError:
  con = psycopg2.connect(user="postgres", dbname="comparisondb", password="coap")
  con.set_session(readonly=True, autocommit=False)

# %%
exp_data_sql = """
SELECT 
    ex.exp_id,
    ex.num_trials, 
    d.dnid,
    n.*
FROM 
	experiment ex
  JOIN deployed_node d ON d.exp_id = ex.exp_id
  JOIN node n ON d.node_id = n.node_id
GROUP BY
	ex.exp_id,
    n.node_id,
    d.dnid
ORDER BY
  ex.attacker_rate,
  ex.proxy_connections
;
"""
lay_of_the_land = pd.read_sql_query(exp_data_sql, con)
con.commit()
print("\n".join(lay_of_the_land.exp_id.unique().tolist()))
lay_of_the_land
# Out:
# 2client_1attacker_infinite_requests_many_trials
# 2client_0attacker_infinite_requests_many_trials
# 5client_1attacker_infinite_requests_many_trials
# 3client_1attacker_infinite_requests
# 1client_1attacker_infinite_requests_many_trials
# 3client_1attacker_infinite_requests_many_trials
# proper_3client_no_attacker_infinite_requests
# 4client_0attacker_infinite_requests_many_trials
# 4client_1attacker_infinite_requests_many_trials
# 5client_0attacker_infinite_requests_many_trials
# 1client_0attacker_infinite_requests_many_trials
#                                              exp_id  num_trials  dnid  \
# 0   2client_1attacker_infinite_requests_many_trials           5    46
# 1   2client_0attacker_infinite_requests_many_trials           5    35
# 2   5client_1attacker_infinite_requests_many_trials           5    82
# 3               3client_1attacker_infinite_requests           3    14
# 4   1client_1attacker_infinite_requests_many_trials           5    39
# ..                                              ...         ...   ...
# 80  2client_1attacker_infinite_requests_many_trials           5    45
# 81  2client_0attacker_infinite_requests_many_trials           5    34
# 82  5client_1attacker_infinite_requests_many_trials           5    77
# 83  5client_0attacker_infinite_requests_many_trials           5    67
# 84              3client_1attacker_infinite_requests           3     8
#
#     node_id node_name hardware_type operating_system
# 0        11   client3        pc2133   ubuntu1804-std
# 1         2  receiver        pc3000   ubuntu1804-std
# 2        13   client5        pc3000   ubuntu1804-std
# 3         2  receiver        pc3000   ubuntu1804-std
# 4        11   client3        pc2133   ubuntu1804-std
# ..      ...       ...           ...              ...
# 80       10   client2        pc3060   ubuntu1804-std
# 81        4     proxy    microcloud   ubuntu1804-std
# 82        8  attacker        pc2133   ubuntu1804-std
# 83        2  receiver        pc3000   ubuntu1804-std
# 84        3  attacker        pc3000   ubuntu1804-std
#
# [85 rows x 7 columns]

# %%
client_rps_sql = """
WITH base_rps_table AS(
	SELECT
		d.exp_id,
		n.node_name,
		e.trial,
		COUNT(DISTINCT e.message_marker) AS sent_messages,
		MAX(e.observe_timestamp) - MIN(e.observe_timestamp) AS active_time_sec
	FROM
		deployed_node d
		JOIN node n ON n.node_id = d.node_id
		JOIN event e ON e.observer_id = d.dnid
		JOIN experiment ex ON ex.exp_id = d.exp_id
	WHERE
		n.node_name LIKE '%client%' OR
		n.node_name LIKE '%attacker%'
	GROUP BY
		d.exp_id,
		n.node_name,
		e.trial
)

SELECT *, sent_messages / active_time_sec AS average_rps
FROM base_rps_table;
"""

df = pd.read_sql_query(client_rps_sql, con)
con.commit()

# Add number of attackers and clients in the df
ndf = df.groupby(by=["exp_id"]).agg(
    has_attacker=("node_name", lambda x: int(any(x.str.startswith("attacker")))),
    num_clients=("node_name", lambda x: x.nunique() - any(x.str.startswith("attacker"))),
)
df = df.merge(ndf, on="exp_id")

df
# Out:
#                                               exp_id node_name  trial  \
# 0    1client_0attacker_infinite_requests_many_trials   client1      1
# 1    1client_0attacker_infinite_requests_many_trials   client1      2
# 2    1client_0attacker_infinite_requests_many_trials   client1      3
# 3    1client_0attacker_infinite_requests_many_trials   client1      4
# 4    1client_0attacker_infinite_requests_many_trials   client1      5
# ..                                               ...       ...    ...
# 186     proper_3client_no_attacker_infinite_requests   client2      2
# 187     proper_3client_no_attacker_infinite_requests   client2      3
# 188     proper_3client_no_attacker_infinite_requests   client3      1
# 189     proper_3client_no_attacker_infinite_requests   client3      2
# 190     proper_3client_no_attacker_infinite_requests   client3      3
#
#      sent_messages  active_time_sec  average_rps  has_attacker  num_clients
# 0            23135        98.638530   234.543236             0            1
# 1            23059        98.621533   233.813035             0            1
# 2            22751        98.641710   230.642798             0            1
# 3            23000        98.632625   233.188562             0            1
# 4            23053        98.649581   233.685737             0            1
# ..             ...              ...          ...           ...          ...
# 186          22902        98.040254   233.597926             0            3
# 187          22617        97.967630   230.861969             0            3
# 188          22917        97.890937   234.107474             0            3
# 189          23177        97.902929   236.734490             0            3
# 190          22817        97.952940   232.938389             0            3
#
# [191 rows x 8 columns]

# %%
df["nodes_in_experiment"] = df["has_attacker"].astype(str) + "attacker_" + df["num_clients"].astype(str) + "client"
df["other_nodes_in_experiment"] = df["num_clients"].astype(str) + "client_" + df["has_attacker"].astype(str) + "attacker"
tdf = df[df["node_name"] != "attacker"]
tdf.boxplot(by="nodes_in_experiment", column="average_rps")
plt.show()

tdf.groupby(by=["nodes_in_experiment"]).count()

df
# Out:
#                                               exp_id node_name  trial  \
# 0    1client_0attacker_infinite_requests_many_trials   client1      1
# 1    1client_0attacker_infinite_requests_many_trials   client1      2
# 2    1client_0attacker_infinite_requests_many_trials   client1      3
# 3    1client_0attacker_infinite_requests_many_trials   client1      4
# 4    1client_0attacker_infinite_requests_many_trials   client1      5
# ..                                               ...       ...    ...
# 186     proper_3client_no_attacker_infinite_requests   client2      2
# 187     proper_3client_no_attacker_infinite_requests   client2      3
# 188     proper_3client_no_attacker_infinite_requests   client3      1
# 189     proper_3client_no_attacker_infinite_requests   client3      2
# 190     proper_3client_no_attacker_infinite_requests   client3      3
#
#      sent_messages  active_time_sec  average_rps  has_attacker  num_clients  \
# 0            23135        98.638530   234.543236             0            1
# 1            23059        98.621533   233.813035             0            1
# 2            22751        98.641710   230.642798             0            1
# 3            23000        98.632625   233.188562             0            1
# 4            23053        98.649581   233.685737             0            1
# ..             ...              ...          ...           ...          ...
# 186          22902        98.040254   233.597926             0            3
# 187          22617        97.967630   230.861969             0            3
# 188          22917        97.890937   234.107474             0            3
# 189          23177        97.902929   236.734490             0            3
# 190          22817        97.952940   232.938389             0            3
#
#     nodes_in_experiment other_nodes_in_experiment
# 0     0attacker_1client         1client_0attacker
# 1     0attacker_1client         1client_0attacker
# 2     0attacker_1client         1client_0attacker
# 3     0attacker_1client         1client_0attacker
# 4     0attacker_1client         1client_0attacker
# ..                  ...                       ...
# 186   0attacker_3client         3client_0attacker
# 187   0attacker_3client         3client_0attacker
# 188   0attacker_3client         3client_0attacker
# 189   0attacker_3client         3client_0attacker
# 190   0attacker_3client         3client_0attacker
#
# [191 rows x 10 columns]

# %%
# total_client_df = tdf.groupby(by=["exp_id"]).agg(
#     total_client_rps=("average_rps", "sum"),
#     nodes_in_experiment=("nodes_in_experiment", "first"),
# ).reset_index()

# total_client_df.boxplot(by="nodes_in_experiment", column="total_client_rps")

# total_client_df

total_client_df = tdf.groupby(by=["exp_id", "trial"]).agg(
    total_client_rps=("average_rps", "sum"),
    nodes_in_experiment=("nodes_in_experiment", "first"),
    other_nodes_in_experiment=("other_nodes_in_experiment", "first"),
).reset_index()

total_client_df.boxplot(by="other_nodes_in_experiment", column="total_client_rps")
plt.show()
