# %%
import psycopg2

import numpy as np
import pandas as pd
import itertools

import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [16, 8]

from pprint import pprint
from collections import OrderedDict

try:
  con
except NameError:
  con = psycopg2.connect(user="postgres", dbname="clouddb", password="coap")
  con.set_session(readonly=True, autocommit=True)

# %%
# %%time 

exp_data_sql = """
SELECT
	ex.*
FROM
	experiment ex
"""
exp_df = pd.read_sql_query(exp_data_sql, con)
print("\n".join(exp_df.exp_id.unique().tolist()))
print()
exp_df
# Out:
# cloud_proxy_and_attacker_noattacker
# cloud_proxy_and_attacker_noattacker_httpson
# cloud_proxy_and_attacker_noattacker_dtlson
# cloud_proxy_and_attacker_noattacker_dtlson_httpson
# cloud_proxy_and_attacker_withattacker
# cloud_proxy_and_attacker_withattacker_dtlson
# cloud_proxy_and_attacker_withattacker_dtlson_httpson
# cloud_proxy_and_attacker_withattacker_httpson
# cloud_proxy_and_500mbpsattacker_withattacker_dtlson_httpson
# cloud_proxy_and_500mbpsattacker_withattacker
# cloud_proxy_and_500mbpsattacker_withattacker_httpson
# cloud_proxy_and_500mbpsattacker_withattacker_dtlson
#
# CPU times: user 11.7 ms, sys: 1.6 ms, total: 13.3 ms
# Wall time: 13.6 ms
# /home/ubuntu/.local/lib/python3.8/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#                                                exp_id attacker_rate  \
# 0                 cloud_proxy_and_attacker_noattacker       100mbps
# 1         cloud_proxy_and_attacker_noattacker_httpson       100mbps
# 2          cloud_proxy_and_attacker_noattacker_dtlson       100mbps
# 3   cloud_proxy_and_attacker_noattacker_dtlson_htt...       100mbps
# 4               cloud_proxy_and_attacker_withattacker       100mbps
# 5        cloud_proxy_and_attacker_withattacker_dtlson       100mbps
# 6   cloud_proxy_and_attacker_withattacker_dtlson_h...       100mbps
# 7       cloud_proxy_and_attacker_withattacker_httpson       100mbps
# 8   cloud_proxy_and_500mbpsattacker_withattacker_d...       500mbps
# 9        cloud_proxy_and_500mbpsattacker_withattacker       500mbps
# 10  cloud_proxy_and_500mbpsattacker_withattacker_h...       500mbps
# 11  cloud_proxy_and_500mbpsattacker_withattacker_d...       500mbps
#
#     server_connections  max_keep_alive_requests  num_clients  num_trials  \
# 0                  256                        0            1           3
# 1                  256                        0            1           3
# 2                  256                        0            1           3
# 3                  256                        0            1           3
# 4                  256                        0            1           3
# 5                  256                        0            1           3
# 6                  256                        0            1           3
# 7                  256                        0            1           3
# 8                  256                        0            1           3
# 9                  256                        0            1           3
# 10                 256                        0            1           3
# 11                 256                        0            1           3
#
#     origin_server_duration  attacker_duration  receiver_duration  \
# 0                      120                 20                120
# 1                      120                 20                120
# 2                      120                 20                120
# 3                      120                 20                120
# 4                      120                 20                120
# 5                      120                 20                120
# 6                      120                 20                120
# 7                      120                 20                120
# 8                      120                 20                120
# 9                      120                 20                120
# 10                     120                 20                120
# 11                     120                 20                120
#
#     proxy_duration  ...               topology_name  num_proxy_connections  \
# 0              120  ...  cloud_proxy_cloud_attacker                     50
# 1              120  ...  cloud_proxy_cloud_attacker                     50
# 2              120  ...  cloud_proxy_cloud_attacker                     50
# 3              120  ...  cloud_proxy_cloud_attacker                     50
# 4              120  ...  cloud_proxy_cloud_attacker                     50
# 5              120  ...  cloud_proxy_cloud_attacker                     50
# 6              120  ...  cloud_proxy_cloud_attacker                     50
# 7              120  ...  cloud_proxy_cloud_attacker                     50
# 8              120  ...  cloud_proxy_cloud_attacker                     50
# 9              120  ...  cloud_proxy_cloud_attacker                     50
# 10             120  ...  cloud_proxy_cloud_attacker                     50
# 11             120  ...  cloud_proxy_cloud_attacker                     50
#
#    request_timeout  max_retries keep_alive_duration  request_retry_interval  \
# 0                5            2                   5                       1
# 1                5            2                   5                       1
# 2                5            2                   5                       1
# 3                5            2                   5                       1
# 4                5            2                   5                       1
# 5                5            2                   5                       1
# 6                5            2                   5                       1
# 7                5            2                   5                       1
# 8                5            2                   5                       1
# 9                5            2                   5                       1
# 10               5            2                   5                       1
# 11               5            2                   5                       1
#
#    reuse_connections run_proxy_with_dtls  run_proxy_with_https  run_attacker
# 0               True               False                 False         False
# 1               True               False                  True         False
# 2               True                True                 False         False
# 3               True                True                  True         False
# 4               True               False                 False          True
# 5               True                True                 False          True
# 6               True                True                  True          True
# 7               True               False                  True          True
# 8               True                True                  True          True
# 9               True               False                 False          True
# 10              True                True                  True          True
# 11              True                True                 False          True
#
# [12 rows x 22 columns]

# %%
# %%time 

fetch_metadata_sql = """
SELECT
	n.node_name,
	dn.dnid,
	dn.node_id
FROM 
	deployed_node dn
	JOIN node n ON n.node_id = dn.node_id
"""

metadata_df = pd.read_sql_query(fetch_metadata_sql, con)

dnid_map_node_name = dict()
node_id_map_node_name = dict()

for record in metadata_df.to_dict(orient="records"):
  dnid = record["dnid"]
  node_id = record["node_id"]
  node_name = record["node_name"]
  
  assert dnid not in dnid_map_node_name
  dnid_map_node_name[dnid] = node_name
  
  if node_id in node_id_map_node_name:
    assert node_id_map_node_name[node_id] == node_name
  else:
    node_id_map_node_name[node_id] = node_name
  
client_dnids = set(dnid for dnid, node_name in dnid_map_node_name.items() if node_name.startswith("client"))
attacker_dnids = set(dnid for dnid, node_name in dnid_map_node_name.items() if node_name.startswith("attacker"))

client_node_ids = set(node_id for node_id, node_name in node_id_map_node_name.items() if node_name.startswith("client"))

print(f"{client_dnids=}")
print(f"{attacker_dnids=}")
print(f"{client_node_ids=}")
# Out:
# client_dnids={32, 2, 37, 7, 42, 12, 47, 17, 52, 22, 57, 27}
# attacker_dnids={1, 36, 6, 41, 10, 46, 16, 51, 21, 56, 26, 31}
# client_node_ids={2}
# CPU times: user 2.34 ms, sys: 3.82 ms, total: 6.17 ms
# Wall time: 6.96 ms
# /home/ubuntu/.local/lib/python3.8/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(

# %%
# %%time

client_messages_sql = f"""
SELECT
	dn.exp_id,
	client_sends.trial,
	client_sends.observer_id,
	client_sends.message_marker,
	(ARRAY_AGG(cm_recvs.coap_code))[1] AS response_code,
	MIN(client_sends.observe_timestamp) AS send_time_sec,
	MIN(client_recvs.observe_timestamp) AS recv_time_sec,
	MIN(client_sends.observe_timestamp) AS first_send_time_sec,
	MAX(client_sends.observe_timestamp) AS last_send_time_sec,
	MIN(client_recvs.observe_timestamp) AS first_recv_time_sec,
	MAX(client_recvs.observe_timestamp) AS last_recv_time_sec,
	1e3 * (MIN(client_recvs.observe_timestamp) - MIN(client_sends.observe_timestamp)) AS rtt_ms_first_transmission,
	1e3 * (MIN(client_recvs.observe_timestamp) - MAX(client_sends.observe_timestamp)) AS rtt_ms_last_transmission,
	COUNT(client_sends.*) AS num_send_observations,
	COUNT(client_recvs.*) AS num_recv_observations,
	SUM(CASE WHEN cm_send.coap_retransmitted = true THEN 1 ELSE 0 END) AS num_retransmissions
FROM
	event client_sends
		JOIN message m_sends ON m_sends.message_id = client_sends.message_id
			JOIN coap_message cm_send ON cm_send.cmci = m_sends.coap_message
	JOIN event client_recvs
		ON client_recvs.trial = client_sends.trial
		AND client_recvs.observer_id = client_sends.observer_id
		AND client_recvs.message_marker = client_sends.message_marker
		JOIN message m_recvs ON m_recvs.message_id = client_recvs.message_id
			JOIN coap_message cm_recvs ON cm_recvs.cmci = m_recvs.coap_message
	JOIN deployed_node dn 
		ON (dn.dnid = client_sends.observer_id AND dn.dnid = client_recvs.observer_id)
WHERE
	client_sends.observer_id IN ({','.join(map(str, client_dnids))})     -- clients senders are observers (observer ID)
		AND m_sends.src_id IN ({','.join(map(str, client_node_ids))})    -- clients are senders (node ID)
	AND client_recvs.observer_id IN ({','.join(map(str, client_dnids))}) -- clients receivers are observers (observer ID)
		AND m_recvs.dst_id IN ({','.join(map(str, client_node_ids))})    -- clients are receivers (node ID)
GROUP BY
	dn.exp_id, client_sends.trial, client_sends.observer_id, client_sends.message_marker
ORDER BY
	dn.exp_id, client_sends.trial, client_sends.observer_id, client_sends.message_marker
"""

message_rtt_df = pd.read_sql_query(client_messages_sql, con)
message_rtt_df.observer_id.replace(dnid_map_node_name, inplace=True)

message_rtt_df["successful_message"] = False
message_rtt_df.loc[(message_rtt_df["response_code"] == "content"), "successful_message"] = True

print(message_rtt_df["response_code"].unique())

message_rtt_df
# Out:
# /home/ubuntu/.local/lib/python3.8/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# ['content' 'bad_gateway']
# CPU times: user 595 ms, sys: 75.2 ms, total: 670 ms
# Wall time: 1.68 s
#                                               exp_id  trial observer_id  \
# 0       cloud_proxy_and_500mbpsattacker_withattacker      1     client1
# 1       cloud_proxy_and_500mbpsattacker_withattacker      1     client1
# 2       cloud_proxy_and_500mbpsattacker_withattacker      1     client1
# 3       cloud_proxy_and_500mbpsattacker_withattacker      1     client1
# 4       cloud_proxy_and_500mbpsattacker_withattacker      1     client1
# ...                                              ...    ...         ...
# 57512  cloud_proxy_and_attacker_withattacker_httpson      3     client1
# 57513  cloud_proxy_and_attacker_withattacker_httpson      3     client1
# 57514  cloud_proxy_and_attacker_withattacker_httpson      3     client1
# 57515  cloud_proxy_and_attacker_withattacker_httpson      3     client1
# 57516  cloud_proxy_and_attacker_withattacker_httpson      3     client1
#
#        message_marker response_code  send_time_sec  recv_time_sec  \
# 0                   1       content       0.000000       0.207288
# 1                   2       content       0.231558       0.288233
# 2                   3       content       0.290401       0.346598
# 3                   4       content       0.348780       0.404318
# 4                   5       content       0.406691       0.462530
# ...               ...           ...            ...            ...
# 57512          518419       content      98.384405      98.437136
# 57513          518420       content      98.437647      98.490177
# 57514          518421       content      98.490717      98.543373
# 57515          518422       content      98.543918      98.596621
# 57516          518423       content      98.597216      98.649930
#
#        first_send_time_sec  last_send_time_sec  first_recv_time_sec  \
# 0                 0.000000            0.000000             0.207288
# 1                 0.231558            0.231558             0.288233
# 2                 0.290401            0.290401             0.346598
# 3                 0.348780            0.348780             0.404318
# 4                 0.406691            0.406691             0.462530
# ...                    ...                 ...                  ...
# 57512            98.384405           98.384405            98.437136
# 57513            98.437647           98.437647            98.490177
# 57514            98.490717           98.490717            98.543373
# 57515            98.543918           98.543918            98.596621
# 57516            98.597216           98.597216            98.649930
#
#        last_recv_time_sec  rtt_ms_first_transmission  \
# 0                0.207288                 207.288027
# 1                0.288233                  56.674957
# 2                0.346598                  56.197166
# 3                0.404318                  55.537939
# 4                0.462530                  55.839062
# ...                   ...                        ...
# 57512           98.437136                  52.731037
# 57513           98.490177                  52.530050
# 57514           98.543373                  52.655935
# 57515           98.596621                  52.702904
# 57516           98.649930                  52.713871
#
#        rtt_ms_last_transmission  num_send_observations  num_recv_observations  \
# 0                    207.288027                      1                      1
# 1                     56.674957                      1                      1
# 2                     56.197166                      1                      1
# 3                     55.537939                      1                      1
# 4                     55.839062                      1                      1
# ...                         ...                    ...                    ...
# 57512                 52.731037                      1                      1
# 57513                 52.530050                      1                      1
# 57514                 52.655935                      1                      1
# 57515                 52.702904                      1                      1
# 57516                 52.713871                      1                      1
#
#        num_retransmissions  successful_message
# 0                        0                True
# 1                        0                True
# 2                        0                True
# 3                        0                True
# 4                        0                True
# ...                    ...                 ...
# 57512                    0                True
# 57513                    0                True
# 57514                    0                True
# 57515                    0                True
# 57516                    0                True
#
# [57517 rows x 17 columns]

# %%
# %%time

client_rps_df = (
  message_rtt_df
  .groupby(by=["exp_id", "trial", "observer_id"])
  .aggregate(
    num_messages=("successful_message", "count"),
    num_successful_messages=("successful_message", "sum"),
    num_retransmissions=("num_retransmissions", "sum"),
    min_rtt_ms=("rtt_ms_first_transmission", "min"),
    median_rtt_ms=("rtt_ms_first_transmission", "median"),
    max_rtt_ms=("rtt_ms_first_transmission", "max"),
    rtt_ms_p0=("rtt_ms_first_transmission", lambda s : pd.Series.quantile(s, q=0.00)),
    rtt_ms_p25=("rtt_ms_first_transmission", lambda s : pd.Series.quantile(s, q=0.25)),
    rtt_ms_p50=("rtt_ms_first_transmission", lambda s : pd.Series.quantile(s, q=0.50)),
    rtt_ms_p75=("rtt_ms_first_transmission", lambda s : pd.Series.quantile(s, q=0.75)),
    rtt_ms_p99=("rtt_ms_first_transmission", lambda s : pd.Series.quantile(s, q=0.99)),
    rtt_ms_p100=("rtt_ms_first_transmission", lambda s : pd.Series.quantile(s, q=1.00)),
    first_active_time=("first_send_time_sec", "min"),
    last_active_time=("last_recv_time_sec", "max"),
  )
  .reset_index()
)
assert client_rps_df["min_rtt_ms"].eq(client_rps_df["rtt_ms_p0"]).all()
assert client_rps_df["median_rtt_ms"].eq(client_rps_df["rtt_ms_p50"]).all()
assert client_rps_df["max_rtt_ms"].eq(client_rps_df["rtt_ms_p100"]).all()

client_rps_df["num_failed_messages"] = client_rps_df["num_messages"] - client_rps_df["num_successful_messages"]
client_rps_df["average_rps"] = client_rps_df["num_successful_messages"] / (client_rps_df["last_active_time"] - client_rps_df["first_active_time"])

client_rps_df = client_rps_df.merge(exp_df, on="exp_id")

df = client_rps_df.copy()

bool_col_replacement = {
  "run_proxy_with_dtls": {True: "dtls", False: "coap"},
  "run_proxy_with_https": {True: "https", False: "http"},
  "reuse_connections": {True: "reuse-connections", False: "no-connection-reuse"},
  "run_attacker": {True: "attacker", False: "no-attacker"},
}
df.replace(bool_col_replacement, inplace=True)

df
# Out:
# CPU times: user 318 ms, sys: 250 µs, total: 318 ms
# Wall time: 316 ms
#                                                exp_id  trial observer_id  \
# 0        cloud_proxy_and_500mbpsattacker_withattacker      1     client1
# 1        cloud_proxy_and_500mbpsattacker_withattacker      2     client1
# 2        cloud_proxy_and_500mbpsattacker_withattacker      3     client1
# 3   cloud_proxy_and_500mbpsattacker_withattacker_d...      1     client1
# 4   cloud_proxy_and_500mbpsattacker_withattacker_d...      2     client1
# 5   cloud_proxy_and_500mbpsattacker_withattacker_d...      3     client1
# 6   cloud_proxy_and_500mbpsattacker_withattacker_d...      1     client1
# 7   cloud_proxy_and_500mbpsattacker_withattacker_d...      2     client1
# 8   cloud_proxy_and_500mbpsattacker_withattacker_d...      3     client1
# 9   cloud_proxy_and_500mbpsattacker_withattacker_h...      1     client1
# 10  cloud_proxy_and_500mbpsattacker_withattacker_h...      2     client1
# 11  cloud_proxy_and_500mbpsattacker_withattacker_h...      3     client1
# 12                cloud_proxy_and_attacker_noattacker      1     client1
# 13                cloud_proxy_and_attacker_noattacker      2     client1
# 14                cloud_proxy_and_attacker_noattacker      3     client1
# 15         cloud_proxy_and_attacker_noattacker_dtlson      1     client1
# 16         cloud_proxy_and_attacker_noattacker_dtlson      2     client1
# 17         cloud_proxy_and_attacker_noattacker_dtlson      3     client1
# 18  cloud_proxy_and_attacker_noattacker_dtlson_htt...      1     client1
# 19  cloud_proxy_and_attacker_noattacker_dtlson_htt...      2     client1
# 20  cloud_proxy_and_attacker_noattacker_dtlson_htt...      3     client1
# 21        cloud_proxy_and_attacker_noattacker_httpson      1     client1
# 22        cloud_proxy_and_attacker_noattacker_httpson      2     client1
# 23        cloud_proxy_and_attacker_noattacker_httpson      3     client1
# 24              cloud_proxy_and_attacker_withattacker      1     client1
# 25              cloud_proxy_and_attacker_withattacker      2     client1
# 26              cloud_proxy_and_attacker_withattacker      3     client1
# 27       cloud_proxy_and_attacker_withattacker_dtlson      1     client1
# 28       cloud_proxy_and_attacker_withattacker_dtlson      2     client1
# 29       cloud_proxy_and_attacker_withattacker_dtlson      3     client1
# 30  cloud_proxy_and_attacker_withattacker_dtlson_h...      1     client1
# 31  cloud_proxy_and_attacker_withattacker_dtlson_h...      2     client1
# 32  cloud_proxy_and_attacker_withattacker_dtlson_h...      3     client1
# 33      cloud_proxy_and_attacker_withattacker_httpson      1     client1
# 34      cloud_proxy_and_attacker_withattacker_httpson      2     client1
# 35      cloud_proxy_and_attacker_withattacker_httpson      3     client1
#
#     num_messages  num_successful_messages  num_retransmissions  min_rtt_ms  \
# 0           1347                     1343                    5   52.052975
# 1           1374                     1372                    4   52.093029
# 2           1372                     1371                    4   51.940918
# 3           1599                     1599                    2   51.674128
# 4           1548                     1548                    3   51.956177
# 5           1578                     1578                    2   51.681995
# 6           1595                     1595                    3   51.757097
# 7           1545                     1545                    3   51.714897
# 8           1555                     1555                    3   51.766157
# 9           1555                     1555                    3   51.675081
# 10          1548                     1548                    3   51.776171
# 11          1582                     1582                    2   51.716089
# 12          1821                     1821                    0   52.402973
# 13          1821                     1821                    0   52.587032
# 14          1822                     1822                    0   52.568197
# 15          1794                     1794                    0   52.537203
# 16          1796                     1796                    0   52.834988
# 17          1798                     1798                    0   52.763939
# 18          1787                     1787                    0   52.855968
# 19          1786                     1786                    0   52.783012
# 20          1785                     1785                    0   52.841902
# 21          1807                     1807                    0   52.251101
# 22          1810                     1810                    0   52.664995
# 23          1808                     1808                    0   52.738190
# 24          1373                     1372                    4   52.065134
# 25          1372                     1370                    4   52.036047
# 26          1372                     1369                    7   51.961899
# 27          1619                     1619                    1   51.708937
# 28          1595                     1595                    2   51.666021
# 29          1562                     1562                    3   51.530838
# 30          1573                     1573                    2   51.587105
# 31          1540                     1540                    3   51.745892
# 32          1585                     1585                    2   51.611185
# 33          1364                     1361                    4   52.196026
# 34          1362                     1360                    4   52.127123
# 35          1367                     1364                    4   52.169085
#
#     median_rtt_ms    max_rtt_ms  rtt_ms_p0  ...               topology_name  \
# 0       52.618027   7602.551937  52.052975  ...  cloud_proxy_cloud_attacker
# 1       52.622914  12678.251028  52.093029  ...  cloud_proxy_cloud_attacker
# 2       52.616000   8044.008970  51.940918  ...  cloud_proxy_cloud_attacker
# 3       52.734852   8975.060940  51.674128  ...  cloud_proxy_cloud_attacker
# 4       52.793026   9089.024067  51.956177  ...  cloud_proxy_cloud_attacker
# 5       52.734137   9309.669971  51.681995  ...  cloud_proxy_cloud_attacker
# 6       52.882910   6310.120106  51.757097  ...  cloud_proxy_cloud_attacker
# 7       52.839041   4210.739851  51.714897  ...  cloud_proxy_cloud_attacker
# 8       52.843094   8908.905029  51.766157  ...  cloud_proxy_cloud_attacker
# 9       52.836180   8294.707060  51.675081  ...  cloud_proxy_cloud_attacker
# 10      52.895069   5829.550982  51.776171  ...  cloud_proxy_cloud_attacker
# 11      52.857041   4873.840094  51.716089  ...  cloud_proxy_cloud_attacker
# 12      53.170919    154.902935  52.402973  ...  cloud_proxy_cloud_attacker
# 13      53.164005    148.150921  52.587032  ...  cloud_proxy_cloud_attacker
# 14      53.148985    143.810034  52.568197  ...  cloud_proxy_cloud_attacker
# 15      53.454995    152.678967  52.537203  ...  cloud_proxy_cloud_attacker
# 16      53.453922    145.328999  52.834988  ...  cloud_proxy_cloud_attacker
# 17      53.431988    149.559021  52.763939  ...  cloud_proxy_cloud_attacker
# 18      53.663969    296.953917  52.855968  ...  cloud_proxy_cloud_attacker
# 19      53.683043    292.608023  52.783012  ...  cloud_proxy_cloud_attacker
# 20      53.663969    293.149948  52.841902  ...  cloud_proxy_cloud_attacker
# 21      53.361893    409.994125  52.251101  ...  cloud_proxy_cloud_attacker
# 22      53.361416    335.145950  52.664995  ...  cloud_proxy_cloud_attacker
# 23      53.372502    351.361036  52.738190  ...  cloud_proxy_cloud_attacker
# 24      52.603006  21626.464844  52.065134  ...  cloud_proxy_cloud_attacker
# 25      52.608967  13428.502083  52.036047  ...  cloud_proxy_cloud_attacker
# 26      52.587032   8057.443142  51.961899  ...  cloud_proxy_cloud_attacker
# 27      52.735090   4208.555937  51.708937  ...  cloud_proxy_cloud_attacker
# 28      52.765131   9415.937901  51.666021  ...  cloud_proxy_cloud_attacker
# 29      52.781463   5087.440014  51.530838  ...  cloud_proxy_cloud_attacker
# 30      52.881002   5265.018940  51.587105  ...  cloud_proxy_cloud_attacker
# 31      52.837968   6190.264940  51.745892  ...  cloud_proxy_cloud_attacker
# 32      52.882910   9461.547852  51.611185  ...  cloud_proxy_cloud_attacker
# 33      52.736521   8150.135994  52.196026  ...  cloud_proxy_cloud_attacker
# 34      52.702904  13009.989977  52.127123  ...  cloud_proxy_cloud_attacker
# 35      52.702904  12800.011873  52.169085  ...  cloud_proxy_cloud_attacker
#
#     num_proxy_connections  request_timeout  max_retries  keep_alive_duration  \
# 0                      50                5            2                    5
# 1                      50                5            2                    5
# 2                      50                5            2                    5
# 3                      50                5            2                    5
# 4                      50                5            2                    5
# 5                      50                5            2                    5
# 6                      50                5            2                    5
# 7                      50                5            2                    5
# 8                      50                5            2                    5
# 9                      50                5            2                    5
# 10                     50                5            2                    5
# 11                     50                5            2                    5
# 12                     50                5            2                    5
# 13                     50                5            2                    5
# 14                     50                5            2                    5
# 15                     50                5            2                    5
# 16                     50                5            2                    5
# 17                     50                5            2                    5
# 18                     50                5            2                    5
# 19                     50                5            2                    5
# 20                     50                5            2                    5
# 21                     50                5            2                    5
# 22                     50                5            2                    5
# 23                     50                5            2                    5
# 24                     50                5            2                    5
# 25                     50                5            2                    5
# 26                     50                5            2                    5
# 27                     50                5            2                    5
# 28                     50                5            2                    5
# 29                     50                5            2                    5
# 30                     50                5            2                    5
# 31                     50                5            2                    5
# 32                     50                5            2                    5
# 33                     50                5            2                    5
# 34                     50                5            2                    5
# 35                     50                5            2                    5
#
#     request_retry_interval  reuse_connections  run_proxy_with_dtls  \
# 0                        1  reuse-connections                 coap
# 1                        1  reuse-connections                 coap
# 2                        1  reuse-connections                 coap
# 3                        1  reuse-connections                 dtls
# 4                        1  reuse-connections                 dtls
# 5                        1  reuse-connections                 dtls
# 6                        1  reuse-connections                 dtls
# 7                        1  reuse-connections                 dtls
# 8                        1  reuse-connections                 dtls
# 9                        1  reuse-connections                 dtls
# 10                       1  reuse-connections                 dtls
# 11                       1  reuse-connections                 dtls
# 12                       1  reuse-connections                 coap
# 13                       1  reuse-connections                 coap
# 14                       1  reuse-connections                 coap
# 15                       1  reuse-connections                 dtls
# 16                       1  reuse-connections                 dtls
# 17                       1  reuse-connections                 dtls
# 18                       1  reuse-connections                 dtls
# 19                       1  reuse-connections                 dtls
# 20                       1  reuse-connections                 dtls
# 21                       1  reuse-connections                 coap
# 22                       1  reuse-connections                 coap
# 23                       1  reuse-connections                 coap
# 24                       1  reuse-connections                 coap
# 25                       1  reuse-connections                 coap
# 26                       1  reuse-connections                 coap
# 27                       1  reuse-connections                 dtls
# 28                       1  reuse-connections                 dtls
# 29                       1  reuse-connections                 dtls
# 30                       1  reuse-connections                 dtls
# 31                       1  reuse-connections                 dtls
# 32                       1  reuse-connections                 dtls
# 33                       1  reuse-connections                 coap
# 34                       1  reuse-connections                 coap
# 35                       1  reuse-connections                 coap
#
#     run_proxy_with_https run_attacker
# 0                   http     attacker
# 1                   http     attacker
# 2                   http     attacker
# 3                   http     attacker
# 4                   http     attacker
# 5                   http     attacker
# 6                  https     attacker
# 7                  https     attacker
# 8                  https     attacker
# 9                  https     attacker
# 10                 https     attacker
# 11                 https     attacker
# 12                  http  no-attacker
# 13                  http  no-attacker
# 14                  http  no-attacker
# 15                  http  no-attacker
# 16                  http  no-attacker
# 17                  http  no-attacker
# 18                 https  no-attacker
# 19                 https  no-attacker
# 20                 https  no-attacker
# 21                 https  no-attacker
# 22                 https  no-attacker
# 23                 https  no-attacker
# 24                  http     attacker
# 25                  http     attacker
# 26                  http     attacker
# 27                  http     attacker
# 28                  http     attacker
# 29                  http     attacker
# 30                 https     attacker
# 31                 https     attacker
# 32                 https     attacker
# 33                 https     attacker
# 34                 https     attacker
# 35                 https     attacker
#
# [36 rows x 40 columns]

# %%
param_comparison_scope = ["run_attacker", "run_proxy_with_dtls", "run_proxy_with_https"]

plot_args = {
  "rot": 75,
}

ax = None
ax = df.boxplot("average_rps", by=param_comparison_scope, ax=ax, **plot_args)
plt.show()

# %%
param_comparison_scope = ["topology_name"]

ax = None
ax = df.boxplot("average_rps", by=param_comparison_scope, ax=ax)
plt.show()

# %%
param_comparison_scope = ["run_attacker", "topology_name", "run_proxy_with_dtls", "run_proxy_with_https"]

plot_args = {
  "by": param_comparison_scope,
  "rot": 90,
}

_, axes = plt.subplots(1, 4)

df.boxplot("min_rtt_ms", ax=axes[0], **plot_args)
df.boxplot("median_rtt_ms", ax=axes[1], **plot_args)
df.boxplot("rtt_ms_p99", ax=axes[2], **plot_args)
df.boxplot("max_rtt_ms", ax=axes[3], **plot_args)

plt.show()
