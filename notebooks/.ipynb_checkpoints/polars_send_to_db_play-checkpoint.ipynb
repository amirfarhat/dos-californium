# %%
# %%time

import polars as pl

FILE_PATH = "/home/ubuntu/dos-californium/deter/expdata/real/final/client_and_attacker_dtlson/1/client_and_attacker_dtlson.parquet"

df = (
  pl
  .scan_parquet(FILE_PATH, use_pyarrow=True, null_values="NULL")
  .collect()
)

df
# Out:
# CPU times: user 676 ms, sys: 142 ms, total: 818 ms
# Wall time: 105 ms
# shape: (381437, 20)
# ┌────────────┬────────────┬────────────┬────────────┬─────┬────────────┬─────────┬────┬────────────┐
# │ message_ti ┆ message_so ┆ message_de ┆ message_pr ┆ ... ┆ http_respo ┆ node_ty ┆ ui ┆ message_ma │
# │ mestamp    ┆ urce       ┆ stination  ┆ otocol     ┆     ┆ nse_for_ur ┆ pe      ┆ d  ┆ rker       │
# │ ---        ┆ ---        ┆ ---        ┆ ---        ┆     ┆ i          ┆ ---     ┆ -- ┆ ---        │
# │ f64        ┆ str        ┆ str        ┆ str        ┆     ┆ ---        ┆ str     ┆ -  ┆ u32        │
# │            ┆            ┆            ┆            ┆     ┆ str        ┆         ┆ st ┆            │
# │            ┆            ┆            ┆            ┆     ┆            ┆         ┆ r  ┆            │
# ╞════════════╪════════════╪════════════╪════════════╪═════╪════════════╪═════════╪════╪════════════╡
# │ 1.6479e9   ┆ client1    ┆ 10.1.5.99  ┆ coap       ┆ ... ┆ null       ┆ client1 ┆ 1_ ┆ 1          │
# │            ┆            ┆            ┆            ┆     ┆            ┆         ┆ 8b ┆            │
# │            ┆            ┆            ┆            ┆     ┆            ┆         ┆ 03 ┆            │
# │            ┆            ┆            ┆            ┆     ┆            ┆         ┆ 8c ┆            │
# │            ┆            ┆            ┆            ┆     ┆            ┆         ┆ 83 ┆            │
# │            ┆            ┆            ┆            ┆     ┆            ┆         ┆ f7 ┆            │
# │            ┆            ┆            ┆            ┆     ┆            ┆         ┆ b7 ┆            │
# │            ┆            ┆            ┆            ┆     ┆            ┆         ┆ 6f ┆            │
# │            ┆            ┆            ┆            ┆     ┆            ┆         ┆ c9 ┆            │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 1.6479e9   ┆ client1    ┆ 10.1.5.99  ┆ coap       ┆ ... ┆ null       ┆ proxy   ┆ 1_ ┆ 1          │
# │            ┆            ┆            ┆            ┆     ┆            ┆         ┆ 8b ┆            │
# │            ┆            ┆            ┆            ┆     ┆            ┆         ┆ 03 ┆            │
# │            ┆            ┆            ┆            ┆     ┆            ┆         ┆ 8c ┆            │
# │            ┆            ┆            ┆            ┆     ┆            ┆         ┆ 83 ┆            │
# │            ┆            ┆            ┆            ┆     ┆            ┆         ┆ f7 ┆            │
# │            ┆            ┆            ┆            ┆     ┆            ┆         ┆ b7 ┆            │
# │            ┆            ┆            ┆            ┆     ┆            ┆         ┆ 6f ┆            │
# │            ┆            ┆            ┆            ┆     ┆            ┆         ┆ c9 ┆            │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 1.6479e9   ┆ 10.1.5.99  ┆ originserv ┆ http       ┆ ... ┆ null       ┆ proxy   ┆ 1_ ┆ 1          │
# │            ┆            ┆ er         ┆            ┆     ┆            ┆         ┆ 8b ┆            │
# │            ┆            ┆            ┆            ┆     ┆            ┆         ┆ 03 ┆            │
# │            ┆            ┆            ┆            ┆     ┆            ┆         ┆ 8c ┆            │
# │            ┆            ┆            ┆            ┆     ┆            ┆         ┆ 83 ┆            │
# │            ┆            ┆            ┆            ┆     ┆            ┆         ┆ f7 ┆            │
# │            ┆            ┆            ┆            ┆     ┆            ┆         ┆ b7 ┆            │
# │            ┆            ┆            ┆            ┆     ┆            ┆         ┆ 6f ┆            │
# │            ┆            ┆            ┆            ┆     ┆            ┆         ┆ c9 ┆            │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 1.6479e9   ┆ originserv ┆ 10.1.5.99  ┆ http       ┆ ... ┆ http://10. ┆ proxy   ┆ 1_ ┆ 1          │
# │            ┆ er         ┆            ┆            ┆     ┆ 1.1.1:80/1 ┆         ┆ 8b ┆            │
# │            ┆            ┆            ┆            ┆     ┆ _8b038c83f ┆         ┆ 03 ┆            │
# │            ┆            ┆            ┆            ┆     ┆ 7b...      ┆         ┆ 8c ┆            │
# │            ┆            ┆            ┆            ┆     ┆            ┆         ┆ 83 ┆            │
# │            ┆            ┆            ┆            ┆     ┆            ┆         ┆ f7 ┆            │
# │            ┆            ┆            ┆            ┆     ┆            ┆         ┆ b7 ┆            │
# │            ┆            ┆            ┆            ┆     ┆            ┆         ┆ 6f ┆            │
# │            ┆            ┆            ┆            ┆     ┆            ┆         ┆ c9 ┆            │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ ...        ┆ ...        ┆ ...        ┆ ...        ┆ ... ┆ ...        ┆ ...     ┆ .. ┆ ...        │
# │            ┆            ┆            ┆            ┆     ┆            ┆         ┆ .  ┆            │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 1.6479e9   ┆ originserv ┆ 10.1.5.99  ┆ http       ┆ ... ┆ http://10. ┆ proxy   ┆ 14 ┆ 67116      │
# │            ┆ er         ┆            ┆            ┆     ┆ 1.1.1:80/1 ┆         ┆ 27 ┆            │
# │            ┆            ┆            ┆            ┆     ┆ 427_2f7189 ┆         ┆ _2 ┆            │
# │            ┆            ┆            ┆            ┆     ┆ 62...      ┆         ┆ f7 ┆            │
# │            ┆            ┆            ┆            ┆     ┆            ┆         ┆ 18 ┆            │
# │            ┆            ┆            ┆            ┆     ┆            ┆         ┆ 96 ┆            │
# │            ┆            ┆            ┆            ┆     ┆            ┆         ┆ 20 ┆            │
# │            ┆            ┆            ┆            ┆     ┆            ┆         ┆ 92 ┆            │
# │            ┆            ┆            ┆            ┆     ┆            ┆         ┆ 30 ┆            │
# │            ┆            ┆            ┆            ┆     ┆            ┆         ┆ 6a ┆            │
# │            ┆            ┆            ┆            ┆     ┆            ┆         ┆ 5  ┆            │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 1.6479e9   ┆ 10.1.5.99  ┆ client1    ┆ coap       ┆ ... ┆ null       ┆ proxy   ┆ 14 ┆ 67116      │
# │            ┆            ┆            ┆            ┆     ┆            ┆         ┆ 27 ┆            │
# │            ┆            ┆            ┆            ┆     ┆            ┆         ┆ _2 ┆            │
# │            ┆            ┆            ┆            ┆     ┆            ┆         ┆ f7 ┆            │
# │            ┆            ┆            ┆            ┆     ┆            ┆         ┆ 18 ┆            │
# │            ┆            ┆            ┆            ┆     ┆            ┆         ┆ 96 ┆            │
# │            ┆            ┆            ┆            ┆     ┆            ┆         ┆ 20 ┆            │
# │            ┆            ┆            ┆            ┆     ┆            ┆         ┆ 92 ┆            │
# │            ┆            ┆            ┆            ┆     ┆            ┆         ┆ 30 ┆            │
# │            ┆            ┆            ┆            ┆     ┆            ┆         ┆ 6a ┆            │
# │            ┆            ┆            ┆            ┆     ┆            ┆         ┆ 5  ┆            │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 1.6479e9   ┆ 10.1.5.99  ┆ originserv ┆ http       ┆ ... ┆ null       ┆ origins ┆ 14 ┆ 67116      │
# │            ┆            ┆ er         ┆            ┆     ┆            ┆ erver   ┆ 27 ┆            │
# │            ┆            ┆            ┆            ┆     ┆            ┆         ┆ _2 ┆            │
# │            ┆            ┆            ┆            ┆     ┆            ┆         ┆ f7 ┆            │
# │            ┆            ┆            ┆            ┆     ┆            ┆         ┆ 18 ┆            │
# │            ┆            ┆            ┆            ┆     ┆            ┆         ┆ 96 ┆            │
# │            ┆            ┆            ┆            ┆     ┆            ┆         ┆ 20 ┆            │
# │            ┆            ┆            ┆            ┆     ┆            ┆         ┆ 92 ┆            │
# │            ┆            ┆            ┆            ┆     ┆            ┆         ┆ 30 ┆            │
# │            ┆            ┆            ┆            ┆     ┆            ┆         ┆ 6a ┆            │
# │            ┆            ┆            ┆            ┆     ┆            ┆         ┆ 5  ┆            │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 1.6479e9   ┆ originserv ┆ 10.1.5.99  ┆ http       ┆ ... ┆ http://10. ┆ origins ┆ 14 ┆ 67116      │
# │            ┆ er         ┆            ┆            ┆     ┆ 1.1.1:80/1 ┆ erver   ┆ 27 ┆            │
# │            ┆            ┆            ┆            ┆     ┆ 427_2f7189 ┆         ┆ _2 ┆            │
# │            ┆            ┆            ┆            ┆     ┆ 62...      ┆         ┆ f7 ┆            │
# │            ┆            ┆            ┆            ┆     ┆            ┆         ┆ 18 ┆            │
# │            ┆            ┆            ┆            ┆     ┆            ┆         ┆ 96 ┆            │
# │            ┆            ┆            ┆            ┆     ┆            ┆         ┆ 20 ┆            │
# │            ┆            ┆            ┆            ┆     ┆            ┆         ┆ 92 ┆            │
# │            ┆            ┆            ┆            ┆     ┆            ┆         ┆ 30 ┆            │
# │            ┆            ┆            ┆            ┆     ┆            ┆         ┆ 6a ┆            │
# │            ┆            ┆            ┆            ┆     ┆            ┆         ┆ 5  ┆            │
# └────────────┴────────────┴────────────┴────────────┴─────┴────────────┴─────────┴────┴────────────┘

# %%
(
  df
  .groupby("message_protocol")
  .agg(
    pl.col("message_protocol").count().alias("count")
  )
)
# Out:
# shape: (2, 2)
# ┌──────────────────┬─────────┐
# │ message_protocol ┆ count   │
# │ ---              ┆ ---     │
# │ str              ┆ u32     │
# ╞══════════════════╪═════════╡
# │ coap             ┆ 1719429 │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┤
# │ http             ┆ 62673   │
# └──────────────────┴─────────┘

# %%
http_df = (
  df
  .filter(
    pl.col("message_protocol") == "http"
  )
)

http_request_df = (
  df
  .filter(
    (pl.col("http_request") == True)
    & (pl.col("http_request_method") == "get")
  )
)

http_response_df = (
  df
  .filter(
    (pl.col("http_request") == False)
    & (pl.col("http_response_code") == 200)
  )
)

print(f"{len(http_df)=}")
print(f"{len(http_request_df)=}")
print(f"{len(http_response_df)=}")

assert len(http_df) == len(http_request_df) + len(http_response_df)

http_df.select(["http_request", "hmci"])
# Out:
# len(http_df)=62673
# len(http_request_df)=31139
# len(http_response_df)=31534
# shape: (62673, 2)
# ┌──────────────┬──────┐
# │ http_request ┆ hmci │
# │ ---          ┆ ---  │
# │ bool         ┆ i32  │
# ╞══════════════╪══════╡
# │ true         ┆ 1    │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌┤
# │ false        ┆ -99  │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌┤
# │ true         ┆ 1    │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌┤
# │ true         ┆ 1    │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌┤
# │ ...          ┆ ...  │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌┤
# │ false        ┆ -99  │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌┤
# │ false        ┆ -99  │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌┤
# │ true         ┆ 1    │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌┤
# │ false        ┆ -99  │
# └──────────────┴──────┘

# %%
(
  df
  .groupby("hmci")
  .agg(
    pl.col("hmci").count().alias("count")
  )
)
# Out:
# shape: (2, 2)
# ┌──────┬─────────┐
# │ hmci ┆ count   │
# │ ---  ┆ ---     │
# │ i32  ┆ u32     │
# ╞══════╪═════════╡
# │ -99  ┆ 1750963 │
# ├╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┤
# │ 1    ┆ 31139   │
# └──────┴─────────┘
