# %%
import polars as pl
import pandas as pd
pd.options.mode.chained_assignment = None
import numpy as np

import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [16, 8]
import matplotlib.cm as cm

group_dir = "/home/ubuntu/cloudgroupe2e"

# %%
# Read the group's entire data

lazy_results_df = (
  pl.scan_parquet(f"{group_dir}/results.parquet")
)
exp_results_df = lazy_results_df

configurations_df = (
  pl.read_parquet(f"{group_dir}/configurations.parquet")
)
pd_configurations_df = configurations_df.to_pandas()

metrics_df = (
  pl.read_parquet(f"{group_dir}/metrics.parquet")
)
pd_metrics_df = (
  metrics_df
  .to_pandas()
  .sort_values(by=["node_type", "trial", "observation_timestamp"])
)

pd_metrics_df
# Out:
#           node_type         metric_type  trial  metric_value  \
# 635    originserver     cpu_utilization      1           0.7
# 755    originserver  memory_utilization      1         218.0
# 4457   originserver     cpu_utilization      1           1.2
# 4577   originserver  memory_utilization      1         229.0
# 4578   originserver  memory_utilization      1         229.0
# ...             ...                 ...    ...           ...
# 33819         proxy  memory_utilization      3        4502.0
# 37648         proxy  memory_utilization      3        1124.0
# 37649         proxy  memory_utilization      3        1124.0
# 41476         proxy  memory_utilization      3        1108.0
# 41477         proxy  memory_utilization      3        1108.0
#
#        observation_timestamp  \
# 635                        0
# 755                        0
# 4457                       0
# 4577                       0
# 4578                       0
# ...                      ...
# 33819                    120
# 37648                    120
# 37649                    120
# 41476                    120
# 41477                    120
#
#                                                   exp_id
# 635         cloud_proxy_and_500mbpsattacker_withattacker
# 755         cloud_proxy_and_500mbpsattacker_withattacker
# 4457   cloud_proxy_and_500mbpsattacker_withattacker_d...
# 4577   cloud_proxy_and_500mbpsattacker_withattacker_d...
# 4578   cloud_proxy_and_500mbpsattacker_withattacker_d...
# ...                                                  ...
# 33819              cloud_proxy_and_attacker_withattacker
# 37648       cloud_proxy_and_attacker_withattacker_dtlson
# 37649       cloud_proxy_and_attacker_withattacker_dtlson
# 41476  cloud_proxy_and_attacker_withattacker_dtlson_h...
# 41477  cloud_proxy_and_attacker_withattacker_dtlson_h...
#
# [45935 rows x 6 columns]

# %%
# %%time

client_sends_df = (
  exp_results_df
  .filter(
    (pl.col("message_source").str.contains("client"))
    & (pl.col("node_type").str.contains("client"))
  )
)
client_recvs_df = (
  exp_results_df
  .filter(
    (pl.col("message_destination").str.contains("client"))
    & (pl.col("node_type").str.contains("client"))
  )
)

rtts_df = (
  client_sends_df
  .join(
    client_recvs_df,
    on=["trial", "node_type", "message_marker"],
    how="left",
  )
  .groupby(by=["exp_id", "trial", "node_type", "message_marker"])
  .agg([
    pl.col("coap_code").first().alias("response_code"),
    pl.col("message_timestamp").min().alias("send_time_sec"),
    pl.col("message_timestamp_right").min().alias("recv_time_sec"),
    pl.col("message_timestamp").min().alias("first_send_time_sec"),
    pl.col("message_timestamp").max().alias("last_send_time_sec"),
    pl.col("message_timestamp_right").min().alias("first_recv_time_sec"),
    pl.col("message_timestamp_right").max().alias("last_recv_time_sec"),
    pl.col("message_timestamp").count().alias("num_send_observations"),
    pl.col("message_timestamp_right").count().alias("num_recv_observations"),
    (pl.col("coap_retransmitted") == True).sum().alias("num_retransmissions"),
  ])
  .with_columns([
    (1e3 * (pl.col("first_recv_time_sec") - pl.col("first_send_time_sec"))).alias("rtt_ms_first_transmission"),
    (1e3 * (pl.col("first_recv_time_sec") - pl.col("last_send_time_sec"))).alias("rtt_ms_last_transmission"),
  ])
  .sort(by=["exp_id", "trial", "node_type", "message_marker"])
)

stats_df = (
  rtts_df
  .groupby(by=["exp_id", "trial", "node_type"])
  .agg([
    pl.col("message_marker").n_unique().alias("num_messages"),
    pl.col("send_time_sec").min().alias("global_first_send_time_sec"),
    pl.col("recv_time_sec").max().alias("global_last_recv_time_sec"),
  ])
  .with_columns([
    (pl.col("num_messages") / (pl.col("global_last_recv_time_sec") - pl.col("global_first_send_time_sec"))).alias("average_rps"),
  ])
  .filter(
    pl.col("node_type").str.contains("client")
  )
)

rtts_df = (
  rtts_df.join(
    stats_df,
    on=["exp_id", "trial", "node_type"],
    how="left",
  )
  .collect()
  .to_pandas()
)

message_rtt_df = rtts_df
message_rtt_df["successful_message"] = False
message_rtt_df.loc[(message_rtt_df["response_code"] == "content"), "successful_message"] = True

print(message_rtt_df["response_code"].unique())

message_rtt_df
# Out:
# ['get']
# CPU times: user 42.2 s, sys: 32.6 s, total: 1min 14s
# Wall time: 20.5 s
#                                               exp_id  trial node_type  \
# 0       cloud_proxy_and_500mbpsattacker_withattacker      1   client1
# 1       cloud_proxy_and_500mbpsattacker_withattacker      1   client1
# 2       cloud_proxy_and_500mbpsattacker_withattacker      1   client1
# 3       cloud_proxy_and_500mbpsattacker_withattacker      1   client1
# 4       cloud_proxy_and_500mbpsattacker_withattacker      1   client1
# ...                                              ...    ...       ...
# 57548  cloud_proxy_and_attacker_withattacker_httpson      3   client1
# 57549  cloud_proxy_and_attacker_withattacker_httpson      3   client1
# 57550  cloud_proxy_and_attacker_withattacker_httpson      3   client1
# 57551  cloud_proxy_and_attacker_withattacker_httpson      3   client1
# 57552  cloud_proxy_and_attacker_withattacker_httpson      3   client1
#
#        message_marker response_code  send_time_sec  recv_time_sec  \
# 0                   1           get       0.000000       0.142585
# 1                   2           get       0.231558       0.215283
# 2                   3           get       0.290401       0.276118
# 3                   4           get       0.348780       0.337057
# 4                   5           get       0.406691       0.398103
# ...               ...           ...            ...            ...
# 57548          518420           get      98.437647      98.490177
# 57549          518421           get      98.490717      98.543373
# 57550          518422           get      98.543918      98.596621
# 57551          518423           get      98.597216      98.649930
# 57552          518424           get      98.650469            NaN
#
#        first_send_time_sec  last_send_time_sec  first_recv_time_sec  ...  \
# 0                 0.000000            0.000000             0.142585  ...
# 1                 0.231558            0.231558             0.215283  ...
# 2                 0.290401            0.290401             0.276118  ...
# 3                 0.348780            0.348780             0.337057  ...
# 4                 0.406691            0.406691             0.398103  ...
# ...                    ...                 ...                  ...  ...
# 57548            98.437647           98.437647            98.490177  ...
# 57549            98.490717           98.490717            98.543373  ...
# 57550            98.543918           98.543918            98.596621  ...
# 57551            98.597216           98.597216            98.649930  ...
# 57552            98.650469           98.650469                  NaN  ...
#
#        num_send_observations  num_recv_observations  num_retransmissions  \
# 0                         12                     12                    0
# 1                         12                     12                    0
# 2                         12                     12                    0
# 3                         12                     12                    0
# 4                         12                     12                    0
# ...                      ...                    ...                  ...
# 57548                      1                      1                    0
# 57549                      1                      1                    0
# 57550                      1                      1                    0
# 57551                      1                      1                    0
# 57552                      1                      1                    0
#
#        rtt_ms_first_transmission  rtt_ms_last_transmission  num_messages  \
# 0                     142.585039                142.585039          1348
# 1                     -16.275167                -16.275167          1348
# 2                     -14.282942                -14.282942          1348
# 3                     -11.723280                -11.723280          1348
# 4                      -8.588076                 -8.588076          1348
# ...                          ...                       ...           ...
# 57548                  52.530050                 52.530050          1368
# 57549                  52.655935                 52.655935          1368
# 57550                  52.702904                 52.702904          1368
# 57551                  52.713871                 52.713871          1368
# 57552                        NaN                       NaN          1368
#
#        global_first_send_time_sec  global_last_recv_time_sec  average_rps  \
# 0                             0.0                  97.301259    13.853880
# 1                             0.0                  97.301259    13.853880
# 2                             0.0                  97.301259    13.853880
# 3                             0.0                  97.301259    13.853880
# 4                             0.0                  97.301259    13.853880
# ...                           ...                        ...          ...
# 57548                         0.0                  98.649930    13.867217
# 57549                         0.0                  98.649930    13.867217
# 57550                         0.0                  98.649930    13.867217
# 57551                         0.0                  98.649930    13.867217
# 57552                         0.0                  98.649930    13.867217
#
#        successful_message
# 0                   False
# 1                   False
# 2                   False
# 3                   False
# 4                   False
# ...                   ...
# 57548               False
# 57549               False
# 57550               False
# 57551               False
# 57552               False
#
# [57553 rows x 21 columns]

# %%
message_rtt_df["observer_id"] = message_rtt_df["node_type"]

# %%
# %%time

client_rps_df = (
  message_rtt_df
  .groupby(by=["exp_id", "trial", "observer_id"])
  .aggregate(
    num_messages=("successful_message", "count"),
    num_successful_messages=("successful_message", "sum"),
    num_retransmissions=("num_retransmissions", "sum"),
    stddev_rtt_ms=("rtt_ms_first_transmission", "std"),
    min_rtt_ms=("rtt_ms_first_transmission", "min"),
    median_rtt_ms=("rtt_ms_first_transmission", "median"),
    max_rtt_ms=("rtt_ms_first_transmission", "max"),
    rtt_ms_p0=("rtt_ms_first_transmission", lambda s : pd.Series.quantile(s, q=0.00)),
    rtt_ms_p25=("rtt_ms_first_transmission", lambda s : pd.Series.quantile(s, q=0.25)),
    rtt_ms_p50=("rtt_ms_first_transmission", lambda s : pd.Series.quantile(s, q=0.50)),
    rtt_ms_p75=("rtt_ms_first_transmission", lambda s : pd.Series.quantile(s, q=0.75)),
    rtt_ms_p99=("rtt_ms_first_transmission", lambda s : pd.Series.quantile(s, q=0.99)),
    rtt_ms_p100=("rtt_ms_first_transmission", lambda s : pd.Series.quantile(s, q=1.00)),
    first_active_time=("first_send_time_sec", "min"),
    last_active_time=("last_recv_time_sec", "max"),
  )
  .reset_index()
)
assert client_rps_df["min_rtt_ms"].eq(client_rps_df["rtt_ms_p0"]).all()
assert client_rps_df["median_rtt_ms"].eq(client_rps_df["rtt_ms_p50"]).all()
assert client_rps_df["max_rtt_ms"].eq(client_rps_df["rtt_ms_p100"]).all()

client_rps_df["num_failed_messages"] = client_rps_df["num_messages"] - client_rps_df["num_successful_messages"]
client_rps_df["average_rps"] = client_rps_df["num_successful_messages"] / (client_rps_df["last_active_time"] - client_rps_df["first_active_time"])

client_rps_df = client_rps_df.merge(pd_configurations_df, on="exp_id")
bool_col_replacement = {
  "run_proxy_with_dtls": {True: "dtls", False: "coap"},
  "run_proxy_with_https": {True: "https", False: "http"},
  "reuse_connections": {True: "reuse-connections", False: "no-connection-reuse"},
  "run_attacker": {True: "attacker", False: "no-attacker"},
}
client_rps_df.replace(bool_col_replacement, inplace=True)

client_rps_df
# Out:
# CPU times: user 305 ms, sys: 13.4 ms, total: 318 ms
# Wall time: 316 ms
#                                                exp_id  trial observer_id  \
# 0        cloud_proxy_and_500mbpsattacker_withattacker      1     client1
# 1        cloud_proxy_and_500mbpsattacker_withattacker      2     client1
# 2        cloud_proxy_and_500mbpsattacker_withattacker      3     client1
# 3   cloud_proxy_and_500mbpsattacker_withattacker_d...      1     client1
# 4   cloud_proxy_and_500mbpsattacker_withattacker_d...      2     client1
# 5   cloud_proxy_and_500mbpsattacker_withattacker_d...      3     client1
# 6   cloud_proxy_and_500mbpsattacker_withattacker_d...      1     client1
# 7   cloud_proxy_and_500mbpsattacker_withattacker_d...      2     client1
# 8   cloud_proxy_and_500mbpsattacker_withattacker_d...      3     client1
# 9   cloud_proxy_and_500mbpsattacker_withattacker_h...      1     client1
# 10  cloud_proxy_and_500mbpsattacker_withattacker_h...      2     client1
# 11  cloud_proxy_and_500mbpsattacker_withattacker_h...      3     client1
# 12                cloud_proxy_and_attacker_noattacker      1     client1
# 13                cloud_proxy_and_attacker_noattacker      2     client1
# 14                cloud_proxy_and_attacker_noattacker      3     client1
# 15         cloud_proxy_and_attacker_noattacker_dtlson      1     client1
# 16         cloud_proxy_and_attacker_noattacker_dtlson      2     client1
# 17         cloud_proxy_and_attacker_noattacker_dtlson      3     client1
# 18  cloud_proxy_and_attacker_noattacker_dtlson_htt...      1     client1
# 19  cloud_proxy_and_attacker_noattacker_dtlson_htt...      2     client1
# 20  cloud_proxy_and_attacker_noattacker_dtlson_htt...      3     client1
# 21        cloud_proxy_and_attacker_noattacker_httpson      1     client1
# 22        cloud_proxy_and_attacker_noattacker_httpson      2     client1
# 23        cloud_proxy_and_attacker_noattacker_httpson      3     client1
# 24              cloud_proxy_and_attacker_withattacker      1     client1
# 25              cloud_proxy_and_attacker_withattacker      2     client1
# 26              cloud_proxy_and_attacker_withattacker      3     client1
# 27       cloud_proxy_and_attacker_withattacker_dtlson      1     client1
# 28       cloud_proxy_and_attacker_withattacker_dtlson      2     client1
# 29       cloud_proxy_and_attacker_withattacker_dtlson      3     client1
# 30  cloud_proxy_and_attacker_withattacker_dtlson_h...      1     client1
# 31  cloud_proxy_and_attacker_withattacker_dtlson_h...      2     client1
# 32  cloud_proxy_and_attacker_withattacker_dtlson_h...      3     client1
# 33      cloud_proxy_and_attacker_withattacker_httpson      1     client1
# 34      cloud_proxy_and_attacker_withattacker_httpson      2     client1
# 35      cloud_proxy_and_attacker_withattacker_httpson      3     client1
#
#     num_messages  num_successful_messages  num_retransmissions  stddev_rtt_ms  \
# 0           1348                        0                    5     318.191454
# 1           1375                        0                    4     393.399395
# 2           1373                        0                    4     312.459188
# 3           1600                        0                    2    4456.768530
# 4           1549                        0                    3     359.694794
# 5           1579                        0                    2     260.339391
# 6           1596                        0                    3    4742.878728
# 7           1546                        0                    3    7382.480112
# 8           1556                        0                    3    6367.596678
# 9           1556                        0                    3    5651.545626
# 10          1549                        0                    3    7275.159194
# 11          1583                        0                    6    3169.305244
# 12          1822                        0                    0    4139.761486
# 13          1822                        0                    0    4181.220936
# 14          1823                        0                    0    3060.858567
# 15          1795                        0                    0    3986.111739
# 16          1797                        0                    0    4235.584777
# 17          1799                        0                    0    3101.253385
# 18          1788                        0                    0    4009.868708
# 19          1787                        0                    0    3867.147317
# 20          1786                        0                    0    3134.847219
# 21          1808                        0                    0    4164.029436
# 22          1811                        0                    0    4199.030102
# 23          1809                        0                    0    3081.391302
# 24          1374                        0                   10     588.658629
# 25          1373                        0                   12     410.002941
# 26          1373                        0                    7     343.528190
# 27          1620                        0                    1    2464.239090
# 28          1596                        0                   10    6400.918721
# 29          1563                        0                    7    7093.988171
# 30          1574                        0                    6     228.162118
# 31          1541                        0                    3    4590.155996
# 32          1586                        0                    2    4956.641069
# 33          1365                        0                    8    6769.716325
# 34          1363                        0                    4     424.567669
# 35          1368                        0                    4     417.666317
#
#       min_rtt_ms  median_rtt_ms    max_rtt_ms  ...  \
# 0     -16.275167      52.555084   7602.551937  ...
# 1       7.383823      52.541494  12678.251028  ...
# 2     -17.952919      52.546024   8044.008970  ...
# 3  -56653.749943      52.652121   8975.060940  ...
# 4   -3193.634272      52.710056   9089.024067  ...
# 5    -358.482122      52.654505   9309.669971  ...
# 6  -59513.997078   -2705.106020   6310.120106  ...
# 7  -51629.169941   -1576.577067   4210.739851  ...
# 8  -38489.850760      52.752972   8908.905029  ...
# 9  -48991.306067      52.736998   8294.707060  ...
# 10 -50002.281904      52.808046   5829.550982  ...
# 11 -45202.253103      52.770972   4083.822966  ...
# 12 -73407.769918      53.166866    126.377106  ...
# 13 -75648.477077      53.158045    125.386953  ...
# 14 -73456.935883      53.061008    112.365246  ...
# 15 -74402.663231    -559.204102    133.838892  ...
# 16 -76695.065022    -582.648039    135.195017  ...
# 17 -74427.567720    -513.973951    124.866247  ...
# 18 -74926.481009    -887.167096    142.585039  ...
# 19 -68429.080009    -949.307919    145.045042  ...
# 20 -75052.397013    -953.273535    136.227131  ...
# 21 -74167.237043    -553.767204    126.208067  ...
# 22 -76202.092886    -369.889975    136.860132  ...
# 23 -74165.339947    -461.875200    133.975983  ...
# 24      8.577108      52.514076  21626.464844  ...
# 25     19.293070      52.533507  13428.502083  ...
# 26     20.366192      52.557468   8057.443142  ...
# 27 -42462.367773      52.641869   4208.555937  ...
# 28 -53628.249884      52.672505   9415.937901  ...
# 29 -55751.995087      52.701950   4236.363888  ...
# 30   -588.460207      52.798986   3821.337938  ...
# 31 -50112.350941      52.760124   6190.264940  ...
# 32 -55113.440990      52.782774   9461.547852  ...
# 33 -13801.133871  -13640.247822   8150.135994  ...
# 34   -319.506168      52.612543  13009.989977  ...
# 35   -306.868076      52.625179  12800.011873  ...
#
#                  topology_name  num_proxy_connections  request_timeout  \
# 0   cloud_proxy_cloud_attacker                     50                5
# 1   cloud_proxy_cloud_attacker                     50                5
# 2   cloud_proxy_cloud_attacker                     50                5
# 3   cloud_proxy_cloud_attacker                     50                5
# 4   cloud_proxy_cloud_attacker                     50                5
# 5   cloud_proxy_cloud_attacker                     50                5
# 6   cloud_proxy_cloud_attacker                     50                5
# 7   cloud_proxy_cloud_attacker                     50                5
# 8   cloud_proxy_cloud_attacker                     50                5
# 9   cloud_proxy_cloud_attacker                     50                5
# 10  cloud_proxy_cloud_attacker                     50                5
# 11  cloud_proxy_cloud_attacker                     50                5
# 12  cloud_proxy_cloud_attacker                     50                5
# 13  cloud_proxy_cloud_attacker                     50                5
# 14  cloud_proxy_cloud_attacker                     50                5
# 15  cloud_proxy_cloud_attacker                     50                5
# 16  cloud_proxy_cloud_attacker                     50                5
# 17  cloud_proxy_cloud_attacker                     50                5
# 18  cloud_proxy_cloud_attacker                     50                5
# 19  cloud_proxy_cloud_attacker                     50                5
# 20  cloud_proxy_cloud_attacker                     50                5
# 21  cloud_proxy_cloud_attacker                     50                5
# 22  cloud_proxy_cloud_attacker                     50                5
# 23  cloud_proxy_cloud_attacker                     50                5
# 24  cloud_proxy_cloud_attacker                     50                5
# 25  cloud_proxy_cloud_attacker                     50                5
# 26  cloud_proxy_cloud_attacker                     50                5
# 27  cloud_proxy_cloud_attacker                     50                5
# 28  cloud_proxy_cloud_attacker                     50                5
# 29  cloud_proxy_cloud_attacker                     50                5
# 30  cloud_proxy_cloud_attacker                     50                5
# 31  cloud_proxy_cloud_attacker                     50                5
# 32  cloud_proxy_cloud_attacker                     50                5
# 33  cloud_proxy_cloud_attacker                     50                5
# 34  cloud_proxy_cloud_attacker                     50                5
# 35  cloud_proxy_cloud_attacker                     50                5
#
#     max_retries  keep_alive_duration  request_retry_interval  \
# 0             2                    5                       1
# 1             2                    5                       1
# 2             2                    5                       1
# 3             2                    5                       1
# 4             2                    5                       1
# 5             2                    5                       1
# 6             2                    5                       1
# 7             2                    5                       1
# 8             2                    5                       1
# 9             2                    5                       1
# 10            2                    5                       1
# 11            2                    5                       1
# 12            2                    5                       1
# 13            2                    5                       1
# 14            2                    5                       1
# 15            2                    5                       1
# 16            2                    5                       1
# 17            2                    5                       1
# 18            2                    5                       1
# 19            2                    5                       1
# 20            2                    5                       1
# 21            2                    5                       1
# 22            2                    5                       1
# 23            2                    5                       1
# 24            2                    5                       1
# 25            2                    5                       1
# 26            2                    5                       1
# 27            2                    5                       1
# 28            2                    5                       1
# 29            2                    5                       1
# 30            2                    5                       1
# 31            2                    5                       1
# 32            2                    5                       1
# 33            2                    5                       1
# 34            2                    5                       1
# 35            2                    5                       1
#
#     reuse_connections  run_proxy_with_dtls  run_proxy_with_https  run_attacker
# 0   reuse-connections                 coap                  http      attacker
# 1   reuse-connections                 coap                  http      attacker
# 2   reuse-connections                 coap                  http      attacker
# 3   reuse-connections                 dtls                  http      attacker
# 4   reuse-connections                 dtls                  http      attacker
# 5   reuse-connections                 dtls                  http      attacker
# 6   reuse-connections                 dtls                 https      attacker
# 7   reuse-connections                 dtls                 https      attacker
# 8   reuse-connections                 dtls                 https      attacker
# 9   reuse-connections                 dtls                 https      attacker
# 10  reuse-connections                 dtls                 https      attacker
# 11  reuse-connections                 dtls                 https      attacker
# 12  reuse-connections                 coap                  http   no-attacker
# 13  reuse-connections                 coap                  http   no-attacker
# 14  reuse-connections                 coap                  http   no-attacker
# 15  reuse-connections                 dtls                  http   no-attacker
# 16  reuse-connections                 dtls                  http   no-attacker
# 17  reuse-connections                 dtls                  http   no-attacker
# 18  reuse-connections                 dtls                 https   no-attacker
# 19  reuse-connections                 dtls                 https   no-attacker
# 20  reuse-connections                 dtls                 https   no-attacker
# 21  reuse-connections                 coap                 https   no-attacker
# 22  reuse-connections                 coap                 https   no-attacker
# 23  reuse-connections                 coap                 https   no-attacker
# 24  reuse-connections                 coap                  http      attacker
# 25  reuse-connections                 coap                  http      attacker
# 26  reuse-connections                 coap                  http      attacker
# 27  reuse-connections                 dtls                  http      attacker
# 28  reuse-connections                 dtls                  http      attacker
# 29  reuse-connections                 dtls                  http      attacker
# 30  reuse-connections                 dtls                 https      attacker
# 31  reuse-connections                 dtls                 https      attacker
# 32  reuse-connections                 dtls                 https      attacker
# 33  reuse-connections                 coap                 https      attacker
# 34  reuse-connections                 coap                 https      attacker
# 35  reuse-connections                 coap                 https      attacker
#
# [36 rows x 41 columns]

# %%
message_rtt_df = message_rtt_df.merge(pd_configurations_df, on="exp_id")
message_rtt_df
# Out:
#                                               exp_id  trial node_type  \
# 0       cloud_proxy_and_500mbpsattacker_withattacker      1   client1
# 1       cloud_proxy_and_500mbpsattacker_withattacker      1   client1
# 2       cloud_proxy_and_500mbpsattacker_withattacker      1   client1
# 3       cloud_proxy_and_500mbpsattacker_withattacker      1   client1
# 4       cloud_proxy_and_500mbpsattacker_withattacker      1   client1
# ...                                              ...    ...       ...
# 57548  cloud_proxy_and_attacker_withattacker_httpson      3   client1
# 57549  cloud_proxy_and_attacker_withattacker_httpson      3   client1
# 57550  cloud_proxy_and_attacker_withattacker_httpson      3   client1
# 57551  cloud_proxy_and_attacker_withattacker_httpson      3   client1
# 57552  cloud_proxy_and_attacker_withattacker_httpson      3   client1
#
#        message_marker response_code  send_time_sec  recv_time_sec  \
# 0                   1           get       0.000000       0.142585
# 1                   2           get       0.231558       0.215283
# 2                   3           get       0.290401       0.276118
# 3                   4           get       0.348780       0.337057
# 4                   5           get       0.406691       0.398103
# ...               ...           ...            ...            ...
# 57548          518420           get      98.437647      98.490177
# 57549          518421           get      98.490717      98.543373
# 57550          518422           get      98.543918      98.596621
# 57551          518423           get      98.597216      98.649930
# 57552          518424           get      98.650469            NaN
#
#        first_send_time_sec  last_send_time_sec  first_recv_time_sec  ...  \
# 0                 0.000000            0.000000             0.142585  ...
# 1                 0.231558            0.231558             0.215283  ...
# 2                 0.290401            0.290401             0.276118  ...
# 3                 0.348780            0.348780             0.337057  ...
# 4                 0.406691            0.406691             0.398103  ...
# ...                    ...                 ...                  ...  ...
# 57548            98.437647           98.437647            98.490177  ...
# 57549            98.490717           98.490717            98.543373  ...
# 57550            98.543918           98.543918            98.596621  ...
# 57551            98.597216           98.597216            98.649930  ...
# 57552            98.650469           98.650469                  NaN  ...
#
#                     topology_name  num_proxy_connections  request_timeout  \
# 0      cloud_proxy_cloud_attacker                     50                5
# 1      cloud_proxy_cloud_attacker                     50                5
# 2      cloud_proxy_cloud_attacker                     50                5
# 3      cloud_proxy_cloud_attacker                     50                5
# 4      cloud_proxy_cloud_attacker                     50                5
# ...                           ...                    ...              ...
# 57548  cloud_proxy_cloud_attacker                     50                5
# 57549  cloud_proxy_cloud_attacker                     50                5
# 57550  cloud_proxy_cloud_attacker                     50                5
# 57551  cloud_proxy_cloud_attacker                     50                5
# 57552  cloud_proxy_cloud_attacker                     50                5
#
#        max_retries  keep_alive_duration  request_retry_interval  \
# 0                2                    5                       1
# 1                2                    5                       1
# 2                2                    5                       1
# 3                2                    5                       1
# 4                2                    5                       1
# ...            ...                  ...                     ...
# 57548            2                    5                       1
# 57549            2                    5                       1
# 57550            2                    5                       1
# 57551            2                    5                       1
# 57552            2                    5                       1
#
#        reuse_connections  run_proxy_with_dtls  run_proxy_with_https  \
# 0                   True                False                 False
# 1                   True                False                 False
# 2                   True                False                 False
# 3                   True                False                 False
# 4                   True                False                 False
# ...                  ...                  ...                   ...
# 57548               True                False                  True
# 57549               True                False                  True
# 57550               True                False                  True
# 57551               True                False                  True
# 57552               True                False                  True
#
#        run_attacker
# 0              True
# 1              True
# 2              True
# 3              True
# 4              True
# ...             ...
# 57548          True
# 57549          True
# 57550          True
# 57551          True
# 57552          True
#
# [57553 rows x 43 columns]

# %%
# %matplotlib notebook

df = message_rtt_df
param_comparison_scope = ["attacker_rate", "run_proxy_with_dtls", "run_proxy_with_https"]

plot_args = {
  "rot": 75,
  "by": param_comparison_scope,
}

plots = ["rtt_ms_first_transmission", "rtt_ms_last_transmission"]
_, axes = plt.subplots(1, len(plots))
for i, p in enumerate(plots):
  df.boxplot(p, ax=axes[i], **plot_args)

plt.show()

(
  message_rtt_df
  .groupby(by=["attacker_rate", "run_proxy_with_dtls", "run_proxy_with_https"])
  .agg(
    average_rps=("rtt_ms_first_transmission", "mean")
  )
)
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">
#                                                         average_rps
# attacker_rate run_proxy_with_dtls run_proxy_with_https
# 0mbps         False               False                 -245.666525
#                                   True                  -750.347830
#               True                False                 -837.567043
#                                   True                 -1194.409172
# 100mbps       False               False                   66.969792
#                                   True                 -2582.958975
#               True                False                 -805.117696
#                                   True                  -451.075501
# 500mbps       False               False                   60.021957
#               True                False                 -229.395379
#                                   True                 -1490.407414

# %%
df = client_rps_df
param_comparison_scope = ["attacker_rate", "run_proxy_with_dtls", "run_proxy_with_https"]

plot_args = {
  "rot": 75,
  "by": param_comparison_scope,
}

plots = ["average_rps", "stddev_rtt_ms"]
_, axes = plt.subplots(1, len(plots))
for i, p in enumerate(plots):
  df.boxplot(p, ax=axes[i], **plot_args)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">

# %%
param_comparison_scope = ["topology_name"]

ax = None
ax = df.boxplot("average_rps", by=param_comparison_scope, ax=ax)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">

# %%
param_comparison_scope = ["attacker_rate", "topology_name", "run_proxy_with_dtls", "run_proxy_with_https"]

plot_args = {
  "by": param_comparison_scope,
  "rot": 90,
}

_, axes = plt.subplots(1, 4)

df.boxplot("min_rtt_ms", ax=axes[0], **plot_args)
df.boxplot("median_rtt_ms", ax=axes[1], **plot_args)
df.boxplot("rtt_ms_p99", ax=axes[2], **plot_args)
df.boxplot("max_rtt_ms", ax=axes[3], **plot_args)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">
