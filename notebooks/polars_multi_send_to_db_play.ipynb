# %%
# %%time

import polars as pl

FP = "/home/ubuntu/multi.parquet"
lazy_df = pl.scan_parquet(FP)
real_df = pl.read_parquet(FP)
real_df
# Out:
# CPU times: user 22.6 s, sys: 25.7 s, total: 48.2 s
# Wall time: 8.03 s
# shape: (24048154, 24)
# ┌────────────┬────────────┬────────────┬────────────┬─────┬──────┬─────┬───────┬───────────────────┐
# │ message_ti ┆ message_so ┆ message_de ┆ message_pr ┆ ... ┆ hmci ┆ mes ┆ trial ┆ exp_id            │
# │ mestamp    ┆ urce       ┆ stination  ┆ otocol     ┆     ┆ ---  ┆ sag ┆ ---   ┆ ---               │
# │ ---        ┆ ---        ┆ ---        ┆ ---        ┆     ┆ i32  ┆ e_i ┆ i32   ┆ str               │
# │ f64        ┆ i64        ┆ i64        ┆ str        ┆     ┆      ┆ d   ┆       ┆                   │
# │            ┆            ┆            ┆            ┆     ┆      ┆ --- ┆       ┆                   │
# │            ┆            ┆            ┆            ┆     ┆      ┆ i32 ┆       ┆                   │
# ╞════════════╪════════════╪════════════╪════════════╪═════╪══════╪═════╪═══════╪═══════════════════╡
# │ 0.0        ┆ 2          ┆ 6          ┆ coap       ┆ ... ┆ -1   ┆ -1  ┆ 1     ┆ multiclient_cloud │
# │            ┆            ┆            ┆            ┆     ┆      ┆     ┆       ┆ _500mbps_attack.. │
# │            ┆            ┆            ┆            ┆     ┆      ┆     ┆       ┆ .                 │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 0.031749   ┆ 2          ┆ 6          ┆ coap       ┆ ... ┆ -1   ┆ -1  ┆ 1     ┆ multiclient_cloud │
# │            ┆            ┆            ┆            ┆     ┆      ┆     ┆       ┆ _500mbps_attack.. │
# │            ┆            ┆            ┆            ┆     ┆      ┆     ┆       ┆ .                 │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 0.105559   ┆ 6          ┆ 5          ┆ http       ┆ ... ┆ -1   ┆ -1  ┆ 1     ┆ multiclient_cloud │
# │            ┆            ┆            ┆            ┆     ┆      ┆     ┆       ┆ _500mbps_attack.. │
# │            ┆            ┆            ┆            ┆     ┆      ┆     ┆       ┆ .                 │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 0.111334   ┆ 5          ┆ 6          ┆ http       ┆ ... ┆ -1   ┆ -1  ┆ 1     ┆ multiclient_cloud │
# │            ┆            ┆            ┆            ┆     ┆      ┆     ┆       ┆ _500mbps_attack.. │
# │            ┆            ┆            ┆            ┆     ┆      ┆     ┆       ┆ .                 │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ ...        ┆ ...        ┆ ...        ┆ ...        ┆ ... ┆ ...  ┆ ... ┆ ...   ┆ ...               │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 102.890745 ┆ 6          ┆ 5          ┆ http       ┆ ... ┆ -1   ┆ -1  ┆ 3     ┆ multiclient_cloud │
# │            ┆            ┆            ┆            ┆     ┆      ┆     ┆       ┆ _500mbps_attack.. │
# │            ┆            ┆            ┆            ┆     ┆      ┆     ┆       ┆ .                 │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 102.896195 ┆ 5          ┆ 6          ┆ http       ┆ ... ┆ -1   ┆ -1  ┆ 3     ┆ multiclient_cloud │
# │            ┆            ┆            ┆            ┆     ┆      ┆     ┆       ┆ _500mbps_attack.. │
# │            ┆            ┆            ┆            ┆     ┆      ┆     ┆       ┆ .                 │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 102.8992   ┆ 5          ┆ 6          ┆ http       ┆ ... ┆ -1   ┆ -1  ┆ 3     ┆ multiclient_cloud │
# │            ┆            ┆            ┆            ┆     ┆      ┆     ┆       ┆ _500mbps_attack.. │
# │            ┆            ┆            ┆            ┆     ┆      ┆     ┆       ┆ .                 │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 102.899589 ┆ 6          ┆ 4          ┆ coap       ┆ ... ┆ -1   ┆ -1  ┆ 3     ┆ multiclient_cloud │
# │            ┆            ┆            ┆            ┆     ┆      ┆     ┆       ┆ _500mbps_attack.. │
# │            ┆            ┆            ┆            ┆     ┆      ┆     ┆       ┆ .                 │
# └────────────┴────────────┴────────────┴────────────┴─────┴──────┴─────┴───────┴───────────────────┘

# %%
database_coap_fields            = ["coap_type", "coap_code", "coap_retransmitted"]
database_http_fields            = ["http_request", "http_request_method", "http_response_code"]
database_message_pattern_fields = ["message_protocol", "message_size", "message_source", "message_destination"]

# %%
# %%time

coap_protocol_df = (
  real_df
  .select(database_coap_fields)
  .unique()
  .drop_nulls()
)

http_protocol_df = (
  real_df
  .select(database_http_fields)
  .unique()
)

protocols_df = (
  real_df
  .select(["message_protocol"] + database_coap_fields + database_http_fields)
  .unique()
)

message_patterns_df = (
  real_df
  .select(database_message_pattern_fields + database_coap_fields + database_http_fields)
  .unique()
)

message_patterns_df
# Out:
# CPU times: user 1min 6s, sys: 1.59 s, total: 1min 7s
# Wall time: 20.6 s
# shape: (109, 10)
# ┌────────────┬────────────┬────────────┬────────────┬─────┬────────────┬────────────┬────────────┬────────────┐
# │ message_pr ┆ message_si ┆ message_so ┆ message_de ┆ ... ┆ coap_retra ┆ http_reque ┆ http_reque ┆ http_respo │
# │ otocol     ┆ ze         ┆ urce       ┆ stination  ┆     ┆ nsmitted   ┆ st         ┆ st_method  ┆ nse_code   │
# │ ---        ┆ ---        ┆ ---        ┆ ---        ┆     ┆ ---        ┆ ---        ┆ ---        ┆ ---        │
# │ str        ┆ i64        ┆ i64        ┆ i64        ┆     ┆ bool       ┆ bool       ┆ str        ┆ i64        │
# ╞════════════╪════════════╪════════════╪════════════╪═════╪════════════╪════════════╪════════════╪════════════╡
# │ coap       ┆ 104        ┆ 2          ┆ 6          ┆ ... ┆ false      ┆ null       ┆ null       ┆ null       │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ http       ┆ 202        ┆ 6          ┆ 5          ┆ ... ┆ null       ┆ true       ┆ get        ┆ null       │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ http       ┆ 462        ┆ 5          ┆ 6          ┆ ... ┆ null       ┆ false      ┆ null       ┆ 200        │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ coap       ┆ 158        ┆ 6          ┆ 2          ┆ ... ┆ false      ┆ null       ┆ null       ┆ null       │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ ...        ┆ ...        ┆ ...        ┆ ...        ┆ ... ┆ ...        ┆ ...        ┆ ...        ┆ ...        │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ coap       ┆ 146        ┆ 2          ┆ 6          ┆ ... ┆ true       ┆ null       ┆ null       ┆ null       │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ coap       ┆ 147        ┆ 1          ┆ 6          ┆ ... ┆ true       ┆ null       ┆ null       ┆ null       │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ coap       ┆ 146        ┆ 4          ┆ 6          ┆ ... ┆ true       ┆ null       ┆ null       ┆ null       │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ coap       ┆ 148        ┆ 1          ┆ 6          ┆ ... ┆ true       ┆ null       ┆ null       ┆ null       │
# └────────────┴────────────┴────────────┴────────────┴─────┴────────────┴────────────┴────────────┴────────────┘

# %%
coap_protocol_df
# Out:
# shape: (5, 3)
# ┌───────────┬─────────────┬────────────────────┐
# │ coap_type ┆ coap_code   ┆ coap_retransmitted │
# │ ---       ┆ ---         ┆ ---                │
# │ str       ┆ str         ┆ bool               │
# ╞═══════════╪═════════════╪════════════════════╡
# │ con       ┆ get         ┆ false              │
# ├╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ ack       ┆ content     ┆ false              │
# ├╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ con       ┆ get         ┆ true               │
# ├╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ ack       ┆ content     ┆ true               │
# ├╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ ack       ┆ bad_gateway ┆ false              │
# └───────────┴─────────────┴────────────────────┘

# %%
# Drop all-null rows
http_protocol_df = http_protocol_df.filter(
    ~pl.fold(
        acc=True,
        f=lambda acc, s: acc & s.is_null(),
        exprs=pl.all(),
    )
)

http_protocol_df
# Out:
# shape: (2, 3)
# ┌──────────────┬─────────────────────┬────────────────────┐
# │ http_request ┆ http_request_method ┆ http_response_code │
# │ ---          ┆ ---                 ┆ ---                │
# │ bool         ┆ str                 ┆ i64                │
# ╞══════════════╪═════════════════════╪════════════════════╡
# │ true         ┆ get                 ┆ null               │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ false        ┆ null                ┆ 200                │
# └──────────────┴─────────────────────┴────────────────────┘

# %%
# %%time

# print(f"{len(protocols_df)}")
# print(f"{len(coap_protocol_df)}")
# print(f"{len(http_protocol_df)}")

assert len(protocols_df) == len(http_protocol_df) + len(coap_protocol_df)

unique_coap_df = (
  protocols_df
  .filter(pl.col("message_protocol") == "coap")
  .select(["coap_type", "coap_code", "coap_retransmitted"])
  .unique()
)

unique_http_df = (
  protocols_df
  .filter(pl.col("message_protocol") == "http")
  .select(["http_request", "http_request_method", "http_response_code"])
  .unique()
)

mp_coap_df = (
  message_patterns_df
  .filter(pl.col("message_protocol") == "coap")
  .select(database_coap_fields)
  .unique()
)

mp_http_df = (
  message_patterns_df
  .filter(pl.col("message_protocol") == "http")
  .select(database_http_fields)
  .unique()
)

assert unique_coap_df.frame_equal(coap_protocol_df)
assert mp_coap_df.frame_equal(coap_protocol_df)

assert unique_http_df.frame_equal(http_protocol_df)
assert mp_http_df.frame_equal(http_protocol_df)
# Out:
# CPU times: user 105 ms, sys: 14.9 ms, total: 120 ms
# Wall time: 13.8 ms

# %%
# %%time

(
  unique_http_df
  .with_columns([
    pl.when(pl.col("http_request") == True)
      .then(pl.lit(-1).alias("http_response_code"))
      .otherwise(pl.col("http_response_code").alias("http_response_code"))
    ,
    pl.when(pl.col("http_request") == False)
      .then(pl.lit("").alias("http_request_method"))
      .otherwise(pl.col("http_request_method").alias("http_request_method"))
  ])
)
# Out:
# CPU times: user 3.46 ms, sys: 1.06 ms, total: 4.52 ms
# Wall time: 1.03 ms
# shape: (2, 3)
# ┌──────────────┬─────────────────────┬────────────────────┐
# │ http_request ┆ http_request_method ┆ http_response_code │
# │ ---          ┆ ---                 ┆ ---                │
# │ bool         ┆ str                 ┆ i64                │
# ╞══════════════╪═════════════════════╪════════════════════╡
# │ true         ┆ get                 ┆ -1                 │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ false        ┆                     ┆ 200                │
# └──────────────┴─────────────────────┴────────────────────┘

# %%
import polars as pl

mpdf = pl.read_parquet("/home/ubuntu/message_patterns_df.parquet")

mpdf_missing_message_id = mpdf.filter(pl.col("message_id") < 0)

print(f"{len(mpdf)=}")
print(f"{len(mpdf_missing_message_id)=}")

mpdf

# %%
assert len(mpdf.filter(pl.col("message_id") < 0)) == 0

# %%
event_df = pl.read_parquet("/home/ubuntu/event_df.parquet")
event_df

# %%
without_message_id = event_df.filter(pl.col("message_id") < 0)
print(f"{len(event_df)=}")
print(f"{len(without_message_id)=}")

# %%
import pandas as pd
import polars as pl

database_experiment_fields      = ["exp_id", "attacker_rate", "server_connections", "max_keep_alive_requests", 
                                   "num_clients", "num_trials", "origin_server_duration", "attacker_duration", 
                                   "receiver_duration", "proxy_duration", "client_duration", "attacker_start_lag_duration", 
                                   "topology_name", "num_proxy_connections", "request_timeout", "max_retries", 
                                   "keep_alive_duration", "request_retry_interval", "reuse_connections", 
                                   "run_proxy_with_dtls", "run_proxy_with_https", "run_attacker"]

confdf = pd.read_json("/home/ubuntu/expname_map_config.json", orient="index").reset_index().drop(columns=["index"])
confdf.rename(columns={"expname": "exp_id"}, inplace=True)
confdf = pl.from_pandas(confdf)

valid_fields = [f for f in database_experiment_fields if f in confdf.columns]

confdf = confdf.select(valid_fields)

confdf
# Out:
# shape: (9, 21)
# ┌───┬────────────┬────────────┬───────────┬─────┬────────────┬────────────┬────────────┬────────────┐
# │ e ┆ server_con ┆ max_keep_a ┆ num_clien ┆ ... ┆ reuse_conn ┆ run_proxy_ ┆ run_proxy_ ┆ run_attack │
# │ x ┆ nections   ┆ live_reque ┆ ts        ┆     ┆ ections    ┆ with_dtls  ┆ with_https ┆ er         │
# │ p ┆ ---        ┆ sts        ┆ ---       ┆     ┆ ---        ┆ ---        ┆ ---        ┆ ---        │
# │ _ ┆ i64        ┆ ---        ┆ i64       ┆     ┆ str        ┆ i64        ┆ i64        ┆ i64        │
# │ i ┆            ┆ i64        ┆           ┆     ┆            ┆            ┆            ┆            │
# │ d ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ - ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ - ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ - ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ s ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ t ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ r ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# ╞═══╪════════════╪════════════╪═══════════╪═════╪════════════╪════════════╪════════════╪════════════╡
# │ m ┆ 256        ┆ 0          ┆ 3         ┆ ... ┆ true       ┆ 0          ┆ 0          ┆ 0          │
# │ u ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ l ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ t ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ i ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ c ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ l ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ i ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ e ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ n ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ t ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ _ ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ c ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ l ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ o ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ u ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ d ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ _ ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ 5 ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ 0 ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ 0 ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ m ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ b ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ p ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ s ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ _ ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ a ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ t ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ t ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ a ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ c ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ k ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ . ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ . ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ . ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# ├╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ m ┆ 256        ┆ 0          ┆ 3         ┆ ... ┆ true       ┆ 1          ┆ 0          ┆ 0          │
# │ u ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ l ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ t ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ i ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ c ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ l ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ i ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ e ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ n ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ t ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ _ ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ c ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ l ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ o ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ u ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ d ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ _ ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ 5 ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ 0 ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ 0 ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ m ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ b ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ p ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ s ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ _ ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ a ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ t ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ t ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ a ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ c ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ k ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ . ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ . ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ . ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# ├╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ m ┆ 256        ┆ 0          ┆ 3         ┆ ... ┆ true       ┆ 1          ┆ 1          ┆ 0          │
# │ u ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ l ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ t ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ i ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ c ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ l ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ i ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ e ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ n ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ t ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ _ ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ c ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ l ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ o ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ u ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ d ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ _ ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ 5 ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ 0 ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ 0 ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ m ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ b ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ p ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ s ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ _ ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ a ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ t ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ t ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ a ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ c ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ k ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ . ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ . ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ . ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# ├╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ m ┆ 256        ┆ 0          ┆ 3         ┆ ... ┆ true       ┆ 0          ┆ 1          ┆ 0          │
# │ u ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ l ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ t ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ i ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ c ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ l ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ i ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ e ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ n ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ t ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ _ ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ c ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ l ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ o ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ u ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ d ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ _ ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ 5 ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ 0 ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ 0 ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ m ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ b ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ p ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ s ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ _ ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ a ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ t ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ t ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ a ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ c ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ k ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ . ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ . ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ . ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# ├╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ . ┆ ...        ┆ ...        ┆ ...       ┆ ... ┆ ...        ┆ ...        ┆ ...        ┆ ...        │
# │ . ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ . ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# ├╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ m ┆ 256        ┆ 0          ┆ 3         ┆ ... ┆ true       ┆ 1          ┆ 0          ┆ 1          │
# │ u ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ l ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ t ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ i ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ c ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ l ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ i ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ e ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ n ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ t ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ _ ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ c ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ l ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ o ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ u ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ d ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ _ ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ 5 ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ 0 ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ 0 ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ m ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ b ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ p ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ s ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ _ ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ a ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ t ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ t ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ a ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ c ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ k ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ . ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ . ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ . ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# ├╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ m ┆ 256        ┆ 0          ┆ 3         ┆ ... ┆ true       ┆ 0          ┆ 1          ┆ 1          │
# │ u ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ l ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ t ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ i ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ c ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ l ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ i ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ e ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ n ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ t ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ _ ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ c ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ l ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ o ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ u ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ d ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ _ ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ 5 ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ 0 ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ 0 ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ m ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ b ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ p ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ s ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ _ ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ a ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ t ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ t ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ a ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ c ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ k ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ . ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ . ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ . ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# ├╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ m ┆ 256        ┆ 0          ┆ 3         ┆ ... ┆ true       ┆ 1          ┆ 1          ┆ 1          │
# │ u ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ l ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ t ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ i ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ c ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ l ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ i ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ e ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ n ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ t ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ _ ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ c ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ l ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ o ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ u ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ d ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ _ ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ 5 ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ 0 ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ 0 ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ m ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ b ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ p ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ s ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ _ ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ a ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ t ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ t ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ a ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ c ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ k ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ . ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ . ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ . ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# ├╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ m ┆ 256        ┆ 0          ┆ 3         ┆ ... ┆ true       ┆ 0          ┆ 1          ┆ 1          │
# │ u ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ l ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ t ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ i ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ c ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ l ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ i ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ e ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ n ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ t ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ _ ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ c ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ l ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ o ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ u ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ d ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ _ ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ 5 ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ 0 ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ 0 ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ m ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ b ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ p ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ s ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ _ ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ a ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ t ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ t ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ a ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ c ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ k ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ . ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ . ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# │ . ┆            ┆            ┆           ┆     ┆            ┆            ┆            ┆            │
# └───┴────────────┴────────────┴───────────┴─────┴────────────┴────────────┴────────────┴────────────┘

# %%
import json
with open("/home/ubuntu/expname_map_config.json", "r")as f:
  d = json.load(f)

# pandas_configuration_df = (
#   pd.DataFrame.from_dict(d, orient="index")
#   .reset_index()
#   .drop(columns=["index"])
#   .rename(columns={
#     "expname": "exp_id",
#     "attack_rate": "attacker_rate",
#   })
#   .replace({
#     "reuse_connections": {"true": True, "false": False},
#     "run_proxy_with_dtls": {"1": True, "0": False},
#     "run_proxy_with_https": {"1": True, "0": False},
#     "run_attacker": {"1": True, "0": False},
#   })
# )

# configuration_df = (
#   pl.from_pandas(pandas_configuration_df)
#   .select(database_experiment_fields)
# )

# configuration_df

pl.LazyFrame.read_json
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [4], in <cell line: 28>()
#       3   d = json.load(f)
#       5 # pandas_configuration_df = (
#       6 #   pd.DataFrame.from_dict(d, orient="index")
#       7 #   .reset_index()
#    (...)
#      25
#      26 # configuration_df
# ---> 28 pl.LazyFrame.read_json
#
# AttributeError: type object 'LazyFrame' has no attribute 'read_json'

# %%
database_experiment_field_map_pl_type = {
  "exp_id"                     : pl.datatypes.Utf8,
  "attacker_rate"              : pl.datatypes.Utf8,
  "server_connections"         : pl.datatypes.Int64,
  "max_keep_alive_requests"    : pl.datatypes.Int64,
  "num_clients"                : pl.datatypes.Int64,
  "num_trials"                 : pl.datatypes.Int64,
  "origin_server_duration"     : pl.datatypes.Int64,
  "attacker_duration"          : pl.datatypes.Int64,
  "receiver_duration"          : pl.datatypes.Int64,
  "proxy_duration"             : pl.datatypes.Int64,
  "client_duration"            : pl.datatypes.Int64,
  "attacker_start_lag_duration": pl.datatypes.Int64,
  "topology_name"              : pl.datatypes.Utf8,
  "num_proxy_connections"      : pl.datatypes.Int64,
  "request_timeout"            : pl.datatypes.Utf8,
  "max_retries"                : pl.datatypes.Int64,
  "keep_alive_duration"        : pl.datatypes.Utf8,
  "request_retry_interval"     : pl.datatypes.Utf8,
  "reuse_connections"          : pl.datatypes.Boolean,
  "run_proxy_with_dtls"        : pl.datatypes.Boolean,
  "run_proxy_with_https"       : pl.datatypes.Boolean,
  "run_attacker"               : pl.datatypes.Boolean,
}

def _cast_cols_from_type_map(type_map):
  """
  Query to cast all columns specified in the `type_map`
  to their specified type, without creating extra columns.
  """
  return [pl.col(col).cast(col_t).alias(col) for col, col_t in type_map.items()]

cast_configuration_fields = _cast_cols_from_type_map(database_experiment_field_map_pl_type)

configuration_df.with_columns(cast_configuration_fields)
# Out:
# shape: (9, 22)
# ┌───┬────────────┬────────────┬────────────┬─────┬────────────┬────────────┬────────────┬────────────┐
# │ e ┆ attacker_r ┆ server_con ┆ max_keep_a ┆ ... ┆ reuse_conn ┆ run_proxy_ ┆ run_proxy_ ┆ run_attack │
# │ x ┆ ate        ┆ nections   ┆ live_reque ┆     ┆ ections    ┆ with_dtls  ┆ with_https ┆ er         │
# │ p ┆ ---        ┆ ---        ┆ sts        ┆     ┆ ---        ┆ ---        ┆ ---        ┆ ---        │
# │ _ ┆ str        ┆ i64        ┆ ---        ┆     ┆ bool       ┆ bool       ┆ bool       ┆ bool       │
# │ i ┆            ┆            ┆ i64        ┆     ┆            ┆            ┆            ┆            │
# │ d ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ - ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ - ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ - ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ s ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ t ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ r ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# ╞═══╪════════════╪════════════╪════════════╪═════╪════════════╪════════════╪════════════╪════════════╡
# │ m ┆ 0mbps      ┆ 256        ┆ 0          ┆ ... ┆ true       ┆ false      ┆ false      ┆ false      │
# │ u ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ l ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ t ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ i ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ c ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ l ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ i ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ e ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ n ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ t ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ _ ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ c ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ l ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ o ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ u ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ d ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ _ ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ 5 ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ 0 ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ 0 ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ m ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ b ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ p ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ s ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ _ ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ a ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ t ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ t ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ a ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ c ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ k ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ . ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ . ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ . ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# ├╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ m ┆ 0mbps      ┆ 256        ┆ 0          ┆ ... ┆ true       ┆ true       ┆ false      ┆ false      │
# │ u ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ l ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ t ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ i ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ c ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ l ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ i ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ e ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ n ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ t ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ _ ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ c ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ l ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ o ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ u ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ d ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ _ ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ 5 ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ 0 ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ 0 ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ m ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ b ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ p ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ s ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ _ ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ a ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ t ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ t ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ a ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ c ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ k ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ . ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ . ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ . ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# ├╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ m ┆ 0mbps      ┆ 256        ┆ 0          ┆ ... ┆ true       ┆ true       ┆ true       ┆ false      │
# │ u ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ l ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ t ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ i ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ c ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ l ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ i ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ e ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ n ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ t ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ _ ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ c ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ l ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ o ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ u ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ d ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ _ ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ 5 ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ 0 ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ 0 ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ m ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ b ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ p ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ s ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ _ ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ a ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ t ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ t ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ a ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ c ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ k ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ . ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ . ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ . ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# ├╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ m ┆ 0mbps      ┆ 256        ┆ 0          ┆ ... ┆ true       ┆ false      ┆ true       ┆ false      │
# │ u ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ l ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ t ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ i ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ c ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ l ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ i ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ e ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ n ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ t ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ _ ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ c ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ l ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ o ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ u ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ d ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ _ ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ 5 ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ 0 ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ 0 ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ m ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ b ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ p ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ s ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ _ ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ a ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ t ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ t ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ a ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ c ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ k ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ . ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ . ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ . ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# ├╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ . ┆ ...        ┆ ...        ┆ ...        ┆ ... ┆ ...        ┆ ...        ┆ ...        ┆ ...        │
# │ . ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ . ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# ├╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ m ┆ 500mbps    ┆ 256        ┆ 0          ┆ ... ┆ true       ┆ true       ┆ false      ┆ true       │
# │ u ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ l ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ t ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ i ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ c ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ l ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ i ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ e ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ n ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ t ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ _ ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ c ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ l ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ o ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ u ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ d ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ _ ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ 5 ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ 0 ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ 0 ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ m ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ b ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ p ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ s ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ _ ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ a ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ t ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ t ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ a ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ c ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ k ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ . ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ . ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ . ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# ├╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ m ┆ 500mbps    ┆ 256        ┆ 0          ┆ ... ┆ true       ┆ false      ┆ true       ┆ true       │
# │ u ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ l ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ t ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ i ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ c ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ l ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ i ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ e ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ n ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ t ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ _ ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ c ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ l ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ o ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ u ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ d ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ _ ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ 5 ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ 0 ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ 0 ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ m ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ b ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ p ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ s ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ _ ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ a ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ t ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ t ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ a ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ c ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ k ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ . ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ . ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ . ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# ├╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ m ┆ 500mbps    ┆ 256        ┆ 0          ┆ ... ┆ true       ┆ true       ┆ true       ┆ true       │
# │ u ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ l ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ t ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ i ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ c ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ l ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ i ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ e ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ n ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ t ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ _ ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ c ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ l ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ o ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ u ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ d ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ _ ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ 5 ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ 0 ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ 0 ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ m ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ b ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ p ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ s ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ _ ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ a ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ t ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ t ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ a ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ c ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ k ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ . ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ . ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ . ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# ├╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ m ┆ 500mbps    ┆ 256        ┆ 0          ┆ ... ┆ true       ┆ false      ┆ true       ┆ true       │
# │ u ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ l ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ t ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ i ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ c ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ l ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ i ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ e ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ n ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ t ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ _ ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ c ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ l ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ o ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ u ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ d ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ _ ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ 5 ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ 0 ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ 0 ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ m ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ b ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ p ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ s ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ _ ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ a ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ t ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ t ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ a ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ c ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ k ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ . ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ . ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ . ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# └───┴────────────┴────────────┴────────────┴─────┴────────────┴────────────┴────────────┴────────────┘

# %%
# %%time

dfdb = pl.read_parquet("/home/ubuntu/dfdb.parquet")
dfdb
# Out:
# shape: (24048154, 24)
# ┌────────────┬────────────┬────────────┬────────────┬─────┬──────┬─────┬───────┬───────────────────┐
# │ message_ti ┆ message_so ┆ message_de ┆ message_pr ┆ ... ┆ hmci ┆ mes ┆ trial ┆ exp_id            │
# │ mestamp    ┆ urce       ┆ stination  ┆ otocol     ┆     ┆ ---  ┆ sag ┆ ---   ┆ ---               │
# │ ---        ┆ ---        ┆ ---        ┆ ---        ┆     ┆ i32  ┆ e_i ┆ i32   ┆ str               │
# │ f64        ┆ i64        ┆ i64        ┆ str        ┆     ┆      ┆ d   ┆       ┆                   │
# │            ┆            ┆            ┆            ┆     ┆      ┆ --- ┆       ┆                   │
# │            ┆            ┆            ┆            ┆     ┆      ┆ i32 ┆       ┆                   │
# ╞════════════╪════════════╪════════════╪════════════╪═════╪══════╪═════╪═══════╪═══════════════════╡
# │ 0.0        ┆ 2          ┆ 6          ┆ coap       ┆ ... ┆ -1   ┆ -1  ┆ 1     ┆ multiclient_cloud │
# │            ┆            ┆            ┆            ┆     ┆      ┆     ┆       ┆ _500mbps_attack.. │
# │            ┆            ┆            ┆            ┆     ┆      ┆     ┆       ┆ .                 │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 0.031749   ┆ 2          ┆ 6          ┆ coap       ┆ ... ┆ -1   ┆ -1  ┆ 1     ┆ multiclient_cloud │
# │            ┆            ┆            ┆            ┆     ┆      ┆     ┆       ┆ _500mbps_attack.. │
# │            ┆            ┆            ┆            ┆     ┆      ┆     ┆       ┆ .                 │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 0.105559   ┆ 6          ┆ 5          ┆ http       ┆ ... ┆ -1   ┆ -1  ┆ 1     ┆ multiclient_cloud │
# │            ┆            ┆            ┆            ┆     ┆      ┆     ┆       ┆ _500mbps_attack.. │
# │            ┆            ┆            ┆            ┆     ┆      ┆     ┆       ┆ .                 │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 0.111334   ┆ 5          ┆ 6          ┆ http       ┆ ... ┆ -1   ┆ -1  ┆ 1     ┆ multiclient_cloud │
# │            ┆            ┆            ┆            ┆     ┆      ┆     ┆       ┆ _500mbps_attack.. │
# │            ┆            ┆            ┆            ┆     ┆      ┆     ┆       ┆ .                 │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ ...        ┆ ...        ┆ ...        ┆ ...        ┆ ... ┆ ...  ┆ ... ┆ ...   ┆ ...               │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 102.890745 ┆ 6          ┆ 5          ┆ http       ┆ ... ┆ -1   ┆ -1  ┆ 3     ┆ multiclient_cloud │
# │            ┆            ┆            ┆            ┆     ┆      ┆     ┆       ┆ _500mbps_attack.. │
# │            ┆            ┆            ┆            ┆     ┆      ┆     ┆       ┆ .                 │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 102.896195 ┆ 5          ┆ 6          ┆ http       ┆ ... ┆ -1   ┆ -1  ┆ 3     ┆ multiclient_cloud │
# │            ┆            ┆            ┆            ┆     ┆      ┆     ┆       ┆ _500mbps_attack.. │
# │            ┆            ┆            ┆            ┆     ┆      ┆     ┆       ┆ .                 │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 102.8992   ┆ 5          ┆ 6          ┆ http       ┆ ... ┆ -1   ┆ -1  ┆ 3     ┆ multiclient_cloud │
# │            ┆            ┆            ┆            ┆     ┆      ┆     ┆       ┆ _500mbps_attack.. │
# │            ┆            ┆            ┆            ┆     ┆      ┆     ┆       ┆ .                 │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 102.899589 ┆ 6          ┆ 4          ┆ coap       ┆ ... ┆ -1   ┆ -1  ┆ 3     ┆ multiclient_cloud │
# │            ┆            ┆            ┆            ┆     ┆      ┆     ┆       ┆ _500mbps_attack.. │
# │            ┆            ┆            ┆            ┆     ┆      ┆     ┆       ┆ .                 │
# └────────────┴────────────┴────────────┴────────────┴─────┴──────┴─────┴───────┴───────────────────┘

# %%
# %%time

jdf = dfdb.join(confdf, how="left", on="exp_id")
jdf
# Out:
# CPU times: user 9.87 s, sys: 31.1 s, total: 40.9 s
# Wall time: 3.54 s
# shape: (24048154, 44)
# ┌────────────┬────────────┬────────────┬────────────┬─────┬────────────┬────────────┬────────────┬────────────┐
# │ message_ti ┆ message_so ┆ message_de ┆ message_pr ┆ ... ┆ reuse_conn ┆ run_proxy_ ┆ run_proxy_ ┆ run_attack │
# │ mestamp    ┆ urce       ┆ stination  ┆ otocol     ┆     ┆ ections    ┆ with_dtls  ┆ with_https ┆ er         │
# │ ---        ┆ ---        ┆ ---        ┆ ---        ┆     ┆ ---        ┆ ---        ┆ ---        ┆ ---        │
# │ f64        ┆ i64        ┆ i64        ┆ str        ┆     ┆ str        ┆ i64        ┆ i64        ┆ i64        │
# ╞════════════╪════════════╪════════════╪════════════╪═════╪════════════╪════════════╪════════════╪════════════╡
# │ 0.0        ┆ 2          ┆ 6          ┆ coap       ┆ ... ┆ true       ┆ 0          ┆ 0          ┆ 0          │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 0.031749   ┆ 2          ┆ 6          ┆ coap       ┆ ... ┆ true       ┆ 0          ┆ 0          ┆ 0          │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 0.105559   ┆ 6          ┆ 5          ┆ http       ┆ ... ┆ true       ┆ 0          ┆ 0          ┆ 0          │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 0.111334   ┆ 5          ┆ 6          ┆ http       ┆ ... ┆ true       ┆ 0          ┆ 0          ┆ 0          │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ ...        ┆ ...        ┆ ...        ┆ ...        ┆ ... ┆ ...        ┆ ...        ┆ ...        ┆ ...        │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 102.890745 ┆ 6          ┆ 5          ┆ http       ┆ ... ┆ true       ┆ 0          ┆ 1          ┆ 1          │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 102.896195 ┆ 5          ┆ 6          ┆ http       ┆ ... ┆ true       ┆ 0          ┆ 1          ┆ 1          │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 102.8992   ┆ 5          ┆ 6          ┆ http       ┆ ... ┆ true       ┆ 0          ┆ 1          ┆ 1          │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 102.899589 ┆ 6          ┆ 4          ┆ coap       ┆ ... ┆ true       ┆ 0          ┆ 1          ┆ 1          │
# └────────────┴────────────┴────────────┴────────────┴─────┴────────────┴────────────┴────────────┴────────────┘

# %%
rtt_df = (
  jdf
  .groupby(["exp_id", "trial", "observer_id", "message_marker"])
)
rtt_df

# %%
import polars as pl
df = pl.read_parquet("/home/ubuntu/dbg_transform.parquet")
df
# Out:
# shape: (2197509, 19)
# ┌────────────┬────────────┬────────────┬────────────┬─────┬────────────┬────────────┬─────────┬────────────┐
# │ message_ti ┆ message_so ┆ message_de ┆ message_pr ┆ ... ┆ http_respo ┆ http_respo ┆ node_ty ┆ message_ma │
# │ mestamp    ┆ urce       ┆ stination  ┆ otocol     ┆     ┆ nse_code_d ┆ nse_for_ur ┆ pe      ┆ rker       │
# │ ---        ┆ ---        ┆ ---        ┆ ---        ┆     ┆ esc        ┆ i          ┆ ---     ┆ ---        │
# │ f64        ┆ str        ┆ str        ┆ str        ┆     ┆ ---        ┆ ---        ┆ str     ┆ i64        │
# │            ┆            ┆            ┆            ┆     ┆ str        ┆ str        ┆         ┆            │
# ╞════════════╪════════════╪════════════╪════════════╪═════╪════════════╪════════════╪═════════╪════════════╡
# │ 0.0        ┆ client1    ┆ proxy      ┆ coap       ┆ ... ┆ null       ┆ null       ┆ client1 ┆ 1          │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 0.023963   ┆ client1    ┆ proxy      ┆ coap       ┆ ... ┆ null       ┆ null       ┆ proxy   ┆ 1          │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 0.108539   ┆ proxy      ┆ originserv ┆ http       ┆ ... ┆ null       ┆ null       ┆ origins ┆ 1          │
# │            ┆            ┆ er         ┆            ┆     ┆            ┆            ┆ erver   ┆            │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 0.109196   ┆ proxy      ┆ originserv ┆ http       ┆ ... ┆ null       ┆ null       ┆ proxy   ┆ 1          │
# │            ┆            ┆ er         ┆            ┆     ┆            ┆            ┆         ┆            │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ ...        ┆ ...        ┆ ...        ┆ ...        ┆ ... ┆ ...        ┆ ...        ┆ ...     ┆ ...        │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 102.862721 ┆ proxy      ┆ originserv ┆ http       ┆ ... ┆ null       ┆ null       ┆ proxy   ┆ 523459     │
# │            ┆            ┆ er         ┆            ┆     ┆            ┆            ┆         ┆            │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 102.867232 ┆ originserv ┆ proxy      ┆ http       ┆ ... ┆ ok         ┆ http://10. ┆ origins ┆ 523459     │
# │            ┆ er         ┆            ┆            ┆     ┆            ┆ 1.1.1:80/1 ┆ erver   ┆            │
# │            ┆            ┆            ┆            ┆     ┆            ┆ 345_7fceda ┆         ┆            │
# │            ┆            ┆            ┆            ┆     ┆            ┆ 94...      ┆         ┆            │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 102.873542 ┆ originserv ┆ proxy      ┆ http       ┆ ... ┆ ok         ┆ http://10. ┆ proxy   ┆ 523459     │
# │            ┆ er         ┆            ┆            ┆     ┆            ┆ 1.1.1:80/1 ┆         ┆            │
# │            ┆            ┆            ┆            ┆     ┆            ┆ 345_7fceda ┆         ┆            │
# │            ┆            ┆            ┆            ┆     ┆            ┆ 94...      ┆         ┆            │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 102.873815 ┆ proxy      ┆ client3    ┆ coap       ┆ ... ┆ null       ┆ null       ┆ proxy   ┆ 523459     │
# └────────────┴────────────┴────────────┴────────────┴─────┴────────────┴────────────┴─────────┴────────────┘

# %%
ipv4_regex                    = r"^(?:(?:25[0-5]|2[0-4][0-9]|[01]?[0-9][0-9]?)\.){3}(?:25[0-5]|2[0-4][0-9]|[01]?[0-9][0-9]?)$"
df.get_column("node_type").str.contains(ipv4_regex).any()
# Out:
# False

# %%
import pandas as pd

df = (
  pd.read_json("/home/ubuntu/dump_times.json", orient="index")
  .reset_index()
  .rename(columns={"index": "exp_id"})
  [["exp_id", "attacker_dump.pcap", "client1_dump.pcap", "receiver_dump.pcap", "server_dump.pcap", "proxy_dump.pcap"]]
)

dumps = [c for c in df.columns if "_dump" in c]
for d in dumps:
  df["rescale_" + d] = round(100 * df[d] / df["proxy_dump.pcap"])
  
df["intensity"] = None
df.loc[df["proxy_dump.pcap"] > 200, "intensity"] = "high"
df.loc[(50 <= df["proxy_dump.pcap"]) & (df["proxy_dump.pcap"] <= 200), "intensity"] = "medium"
df.loc[(df["proxy_dump.pcap"] < 50), "intensity"] = "low"

df
# Out:
#                                                exp_id  attacker_dump.pcap  \
# 0   process_cloud_proxy_and_500mbpsattacker_withat...               174.0
# 1   process_cloud_proxy_and_500mbpsattacker_withat...               103.0
# 2   process_cloud_proxy_and_500mbpsattacker_withat...               101.0
# 3   process_cloud_proxy_and_500mbpsattacker_withat...               102.0
# 4       process_cloud_proxy_and_attacker_withattacker               177.0
# 5   process_cloud_proxy_and_attacker_withattacker_...               105.0
# 6   process_cloud_proxy_and_attacker_withattacker_...               105.0
# 7   process_cloud_proxy_and_attacker_withattacker_...               179.0
# 8         process_cloud_proxy_and_attacker_noattacker                 NaN
# 9   process_cloud_proxy_and_attacker_noattacker_dt...                 NaN
# 10  process_cloud_proxy_and_attacker_noattacker_ht...                 NaN
#
#     client1_dump.pcap  receiver_dump.pcap  server_dump.pcap  proxy_dump.pcap  \
# 0                  18                 135               134              218
# 1                  19                  17               114              154
# 2                  19                  17               121              153
# 3                  19                  17               122              157
# 4                  19                 138               133              217
# 5                  19                  17               114              154
# 6                  18                  16               124              158
# 7                  19                 134               138              217
# 8                  19                  17                20               21
# 9                  18                  17                21               23
# 10                 19                  17                21               24
#
#     rescale_attacker_dump.pcap  rescale_client1_dump.pcap  \
# 0                         80.0                        8.0
# 1                         67.0                       12.0
# 2                         66.0                       12.0
# 3                         65.0                       12.0
# 4                         82.0                        9.0
# 5                         68.0                       12.0
# 6                         66.0                       11.0
# 7                         82.0                        9.0
# 8                          NaN                       90.0
# 9                          NaN                       78.0
# 10                         NaN                       79.0
#
#     rescale_receiver_dump.pcap  rescale_server_dump.pcap  \
# 0                         62.0                      61.0
# 1                         11.0                      74.0
# 2                         11.0                      79.0
# 3                         11.0                      78.0
# 4                         64.0                      61.0
# 5                         11.0                      74.0
# 6                         10.0                      78.0
# 7                         62.0                      64.0
# 8                         81.0                      95.0
# 9                         74.0                      91.0
# 10                        71.0                      88.0
#
#     rescale_proxy_dump.pcap intensity
# 0                     100.0      high
# 1                     100.0    medium
# 2                     100.0    medium
# 3                     100.0    medium
# 4                     100.0      high
# 5                     100.0    medium
# 6                     100.0    medium
# 7                     100.0      high
# 8                     100.0       low
# 9                     100.0       low
# 10                    100.0       low

# %%
gdf = (
  df.groupby("intensity")
  .agg(
    avg_proxy_decode_time=("proxy_dump.pcap", "mean"),
    avg_server_decode_time=("server_dump.pcap", "mean"),
    avg_receiver_decode_time=("receiver_dump.pcap", "mean"),
    avg_client1_decode_time=("client1_dump.pcap", "mean"),
    avg_attacker_decode_time=("attacker_dump.pcap", "mean"),
  )
  .reset_index()
)

for c in set(gdf.columns) - {"intensity"}:
  gdf[c] = round(gdf[c])

gdf = gdf[["intensity", "avg_proxy_decode_time", "avg_server_decode_time", "avg_attacker_decode_time", "avg_receiver_decode_time", "avg_client1_decode_time"]]

gdf.to_csv("/home/ubuntu/dump_sizes.csv", index=None)

gdf
# Out:
#   intensity  avg_proxy_decode_time  avg_server_decode_time  \
# 0      high                  217.0                   135.0
# 1       low                   23.0                    21.0
# 2    medium                  155.0                   119.0
#
#    avg_attacker_decode_time  avg_receiver_decode_time  avg_client1_decode_time
# 0                     177.0                     136.0                     19.0
# 1                       NaN                      17.0                     19.0
# 2                     103.0                      17.0                     19.0

# %%
rdf = gdf.copy()

for c in set(rdf.columns) - {"intensity", "avg_proxy_decode_time"}:
  rdf[c] = 100 * rdf[c] / rdf["avg_proxy_decode_time"]
rdf["avg_proxy_decode_time"] = 100

rdf
# Out:
#   intensity  avg_proxy_decode_time  avg_server_decode_time  \
# 0      high                    100               62.211982
# 1       low                    100               91.304348
# 2    medium                    100               76.774194
#
#    avg_attacker_decode_time  avg_receiver_decode_time  avg_client1_decode_time
# 0                 81.566820                 62.672811                 8.755760
# 1                       NaN                 73.913043                82.608696
# 2                 66.451613                 10.967742                12.258065

# %%
# %%time

import polars as pl

F = "/home/ubuntu/dos-californium/deter/expdata/real/final/gigabit_attack_50sec_with_tcpdump/*/gigabit_attack_50sec_with_tcpdump.parquet"
N = 25
dfs = list()
for i in range(N):
  dfs.append(pl.scan_parquet(F))
df = pl.concat(dfs).collect()
df

# %%
1e-9 * df.estimated_size()
# Out:
# 3.5655345190000003

# %%
import polars as pl

F = "/home/ubuntu/gigabit_attack_*.csv"
df = pl.read_csv(F)
df
# Out:
# shape: (16, 6)
# ┌──────────────┬────────────────────┬────────┬────────┬─────────────┬──────────────────────────────┐
# │ node_type    ┆ metric_type        ┆ p95_me ┆ p99_me ┆ mean_metric ┆ exp_id                       │
# │ ---          ┆ ---                ┆ tric_v ┆ tric_v ┆ _value      ┆ ---                          │
# │ str          ┆ str                ┆ alue   ┆ alue   ┆ ---         ┆ str                          │
# │              ┆                    ┆ ---    ┆ ---    ┆ f64         ┆                              │
# │              ┆                    ┆ f64    ┆ f64    ┆             ┆                              │
# ╞══════════════╪════════════════════╪════════╪════════╪═════════════╪══════════════════════════════╡
# │ originserver ┆ cpu_utilization    ┆ 31.7   ┆ 34.304 ┆ 10.150222   ┆ gigabit_attack_100sec_with_t │
# │              ┆                    ┆        ┆        ┆             ┆ cpdu...                      │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ originserver ┆ memory_utilization ┆ 293.0  ┆ 296.66 ┆ 280.392451  ┆ gigabit_attack_100sec_with_t │
# │              ┆                    ┆        ┆        ┆             ┆ cpdu...                      │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ proxy        ┆ cpu_utilization    ┆ 59.905 ┆ 88.109 ┆ 20.410444   ┆ gigabit_attack_100sec_with_t │
# │              ┆                    ┆        ┆        ┆             ┆ cpdu...                      │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ proxy        ┆ memory_utilization ┆ 8729.0 ┆ 8738.0 ┆ 6429.429501 ┆ gigabit_attack_100sec_with_t │
# │              ┆                    ┆        ┆        ┆             ┆ cpdu...                      │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ ...          ┆ ...                ┆ ...    ┆ ...    ┆ ...         ┆ ...                          │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ originserver ┆ cpu_utilization    ┆ 27.705 ┆ 31.104 ┆ 5.430667    ┆ gigabit_attack_50sec_without │
# │              ┆                    ┆        ┆        ┆             ┆ _tcp...                      │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ originserver ┆ memory_utilization ┆ 270.0  ┆ 271.0  ┆ 264.135698  ┆ gigabit_attack_50sec_without │
# │              ┆                    ┆        ┆        ┆             ┆ _tcp...                      │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ proxy        ┆ cpu_utilization    ┆ 58.5   ┆ 88.112 ┆ 11.666222   ┆ gigabit_attack_50sec_without │
# │              ┆                    ┆        ┆        ┆             ┆ _tcp...                      │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ proxy        ┆ memory_utilization ┆ 8145.0 ┆ 8147.0 ┆ 6100.742346 ┆ gigabit_attack_50sec_without │
# │              ┆                    ┆        ┆        ┆             ┆ _tcp...                      │
# └──────────────┴────────────────────┴────────┴────────┴─────────────┴──────────────────────────────┘

# %%
tdf = df.with_columns([
  pl.when(pl.col("exp_id").str.contains("100"))
    .then(pl.lit(100).alias("attack_duration_sec"))
    .otherwise(pl.lit(50).alias("attack_duration_sec")),
  pl.when(pl.col("exp_id").str.contains("without"))
    .then(pl.lit(False).alias("run_tcpdump"))
    .otherwise(pl.lit(True).alias("run_tcpdump")),
])

tdf = tdf.with_columns([
  pl.when(pl.col("run_tcpdump") == False)
    .then((pl.col("p95_metric_value") * -1).alias("p95_metric_value"))
    .otherwise(pl.col("p95_metric_value").alias("p95_metric_value")),
    pl.when(pl.col("run_tcpdump") == False)
    .then((pl.col("p99_metric_value") * -1).alias("p99_metric_value"))
    .otherwise(pl.col("p99_metric_value").alias("p99_metric_value")),
    pl.when(pl.col("run_tcpdump") == False)
    .then((pl.col("mean_metric_value") * -1).alias("mean_metric_value"))
    .otherwise(pl.col("mean_metric_value").alias("mean_metric_value")),
])

tdf
# Out:
# shape: (16, 8)
# ┌───────────┬───────────┬────────────┬────────────┬────────────┬──────────┬────────────┬───────────┐
# │ node_type ┆ metric_ty ┆ p95_metric ┆ p99_metric ┆ mean_metri ┆ exp_id   ┆ attack_dur ┆ run_tcpdu │
# │ ---       ┆ pe        ┆ _value     ┆ _value     ┆ c_value    ┆ ---      ┆ ation_sec  ┆ mp        │
# │ str       ┆ ---       ┆ ---        ┆ ---        ┆ ---        ┆ str      ┆ ---        ┆ ---       │
# │           ┆ str       ┆ f64        ┆ f64        ┆ f64        ┆          ┆ i32        ┆ bool      │
# ╞═══════════╪═══════════╪════════════╪════════════╪════════════╪══════════╪════════════╪═══════════╡
# │ originser ┆ cpu_utili ┆ 31.7       ┆ 34.304     ┆ 10.150222  ┆ gigabit_ ┆ 100        ┆ true      │
# │ ver       ┆ zation    ┆            ┆            ┆            ┆ attack_1 ┆            ┆           │
# │           ┆           ┆            ┆            ┆            ┆ 00sec_wi ┆            ┆           │
# │           ┆           ┆            ┆            ┆            ┆ th_tcpdu ┆            ┆           │
# │           ┆           ┆            ┆            ┆            ┆ ...      ┆            ┆           │
# ├╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┤
# │ originser ┆ memory_ut ┆ 293.0      ┆ 296.66     ┆ 280.392451 ┆ gigabit_ ┆ 100        ┆ true      │
# │ ver       ┆ ilization ┆            ┆            ┆            ┆ attack_1 ┆            ┆           │
# │           ┆           ┆            ┆            ┆            ┆ 00sec_wi ┆            ┆           │
# │           ┆           ┆            ┆            ┆            ┆ th_tcpdu ┆            ┆           │
# │           ┆           ┆            ┆            ┆            ┆ ...      ┆            ┆           │
# ├╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┤
# │ proxy     ┆ cpu_utili ┆ 59.905     ┆ 88.109     ┆ 20.410444  ┆ gigabit_ ┆ 100        ┆ true      │
# │           ┆ zation    ┆            ┆            ┆            ┆ attack_1 ┆            ┆           │
# │           ┆           ┆            ┆            ┆            ┆ 00sec_wi ┆            ┆           │
# │           ┆           ┆            ┆            ┆            ┆ th_tcpdu ┆            ┆           │
# │           ┆           ┆            ┆            ┆            ┆ ...      ┆            ┆           │
# ├╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┤
# │ proxy     ┆ memory_ut ┆ 8729.0     ┆ 8738.0     ┆ 6429.42950 ┆ gigabit_ ┆ 100        ┆ true      │
# │           ┆ ilization ┆            ┆            ┆ 1          ┆ attack_1 ┆            ┆           │
# │           ┆           ┆            ┆            ┆            ┆ 00sec_wi ┆            ┆           │
# │           ┆           ┆            ┆            ┆            ┆ th_tcpdu ┆            ┆           │
# │           ┆           ┆            ┆            ┆            ┆ ...      ┆            ┆           │
# ├╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┤
# │ ...       ┆ ...       ┆ ...        ┆ ...        ┆ ...        ┆ ...      ┆ ...        ┆ ...       │
# ├╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┤
# │ originser ┆ cpu_utili ┆ -27.705    ┆ -31.104    ┆ -5.430667  ┆ gigabit_ ┆ 50         ┆ false     │
# │ ver       ┆ zation    ┆            ┆            ┆            ┆ attack_5 ┆            ┆           │
# │           ┆           ┆            ┆            ┆            ┆ 0sec_wit ┆            ┆           │
# │           ┆           ┆            ┆            ┆            ┆ hout_tcp ┆            ┆           │
# │           ┆           ┆            ┆            ┆            ┆ ...      ┆            ┆           │
# ├╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┤
# │ originser ┆ memory_ut ┆ -270.0     ┆ -271.0     ┆ -264.13569 ┆ gigabit_ ┆ 50         ┆ false     │
# │ ver       ┆ ilization ┆            ┆            ┆ 8          ┆ attack_5 ┆            ┆           │
# │           ┆           ┆            ┆            ┆            ┆ 0sec_wit ┆            ┆           │
# │           ┆           ┆            ┆            ┆            ┆ hout_tcp ┆            ┆           │
# │           ┆           ┆            ┆            ┆            ┆ ...      ┆            ┆           │
# ├╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┤
# │ proxy     ┆ cpu_utili ┆ -58.5      ┆ -88.112    ┆ -11.666222 ┆ gigabit_ ┆ 50         ┆ false     │
# │           ┆ zation    ┆            ┆            ┆            ┆ attack_5 ┆            ┆           │
# │           ┆           ┆            ┆            ┆            ┆ 0sec_wit ┆            ┆           │
# │           ┆           ┆            ┆            ┆            ┆ hout_tcp ┆            ┆           │
# │           ┆           ┆            ┆            ┆            ┆ ...      ┆            ┆           │
# ├╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┤
# │ proxy     ┆ memory_ut ┆ -8145.0    ┆ -8147.0    ┆ -6100.7423 ┆ gigabit_ ┆ 50         ┆ false     │
# │           ┆ ilization ┆            ┆            ┆ 46         ┆ attack_5 ┆            ┆           │
# │           ┆           ┆            ┆            ┆            ┆ 0sec_wit ┆            ┆           │
# │           ┆           ┆            ┆            ┆            ┆ hout_tcp ┆            ┆           │
# │           ┆           ┆            ┆            ┆            ┆ ...      ┆            ┆           │
# └───────────┴───────────┴────────────┴────────────┴────────────┴──────────┴────────────┴───────────┘

# %%
(
  tdf.groupby(by=["attack_duration_sec", "node_type", "metric_type"])
  .agg([
    pl.col("p95_metric_value").sum(),
    pl.col("p99_metric_value").sum(),
    pl.col("mean_metric_value").sum(),
  ])
  .sort(by=["attack_duration_sec", "node_type", "metric_type"])
)
# Out:
# shape: (8, 6)
# ┌─────┬──────────────┬────────────────────┬────────┬────────┬─────────────┐
# │ att ┆ node_type    ┆ metric_type        ┆ p95_me ┆ p99_me ┆ mean_metric │
# │ ack ┆ ---          ┆ ---                ┆ tric_v ┆ tric_v ┆ _value      │
# │ _du ┆ str          ┆ str                ┆ alue   ┆ alue   ┆ ---         │
# │ rat ┆              ┆                    ┆ ---    ┆ ---    ┆ f64         │
# │ ion ┆              ┆                    ┆ f64    ┆ f64    ┆             │
# │ _se ┆              ┆                    ┆        ┆        ┆             │
# │ c   ┆              ┆                    ┆        ┆        ┆             │
# │ --- ┆              ┆                    ┆        ┆        ┆             │
# │ i32 ┆              ┆                    ┆        ┆        ┆             │
# ╞═════╪══════════════╪════════════════════╪════════╪════════╪═════════════╡
# │ 50  ┆ originserver ┆ cpu_utilization    ┆ 0.7    ┆ 1.698  ┆ 0.187889    │
# ├╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 50  ┆ originserver ┆ memory_utilization ┆ 3.0    ┆ 3.0    ┆ 2.184055    │
# ├╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 50  ┆ proxy        ┆ cpu_utilization    ┆ 0.205  ┆ -0.902 ┆ -0.113444   │
# ├╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 50  ┆ proxy        ┆ memory_utilization ┆ -186.0 ┆ -187.0 ┆ -126.065662 │
# ├╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 100 ┆ originserver ┆ cpu_utilization    ┆ 2.695  ┆ 1.903  ┆ 0.657889    │
# ├╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 100 ┆ originserver ┆ memory_utilization ┆ 8.0    ┆ 11.66  ┆ 7.486514    │
# ├╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 100 ┆ proxy        ┆ cpu_utilization    ┆ -0.42  ┆ 0.901  ┆ -0.149444   │
# ├╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 100 ┆ proxy        ┆ memory_utilization ┆ -58.0  ┆ -50.0  ┆ -66.3859    │
# └─────┴──────────────┴────────────────────┴────────┴────────┴─────────────┘

# %%
import dateutil.parser as dp
import pandas as pd

F = "/home/ubuntu/dos-californium/deter/expdata/real/final/{}/{}/client1.log"

d = list()
def parse_client_log(F, expname, trial):
  with open(F) as f:
    for i, L in enumerate(f):
      if i == 0:
        continue

      L = L.replace("--", "")
      L = L.replace("d:", "d ")
      L = L.replace("v:", "v ")

      parts = L.split()
      parts = [f"{parts[0]} {parts[1]}", parts[2].lower(), int(parts[3])]
      parts[0] = dp.parse(parts[0]).timestamp()
      
      d.append({
        "exp_id": expname,
        "trial": trial,
        "timestamp": parts[0],
        "event": parts[1],
        "message_number": parts[2],
      })
    
exps = [
  "gigabit_attack_50sec_with_tcpdump",
  "gigabit_attack_50sec_without_tcpdump",
  "gigabit_attack_100sec_with_tcpdump",
  "gigabit_attack_100sec_without_tcpdump",

]
trials = list(range(1, 3 + 1))
for e in exps:
  for t in trials:
    parse_client_log(F.format(e, t), e, t)
    
df = pd.DataFrame.from_dict(d)

df.loc[df["event"] == "send", "timestamp"] *= -1

df
# Out:
#                                       exp_id  trial     timestamp event  \
# 0          gigabit_attack_50sec_with_tcpdump      1 -1.651699e+09  send
# 1          gigabit_attack_50sec_with_tcpdump      1  1.651699e+09  recv
# 2          gigabit_attack_50sec_with_tcpdump      1 -1.651699e+09  send
# 3          gigabit_attack_50sec_with_tcpdump      1  1.651699e+09  recv
# 4          gigabit_attack_50sec_with_tcpdump      1 -1.651699e+09  send
# ...                                      ...    ...           ...   ...
# 75083  gigabit_attack_100sec_without_tcpdump      3 -1.651702e+09  send
# 75084  gigabit_attack_100sec_without_tcpdump      3  1.651702e+09  recv
# 75085  gigabit_attack_100sec_without_tcpdump      3 -1.651702e+09  send
# 75086  gigabit_attack_100sec_without_tcpdump      3  1.651702e+09  recv
# 75087  gigabit_attack_100sec_without_tcpdump      3 -1.651702e+09  send
#
#        message_number
# 0                   1
# 1                   1
# 2                   2
# 3                   2
# 4                   3
# ...               ...
# 75083            2684
# 75084            2684
# 75085            2685
# 75086            2685
# 75087            2686
#
# [75088 rows x 5 columns]

# %%
tdf = (
  df.groupby(by=["exp_id", "trial", "message_number"])
  .agg(
    rtt_sec=("timestamp", "sum")
  )
  .reset_index()
)

tdf["rtt_ms"] = (1e3 * tdf["rtt_sec"]).astype(int)
tdf.drop(columns=["rtt_sec"], inplace=True)

tdf = tdf[tdf["rtt_ms"] > 0]

tdf.loc[tdf["exp_id"] == "gigabit_attack_50sec_with_tcpdump", "attack_duration"] = 50
tdf.loc[tdf["exp_id"] == "gigabit_attack_50sec_without_tcpdump", "attack_duration"] = 50
tdf.loc[tdf["exp_id"] == "gigabit_attack_100sec_with_tcpdump", "attack_duration"] = 100
tdf.loc[tdf["exp_id"] == "gigabit_attack_100sec_without_tcpdump", "attack_duration"] = 100

tdf.loc[tdf["exp_id"] == "gigabit_attack_50sec_with_tcpdump", "run_tcpdump"] = True
tdf.loc[tdf["exp_id"] == "gigabit_attack_50sec_without_tcpdump", "run_tcpdump"] = False
tdf.loc[tdf["exp_id"] == "gigabit_attack_100sec_with_tcpdump", "run_tcpdump"] = True
tdf.loc[tdf["exp_id"] == "gigabit_attack_100sec_without_tcpdump", "run_tcpdump"] = False

tdf
# Out:
#                                      exp_id  trial  message_number  rtt_ms  \
# 0        gigabit_attack_100sec_with_tcpdump      1               1     234
# 1        gigabit_attack_100sec_with_tcpdump      1               2      59
# 2        gigabit_attack_100sec_with_tcpdump      1               3      58
# 3        gigabit_attack_100sec_with_tcpdump      1               4      58
# 4        gigabit_attack_100sec_with_tcpdump      1               5      58
# ...                                     ...    ...             ...     ...
# 37544  gigabit_attack_50sec_without_tcpdump      3            3566      52
# 37545  gigabit_attack_50sec_without_tcpdump      3            3567      54
# 37546  gigabit_attack_50sec_without_tcpdump      3            3568      52
# 37547  gigabit_attack_50sec_without_tcpdump      3            3569      52
# 37548  gigabit_attack_50sec_without_tcpdump      3            3570      52
#
#        attack_duration run_tcpdump
# 0                100.0        True
# 1                100.0        True
# 2                100.0        True
# 3                100.0        True
# 4                100.0        True
# ...                ...         ...
# 37544             50.0       False
# 37545             50.0       False
# 37546             50.0       False
# 37547             50.0       False
# 37548             50.0       False
#
# [37538 rows x 6 columns]

# %%
xdf = (
  tdf.groupby(by=["exp_id", "trial"])
  .agg(
    num_messages=("message_number", "max"),
    avg_rtt_ms=("rtt_ms", "mean"),
    max_rtt_ms=("rtt_ms", "max"),
  )
  .reset_index()
)

xdf
# Out:
#                                    exp_id  trial  num_messages  avg_rtt_ms  \
# 0      gigabit_attack_100sec_with_tcpdump      1          2670   92.503745
# 1      gigabit_attack_100sec_with_tcpdump      2          2666   92.621905
# 2      gigabit_attack_100sec_with_tcpdump      3          2639   93.526715
# 3   gigabit_attack_100sec_without_tcpdump      1          2677   92.221143
# 4   gigabit_attack_100sec_without_tcpdump      2          2683   92.034663
# 5   gigabit_attack_100sec_without_tcpdump      3          2685   91.961266
# 6       gigabit_attack_50sec_with_tcpdump      1          3570   68.532493
# 7       gigabit_attack_50sec_with_tcpdump      2          3601   68.286865
# 8       gigabit_attack_50sec_with_tcpdump      3          3585   68.657741
# 9    gigabit_attack_50sec_without_tcpdump      1          3596   68.401557
# 10   gigabit_attack_50sec_without_tcpdump      2          3596   68.424917
# 11   gigabit_attack_50sec_without_tcpdump      3          3570   68.935574
#
#     max_rtt_ms
# 0         8002
# 1        13808
# 2        13286
# 3        13217
# 4         7832
# 5         7730
# 6         7904
# 7         5426
# 8        11976
# 9        19328
# 10        7230
# 11       13439

# %%
(
   tdf.groupby(by=["exp_id"])
  .agg(
    num_messages=("message_number", "max"),
    avg_rtt_ms=("rtt_ms", "mean"),
    std_rtt_ms=("rtt_ms", "std"),
    max_rtt_ms=("rtt_ms", "max"),
  )
)
# Out:
#                                        num_messages  avg_rtt_ms  std_rtt_ms  \
# exp_id
# gigabit_attack_100sec_with_tcpdump             2670   92.881755  480.376128
# gigabit_attack_100sec_without_tcpdump          2685   92.072219  463.823970
# gigabit_attack_50sec_with_tcpdump              3601   68.492004  308.319244
# gigabit_attack_50sec_without_tcpdump           3596   68.586508  336.788708
#
#                                        max_rtt_ms
# exp_id
# gigabit_attack_100sec_with_tcpdump          13808
# gigabit_attack_100sec_without_tcpdump       13217
# gigabit_attack_50sec_with_tcpdump           11976
# gigabit_attack_50sec_without_tcpdump        19328

# %%
(
   tdf.groupby(by=["attack_duration", "run_tcpdump"])
  .agg(
    num_messages=("message_number", "max"),
    avg_rtt_ms=("rtt_ms", "mean"),
    std_rtt_ms=("rtt_ms", "std"),
    max_rtt_ms=("rtt_ms", "max"),
  )
)
# Out:
#                              num_messages  avg_rtt_ms  std_rtt_ms  max_rtt_ms
# attack_duration run_tcpdump
# 50.0            False                3596   68.586508  336.788708       19328
#                 True                 3601   68.492004  308.319244       11976
# 100.0           False                2685   92.072219  463.823970       13217
#                 True                 2670   92.881755  480.376128       13808

# %%
import pandas as pd

regdf = pd.read_csv("/home/ubuntu/dos-californium/regdumps.csv")
regdf["zipped"] = False
zipdf = pd.read_csv("/home/ubuntu/dos-californium/zipdumps.csv")
zipdf["zipped"] = True

_df = pd.concat([regdf, zipdf])
_df
d = list()
for r in _df.to_dict(orient="records"):
  nr = {**r}
  parts = r["exp_id"].split("/")
  nr["exp_id"] = parts[0]
  nr["trial"] = parts[1]
  nr["dump"] = parts[2].replace("client1", "client").replace(".zip", "").replace(".pcap", "")
  d.append(nr)
  
df = pd.DataFrame.from_records(d)

gdf = (
  df
  .groupby(by=["exp_id", "trial", "dump"])
  .agg(
    unzipped_size=("size", "max"),
    zipped_size=("size", "min"),
  )
  .reset_index()
)
gdf["compression_ratio"] = gdf["unzipped_size"] / gdf["zipped_size"]

import polars as pl

cdf = pl.read_parquet("/home/ubuntu/cloudgroupe2e/configurations.parquet").to_pandas()
cdf = cdf[["exp_id", "attacker_rate", "run_proxy_with_dtls", "run_proxy_with_https", "run_attacker"]]


mdf = gdf.merge(cdf, on="exp_id")

mdf["dump_distribution"] = mdf["dump"]
mdf.dump_distribution.replace({
  "attacker_dump": "CoAP Dominant",
  "client_dump": "CoAP Dominant",
  "proxy_dump": "Mixed",
  "receiver_dump": "CoAP Dominant",
  "server_dump": "HTTP Dominant",
}, inplace=True)

mdf.rename(columns={
  "run_proxy_with_dtls": "dtls",
  "run_proxy_with_https": "https",
  "dump_distribution": "capture_distribution",
}, inplace=True)

mdf["encryption"] = ""
mdf.loc[(mdf["dtls"] == False) & (mdf["https"] == False), "encryption"] = "No Encryption"
mdf.loc[(mdf["dtls"] == False) & (mdf["https"] == True), "encryption"] = "HTTPS"
mdf.loc[(mdf["dtls"] == True) & (mdf["https"] == False), "encryption"] = "CoAPS"
mdf.loc[(mdf["dtls"] == True) & (mdf["https"] == True), "encryption"] = "CoAPS + HTTPS"

import seaborn as sns
import matplotlib.pyplot as plt

plt.rcParams['figure.dpi'] = 300
plt.rcParams['savefig.dpi'] = 300

g = sns.catplot(
  data=mdf,
  kind="bar",
  ci=None,
  x="encryption",
  y="compression_ratio",
  order=["No Encryption", "CoAPS", "HTTPS", "CoAPS + HTTPS"],
  hue="capture_distribution",
  hue_order=["CoAP Dominant", "HTTP Dominant", "Mixed"],
  legend_out=False,
  height=5,
  aspect=2,
)

plt.rcParams['font.size'] = '18'
plt.rcParams['lines.linewidth'] = 3
plt.rcParams['lines.markersize'] = 9

g.set(xlabel="Encryption Type", ylabel="Average Compression Ratio")
sns.move_legend(
  g, 
  "upper right", 
  title="Traffic Type", 
  frameon=True, 
  labelspacing=0.05,
  bbox_to_anchor=((1, 1)),
  markerfirst=True,
)
plt.show()

mdf
# Out:
#                                             exp_id trial           dump  \
# 0     cloud_proxy_and_500mbpsattacker_withattacker     1  attacker_dump
# 1     cloud_proxy_and_500mbpsattacker_withattacker     1    client_dump
# 2     cloud_proxy_and_500mbpsattacker_withattacker     1     proxy_dump
# 3     cloud_proxy_and_500mbpsattacker_withattacker     1  receiver_dump
# 4     cloud_proxy_and_500mbpsattacker_withattacker     1    server_dump
# ..                                             ...   ...            ...
# 163  cloud_proxy_and_attacker_withattacker_httpson     3  attacker_dump
# 164  cloud_proxy_and_attacker_withattacker_httpson     3    client_dump
# 165  cloud_proxy_and_attacker_withattacker_httpson     3     proxy_dump
# 166  cloud_proxy_and_attacker_withattacker_httpson     3  receiver_dump
# 167  cloud_proxy_and_attacker_withattacker_httpson     3    server_dump
#
#      unzipped_size  zipped_size  compression_ratio attacker_rate   dtls  \
# 0         61737825      9987428           6.181554       500mbps  False
# 1           399317        79561           5.019004       500mbps  False
# 2        156279922     23349749           6.693002       500mbps  False
# 3         37880006      7604858           4.981027       500mbps  False
# 4         59321304      5536648          10.714299       500mbps  False
# ..             ...          ...                ...           ...    ...
# 163       64031575     10189835           6.283868       100mbps  False
# 164         407977        80762           5.051596       100mbps  False
# 165      157809292     68367983           2.308234       100mbps  False
# 166       37315014      7615720           4.899736       100mbps  False
# 167       59199950     49505989           1.195814       100mbps  False
#
#      https  run_attacker capture_distribution     encryption
# 0    False          True        CoAP Dominant  No Encryption
# 1    False          True        CoAP Dominant  No Encryption
# 2    False          True                Mixed  No Encryption
# 3    False          True        CoAP Dominant  No Encryption
# 4    False          True        HTTP Dominant  No Encryption
# ..     ...           ...                  ...            ...
# 163   True          True        CoAP Dominant          HTTPS
# 164   True          True        CoAP Dominant          HTTPS
# 165   True          True                Mixed          HTTPS
# 166   True          True        CoAP Dominant          HTTPS
# 167   True          True        HTTP Dominant          HTTPS
#
# [168 rows x 12 columns]

# %%
d = list()
# with open("/home/ubuntu/dos-californium/decode_lines.txt", "r") as f:
with open("/home/ubuntu/dos-californium/redone_decode_lines.txt", "r") as f:
  for i, L in enumerate(f):
    L = L.rstrip().replace("\t", " ").replace("-real ", "/real/").replace(":real ", "/real/").replace(":", "/").replace("-", "/")
    parts = L.split("/")
    group_id = parts[0].replace("file_", "")
    exp_id = parts[1].replace("process_", "").replace(".log", "")
    if i % 2 == 0:
      dump = parts[-1].replace("client1", "client").replace("_dump.pcap", "").title()
      d.append({
        "group_id": group_id,
        "exp_id": exp_id,
        "capture": dump,
        "decode_time_sec": None
      })
    else:
      s = parts[-1]
      mins = int(s[:s.index("m")])
      secs = float(s[s.index("m")+1:-1])
      time = mins*60 + secs
      d[-1]["decode_time_sec"] = time

df = pd.DataFrame.from_dict(d)

volumes = [
  {"exp_id": "cloud_proxy_and_attacker_withattacker", "attack_volume": 250, "duration_sec": 20,},
  {"exp_id": "megabit300_attack_20sec_with_tcpdump", "attack_volume": 750, "duration_sec": 20,},
  {"exp_id": "megabit750_attack_20sec_with_tcpdump", "attack_volume": 1875, "duration_sec": 20,},
  {"exp_id": "gigabit_attack_20sec_with_tcpdump", "attack_volume": 2500, "duration_sec": 20,},
  {"exp_id": "gigabit_attack_35sec_with_tcpdump", "attack_volume": 4375, "duration_sec": 35,},
  {"exp_id": "gigabit_attack_50sec_with_tcpdump", "attack_volume": 6250, "duration_sec": 50,},
  {"exp_id": "gigabit_attack_75sec_with_tcpdump", "attack_volume": 9375, "duration_sec": 75,},
  {"exp_id": "gigabit_attack_100sec_with_tcpdump", "attack_volume": 12500, "duration_sec": 100,},
]
vdf = pd.DataFrame.from_records(volumes)

df = df.merge(vdf, on="exp_id")
df["capture"] = df["capture"].str.replace("_dump.pcap", "")
df["capture"] = df["capture"].str.replace("client1", "client")
df = df[df["exp_id"].str.startswith("gigabit_attack")]
df["capture"] = df["capture"].str.title()

gdf = (
  df
  .groupby(by=["exp_id", "attack_volume", "capture"])
  .agg(
    avg_decode_time=("decode_time_sec", "mean"),
    attack_duration_sec=("duration_sec", "max")
  )
  .sort_values(by="attack_volume")
  .reset_index()
)

g = sns.relplot(
  data=df,
  kind="line",
  ci="sd",
  err_style="bars",
  x="duration_sec",
  y="decode_time_sec",
  hue="capture",
  hue_order=[
    'Proxy',
    'Attacker',
    'Server',
    'Receiver',
    'Client',
  ],
  palette={
    'Proxy': "tab:red",
    'Attacker': "tab:purple",
    'Server': "tab:green",
    'Receiver': "tab:orange",
    'Client': "tab:blue",
  },
  marker='D',
  height=5,
  aspect=2,
  err_kws={
    "elinewidth": 2,
    "capthick": 2,
    "capsize": 15,
  }
)

g.set(xlabel="Attack Duraction in Seconds", ylabel="Capture Decode Time in Seconds")
sns.move_legend(
  g, 
  "upper left", 
  title="Device", 
  frameon=True, 
  labelspacing=0.05,
  bbox_to_anchor=(.125, .9),
  markerfirst=True,
)
plt.show()

gdf
# Out:
# /tmp/ipykernel_3177204/1328564367.py:39: FutureWarning: The default value of regex will change from True to False in a future version.
#   df["capture"] = df["capture"].str.replace("_dump.pcap", "")
#                                 exp_id  attack_volume   capture  \
# 0    gigabit_attack_20sec_with_tcpdump           2500  Receiver
# 1    gigabit_attack_20sec_with_tcpdump           2500  Attacker
# 2    gigabit_attack_20sec_with_tcpdump           2500    Client
# 3    gigabit_attack_20sec_with_tcpdump           2500     Proxy
# 4    gigabit_attack_20sec_with_tcpdump           2500    Server
# 5    gigabit_attack_35sec_with_tcpdump           4375    Server
# 6    gigabit_attack_35sec_with_tcpdump           4375  Receiver
# 7    gigabit_attack_35sec_with_tcpdump           4375    Client
# 8    gigabit_attack_35sec_with_tcpdump           4375  Attacker
# 9    gigabit_attack_35sec_with_tcpdump           4375     Proxy
# 10   gigabit_attack_50sec_with_tcpdump           6250    Server
# 11   gigabit_attack_50sec_with_tcpdump           6250  Receiver
# 12   gigabit_attack_50sec_with_tcpdump           6250  Attacker
# 13   gigabit_attack_50sec_with_tcpdump           6250    Client
# 14   gigabit_attack_50sec_with_tcpdump           6250     Proxy
# 15   gigabit_attack_75sec_with_tcpdump           9375  Attacker
# 16   gigabit_attack_75sec_with_tcpdump           9375    Client
# 17   gigabit_attack_75sec_with_tcpdump           9375     Proxy
# 18   gigabit_attack_75sec_with_tcpdump           9375    Server
# 19   gigabit_attack_75sec_with_tcpdump           9375  Receiver
# 20  gigabit_attack_100sec_with_tcpdump          12500    Server
# 21  gigabit_attack_100sec_with_tcpdump          12500  Receiver
# 22  gigabit_attack_100sec_with_tcpdump          12500     Proxy
# 23  gigabit_attack_100sec_with_tcpdump          12500    Client
# 24  gigabit_attack_100sec_with_tcpdump          12500  Attacker
#
#     avg_decode_time  attack_duration_sec
# 0         16.275000                   20
# 1         26.442000                   20
# 2          1.198333                   20
# 3         73.531000                   20
# 4         27.432667                   20
# 5         44.577000                   35
# 6         27.249000                   35
# 7          0.759000                   35
# 8         42.503333                   35
# 9        124.093000                   35
# 10        61.276000                   50
# 11        42.067667                   50
# 12        66.224667                   50
# 13         1.042667                   50
# 14       176.951333                   50
# 15        98.173667                   75
# 16         0.661333                   75
# 17       270.985667                   75
# 18        92.082333                   75
# 19        61.580000                   75
# 20       123.492667                  100
# 21        85.629667                  100
# 22       361.211333                  100
# 23         1.217000                  100
# 24       140.253333                  100

# %%
d = list()
with open("/home/ubuntu/dos-californium/gigabit_dump_sizes.txt", "r") as f:
  for L in f:
    parts = L.split()
    size_bytes = int(parts[0])
    dump_path = parts[1].replace("./", "")
    path_parts = dump_path.split("/")
    exp_id = path_parts[0]
    trial = int(path_parts[1])
    capture = path_parts[2].replace("client1", "client").replace("_dump.pcap", "").title()
    
    d.append({
      "size_bytes": size_bytes,
      "exp_id": exp_id,
      "trial": trial,
      "capture": capture,
    })

sdf = pd.DataFrame.from_records(d)
sdf = sdf.merge(df, on=["exp_id", "capture"])
sdf["megabytes_size"] = (1e-6 * sdf["size_bytes"])
sdf["decode_msec_per_capture_megabyte"] = (1e3 * sdf["decode_time_sec"]) / (1e-6 * sdf["size_bytes"])
sdf["decode_sec_per_capture_gigabyte"] = (1e0 * sdf["decode_time_sec"]) / (1e-9 * sdf["size_bytes"])

ax = sns.ecdfplot(
  data=sdf[sdf["capture"] != "Client"],
  x="decode_sec_per_capture_gigabyte",
  hue="capture",
)

ax.set_xlim([200, 700])
# ax.set_xticks(list(range(200, 1_100 + 1, 50)), rot=45)
ax.set_ylabel("CDF")
ax.set_xlabel("Decode Time in Seconds per Gigabyte of Capture")
ax.get_legend().set_title("Device")
plt.show()

(
  sdf.groupby(by="capture")
  .agg(
    max_decode_time_sec=("decode_time_sec", "max"),
    min_decode_time_sec=("decode_time_sec", "min"),
    max_decode_sec_per_capture_gigabyte=("decode_sec_per_capture_gigabyte", "max"),
    min_decode_sec_per_capture_gigabyte=("decode_sec_per_capture_gigabyte", "min"),
  )
)
# Out:
#           max_decode_time_sec  min_decode_time_sec  \
# capture
# Attacker              143.372               25.991
# Client                  1.345                0.568
# Proxy                 365.889               72.958
# Receiver               87.157               15.521
# Server                128.935               27.264
#
#           max_decode_sec_per_capture_gigabyte  \
# capture
# Attacker                           472.667890
# Client                            7138.680900
# Proxy                              371.234172
# Receiver                           400.252541
# Server                             260.660324
#
#           min_decode_sec_per_capture_gigabyte
# capture
# Attacker                           385.297062
# Client                             839.279007
# Proxy                              326.549156
# Receiver                           335.441286
# Server                             224.660455

# %%
ax = sns.ecdfplot(
  data=sdf,
  x="megabytes_size",
  hue="capture",
)

# ax.set_xlim([200, 1_000])
# # ax.set_xticks(list(range(200, 1_100 + 1, 50)), rot=45)
# ax.set_ylabel("CDF")
# ax.set_xlabel("Decode Time in Seconds per Gigabyte of Capture")
# ax.get_legend().set_title("Device")

# %%
sdf[sdf["megabytes_size"] == sdf["megabytes_size"].max()]
# Out:
#     size_bytes                              exp_id  trial capture  \
# 24  1012987206  gigabit_attack_100sec_with_tcpdump      3   Proxy
# 25  1012987206  gigabit_attack_100sec_with_tcpdump      3   Proxy
# 26  1012987206  gigabit_attack_100sec_with_tcpdump      3   Proxy
#
#                                   group_id  decode_time_sec  attack_volume  \
# 24  no2_gigabit_attack_100sec_with_tcpdump          365.889          12500
# 25  no2_gigabit_attack_100sec_with_tcpdump          357.488          12500
# 26  no2_gigabit_attack_100sec_with_tcpdump          360.257          12500
#
#     duration_sec  megabytes_size  decode_msec_per_capture_megabyte  \
# 24           100     1012.987206                        361.198047
# 25           100     1012.987206                        352.904753
# 26           100     1012.987206                        355.638253
#
#     decode_sec_per_capture_gigabyte
# 24                       361.198047
# 25                       352.904753
# 26                       355.638253

# %%
sns.relplot(
  kind="line",
  data=sdf[sdf["capture"] != "Client"],
  x="megabytes_size",
  y="time",
  hue="capture",
)

sdf
# Out:
#      size_bytes                              exp_id  trial   capture     time  \
# 0     304852466  gigabit_attack_100sec_with_tcpdump      1  Attacker  179.576
# 1     304852466  gigabit_attack_100sec_with_tcpdump      1  Attacker  170.954
# 2     304852466  gigabit_attack_100sec_with_tcpdump      1  Attacker  183.502
# 3     303325026  gigabit_attack_100sec_with_tcpdump      2  Attacker  179.576
# 4     303325026  gigabit_attack_100sec_with_tcpdump      2  Attacker  170.954
# ..          ...                                 ...    ...       ...      ...
# 220   383281767   gigabit_attack_75sec_with_tcpdump      2    Server  126.772
# 221   383281767   gigabit_attack_75sec_with_tcpdump      2    Server  128.271
# 222   380770343   gigabit_attack_75sec_with_tcpdump      3    Server  127.328
# 223   380770343   gigabit_attack_75sec_with_tcpdump      3    Server  126.772
# 224   380770343   gigabit_attack_75sec_with_tcpdump      3    Server  128.271
#
#      attack_volume  duration_sec  megabytes_size  \
# 0            12500           100      304.852466
# 1            12500           100      304.852466
# 2            12500           100      304.852466
# 3            12500           100      303.325026
# 4            12500           100      303.325026
# ..             ...           ...             ...
# 220           9375            75      383.281767
# 221           9375            75      383.281767
# 222           9375            75      380.770343
# 223           9375            75      380.770343
# 224           9375            75      380.770343
#
#      decode_msec_per_capture_megabyte  decode_sec_per_capture_gigabyte
# 0                          589.058709                       589.058709
# 1                          560.776176                       560.776176
# 2                          601.937069                       601.937069
# 3                          592.025005                       592.025005
# 4                          563.600051                       563.600051
# ..                                ...                              ...
# 220                        330.754059                       330.754059
# 221                        334.665019                       334.665019
# 222                        334.395791                       334.395791
# 223                        332.935593                       332.935593
# 224                        336.872349                       336.872349
#
# [225 rows x 10 columns]

# %%
d = list()
with open("/home/ubuntu/dos-californium/cloudgroupdecodetimes.txt", "r") as f:
  for i, L in enumerate(f):
    L = L.rstrip().replace("\t", " ").replace("-real ", "/real/").replace(":real ", "/real/").replace(":", "/").replace("-", "/")
    parts = L.split("/")
    group_id = parts[0].replace("file_", "")
    exp_id = parts[1].replace("process_", "").replace(".log", "")
    if i % 2 == 0:
      dump = parts[-1].replace("client1", "client").replace("_dump.pcap", "").title()
      d.append({
        "group_id": group_id,
        "exp_id": exp_id,
        "capture": dump,
        "decode_time_sec": None
      })
    else:
      s = parts[-1]
      mins = int(s[:s.index("m")])
      secs = float(s[s.index("m")+1:-1])
      time = mins*60 + secs
      d[-1]["decode_time_sec"] = time

ddf = pd.DataFrame.from_records(d)

import polars as pl
cdf = pl.read_parquet("/home/ubuntu/cloudgroupe2e/configurations.parquet").to_pandas()
cdf = cdf[["exp_id", "attacker_rate", "run_proxy_with_dtls", "run_proxy_with_https", "run_attacker"]]
ddf = ddf.merge(cdf, on="exp_id")

_df = pd.DataFrame.from_dict({
  'cloud_proxy_and_attacker_withattacker_httpson' : "High",
  'cloud_proxy_and_500mbpsattacker_withattacker' : "High",
  'cloud_proxy_and_attacker_withattacker' : "High",
  'cloud_proxy_and_attacker_withattacker_dtlson_httpson' : "Medium",
  'cloud_proxy_and_500mbpsattacker_withattacker_httpson' : "Medium",
  'cloud_proxy_and_500mbpsattacker_withattacker_dtlson' : "Medium",
  'cloud_proxy_and_500mbpsattacker_withattacker_dtlson_httpson' : "Medium",
  'cloud_proxy_and_attacker_withattacker_dtlson' : "Medium",
  'cloud_proxy_and_attacker_noattacker_dtlson' : "Low",
  'cloud_proxy_and_attacker_noattacker_dtlson_httpson' : "Low",
  'cloud_proxy_and_attacker_noattacker' : "Low",
  'cloud_proxy_and_attacker_noattacker_httpson' : "Low",
}, orient="index", columns=["volume"]).reset_index().rename(columns={"index": "exp_id"})
ddf = ddf.merge(_df, on="exp_id")

adf = ddf[ddf["run_attacker"] == True]

ddf
# Out:
#          group_id                                         exp_id   capture  \
# 0     cloudno2_v1   cloud_proxy_and_500mbpsattacker_withattacker  Attacker
# 1     cloudno2_v1   cloud_proxy_and_500mbpsattacker_withattacker    Client
# 2     cloudno2_v1   cloud_proxy_and_500mbpsattacker_withattacker     Proxy
# 3     cloudno2_v1   cloud_proxy_and_500mbpsattacker_withattacker  Receiver
# 4     cloudno2_v1   cloud_proxy_and_500mbpsattacker_withattacker    Server
# ...           ...                                            ...       ...
# 1003  cloudno2_v6  cloud_proxy_and_attacker_withattacker_httpson  Attacker
# 1004  cloudno2_v6  cloud_proxy_and_attacker_withattacker_httpson    Client
# 1005  cloudno2_v6  cloud_proxy_and_attacker_withattacker_httpson     Proxy
# 1006  cloudno2_v6  cloud_proxy_and_attacker_withattacker_httpson  Receiver
# 1007  cloudno2_v6  cloud_proxy_and_attacker_withattacker_httpson    Server
#
#       decode_time_sec attacker_rate  run_proxy_with_dtls  \
# 0             136.216       500mbps                False
# 1              14.212       500mbps                False
# 2             170.037       500mbps                False
# 3             105.946       500mbps                False
# 4             100.154       500mbps                False
# ...               ...           ...                  ...
# 1003          128.967       100mbps                False
# 1004           10.662       100mbps                False
# 1005          161.566       100mbps                False
# 1006           98.026       100mbps                False
# 1007           97.864       100mbps                False
#
#       run_proxy_with_https  run_attacker volume
# 0                    False          True   High
# 1                    False          True   High
# 2                    False          True   High
# 3                    False          True   High
# 4                    False          True   High
# ...                    ...           ...    ...
# 1003                  True          True   High
# 1004                  True          True   High
# 1005                  True          True   High
# 1006                  True          True   High
# 1007                  True          True   High
#
# [1008 rows x 9 columns]

# %%
(
  ddf
  .groupby(by=["volume"])
  .agg(
    mean_decode_time_sec=("decode_time_sec", "mean"),
    max_decode_time_sec=("decode_time_sec", "max"),
    min_decode_time_sec=("decode_time_sec", "min"),
  )
  .reset_index()
)

print(f"{ddf.decode_time_sec.mean()=}")
print(f"{ddf.decode_time_sec.max()=}")
print(f"{ddf.decode_time_sec.min()=}")
# Out:
# ddf.decode_time_sec.mean()=57.8934255952381
# ddf.decode_time_sec.max()=177.80700000000002
# ddf.decode_time_sec.min()=4.013

# %%
__df = (
  ddf
  .groupby(by=["volume", "capture"])
  .agg(
    mean_decode_time_sec=("decode_time_sec", "mean"),
    median_decode_time_sec=("decode_time_sec", "median"),
    max_decode_time_sec=("decode_time_sec", "max"),
    p99_decode_time_sec=("decode_time_sec", lambda x: x.quantile(0.95)),
  )
  .reset_index()
)

__df
# Out:
#     volume   capture  mean_decode_time_sec  median_decode_time_sec  \
# 0     High  Attacker            128.921500                128.7325
# 1     High    Client             11.315204                 10.6090
# 2     High     Proxy            166.509537                164.5940
# 3     High  Receiver            101.224426                100.2185
# 4     High    Server            100.197315                 99.4660
# 5      Low    Client             11.682806                 10.6780
# 6      Low     Proxy             15.646903                 14.6050
# 7      Low  Receiver             10.170514                  9.0475
# 8      Low    Server             13.772597                 12.4625
# 9   Medium  Attacker             76.167056                 75.8925
# 10  Medium    Client             11.860889                 10.6085
# 11  Medium     Proxy            117.323478                116.0345
# 12  Medium  Receiver              9.868544                  8.9875
# 13  Medium    Server             87.267356                 87.0400
#
#     max_decode_time_sec  p99_decode_time_sec
# 0               139.354            137.71230
# 1                16.672             15.81950
# 2               177.807            175.55675
# 3               109.965            109.21540
# 4               114.073            107.69600
# 5                17.163             16.68925
# 6                21.444             20.71345
# 7                15.386             14.78540
# 8                18.996             18.50175
# 9                89.542             83.22140
# 10               17.688             17.15650
# 11              135.134            125.31620
# 12               15.387             14.92770
# 13              101.392             98.08810

# %%
d = list()
with open("/home/ubuntu/dos-californium/total_grouping_decode_times.txt", "r") as f:
  for i, L in enumerate(f):
    L = L.rstrip().replace("\t", " ").replace("-real ", "/real/").replace(":real ", "/real/").replace(":", "/").replace("-", "/")
    parts = L.split("/")
    group_id = parts[0].replace("file_", "")
    exp_id = parts[1].replace("process_", "").replace(".log", "")
    if i % 2 == 0:
      dump = parts[-1].replace("client1", "client").replace("_dump.pcap", "").title()
      d.append({
        "group_id": group_id,
        "exp_id": exp_id,
        "decode_time_sec": None
      })
    else:
      s = parts[-1]
      mins = int(s[:s.index("m")])
      secs = float(s[s.index("m")+1:-1])
      time = mins*60 + secs
      d[-1]["decode_time_sec"] = time

tgddf = pd.DataFrame.from_records(d)
tgddf
# Out:
#        group_id                                             exp_id  \
# 0   cloudno2_v1       cloud_proxy_and_500mbpsattacker_withattacker
# 1   cloudno2_v1  cloud_proxy_and_500mbpsattacker_withattacker_d...
# 2   cloudno2_v1  cloud_proxy_and_500mbpsattacker_withattacker_d...
# 3   cloudno2_v1  cloud_proxy_and_500mbpsattacker_withattacker_h...
# 4   cloudno2_v1                cloud_proxy_and_attacker_noattacker
# ..          ...                                                ...
# 67  cloudno2_v6        cloud_proxy_and_attacker_noattacker_httpson
# 68  cloudno2_v6              cloud_proxy_and_attacker_withattacker
# 69  cloudno2_v6       cloud_proxy_and_attacker_withattacker_dtlson
# 70  cloudno2_v6  cloud_proxy_and_attacker_withattacker_dtlson_h...
# 71  cloudno2_v6      cloud_proxy_and_attacker_withattacker_httpson
#
#     decode_time_sec
# 0           172.158
# 1           127.435
# 2           134.575
# 3           137.651
# 4            20.785
# ..              ...
# 67           16.650
# 68          166.493
# 69          115.855
# 70          131.046
# 71          175.313
#
# [72 rows x 3 columns]

# %%
total_decode_times = (
  (
    tgddf.groupby(by=["group_id"])
    .agg(
      max_decode_time_sec=("decode_time_sec", "max")
    )
    .reset_index()
    .max_decode_time_sec
  )
)

def to_min_and_sec(sec):
  m, s = divmod(sec, 60)
  m = int(m)
  s = int(s)
  return f"{m}m{s}sec"

print(f"{to_min_and_sec(total_decode_times.mean())=}")
print(f"{to_min_and_sec(total_decode_times.median())=}")
print(f"{to_min_and_sec(total_decode_times.max())=}")
print(f"{to_min_and_sec(total_decode_times.min())=}")
print(f"{to_min_and_sec(total_decode_times.sum())=}")
# Out:
# to_min_and_sec(total_decode_times.mean())='2m52sec'
# to_min_and_sec(total_decode_times.median())='2m53sec'
# to_min_and_sec(total_decode_times.max())='2m58sec'
# to_min_and_sec(total_decode_times.min())='2m46sec'
# to_min_and_sec(total_decode_times.sum())='17m15sec'

# %%
import polars as pl

rdf = pl.read_parquet("/home/ubuntu/cloudgroupe2e_v4/results.parquet")
rdf
# Out:
# shape: (27994110, 21)
# ┌────────────┬────────────┬────────────┬────────────┬─────┬─────────┬────────────┬───────┬─────────┐
# │ message_ti ┆ message_so ┆ message_de ┆ message_pr ┆ ... ┆ node_ty ┆ message_ma ┆ trial ┆ exp_id  │
# │ mestamp    ┆ urce       ┆ stination  ┆ otocol     ┆     ┆ pe      ┆ rker       ┆ ---   ┆ ---     │
# │ ---        ┆ ---        ┆ ---        ┆ ---        ┆     ┆ ---     ┆ ---        ┆ i32   ┆ str     │
# │ f64        ┆ str        ┆ str        ┆ str        ┆     ┆ str     ┆ i64        ┆       ┆         │
# ╞════════════╪════════════╪════════════╪════════════╪═════╪═════════╪════════════╪═══════╪═════════╡
# │ 0.0        ┆ client1    ┆ proxy      ┆ coap       ┆ ... ┆ client1 ┆ 1          ┆ 1     ┆ cloud_p │
# │            ┆            ┆            ┆            ┆     ┆         ┆            ┆       ┆ roxy_an │
# │            ┆            ┆            ┆            ┆     ┆         ┆            ┆       ┆ d_500mb │
# │            ┆            ┆            ┆            ┆     ┆         ┆            ┆       ┆ psattac │
# │            ┆            ┆            ┆            ┆     ┆         ┆            ┆       ┆ ker_... │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┤
# │ 0.006598   ┆ client1    ┆ proxy      ┆ coap       ┆ ... ┆ proxy   ┆ 1          ┆ 1     ┆ cloud_p │
# │            ┆            ┆            ┆            ┆     ┆         ┆            ┆       ┆ roxy_an │
# │            ┆            ┆            ┆            ┆     ┆         ┆            ┆       ┆ d_500mb │
# │            ┆            ┆            ┆            ┆     ┆         ┆            ┆       ┆ psattac │
# │            ┆            ┆            ┆            ┆     ┆         ┆            ┆       ┆ ker_... │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┤
# │ 0.107456   ┆ proxy      ┆ originserv ┆ http       ┆ ... ┆ proxy   ┆ 1          ┆ 1     ┆ cloud_p │
# │            ┆            ┆ er         ┆            ┆     ┆         ┆            ┆       ┆ roxy_an │
# │            ┆            ┆            ┆            ┆     ┆         ┆            ┆       ┆ d_500mb │
# │            ┆            ┆            ┆            ┆     ┆         ┆            ┆       ┆ psattac │
# │            ┆            ┆            ┆            ┆     ┆         ┆            ┆       ┆ ker_... │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┤
# │ 0.118674   ┆ originserv ┆ proxy      ┆ http       ┆ ... ┆ proxy   ┆ 1          ┆ 1     ┆ cloud_p │
# │            ┆ er         ┆            ┆            ┆     ┆         ┆            ┆       ┆ roxy_an │
# │            ┆            ┆            ┆            ┆     ┆         ┆            ┆       ┆ d_500mb │
# │            ┆            ┆            ┆            ┆     ┆         ┆            ┆       ┆ psattac │
# │            ┆            ┆            ┆            ┆     ┆         ┆            ┆       ┆ ker_... │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┤
# │ ...        ┆ ...        ┆ ...        ┆ ...        ┆ ... ┆ ...     ┆ ...        ┆ ...   ┆ ...     │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┤
# │ 99.531307  ┆ proxy      ┆ originserv ┆ http       ┆ ... ┆ origins ┆ 518440     ┆ 3     ┆ cloud_p │
# │            ┆            ┆ er         ┆            ┆     ┆ erver   ┆            ┆       ┆ roxy_an │
# │            ┆            ┆            ┆            ┆     ┆         ┆            ┆       ┆ d_attac │
# │            ┆            ┆            ┆            ┆     ┆         ┆            ┆       ┆ ker_wit │
# │            ┆            ┆            ┆            ┆     ┆         ┆            ┆       ┆ hatt... │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┤
# │ 99.531612  ┆ originserv ┆ proxy      ┆ http       ┆ ... ┆ proxy   ┆ 518440     ┆ 3     ┆ cloud_p │
# │            ┆ er         ┆            ┆            ┆     ┆         ┆            ┆       ┆ roxy_an │
# │            ┆            ┆            ┆            ┆     ┆         ┆            ┆       ┆ d_attac │
# │            ┆            ┆            ┆            ┆     ┆         ┆            ┆       ┆ ker_wit │
# │            ┆            ┆            ┆            ┆     ┆         ┆            ┆       ┆ hatt... │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┤
# │ 99.531976  ┆ proxy      ┆ client1    ┆ coap       ┆ ... ┆ proxy   ┆ 518440     ┆ 3     ┆ cloud_p │
# │            ┆            ┆            ┆            ┆     ┆         ┆            ┆       ┆ roxy_an │
# │            ┆            ┆            ┆            ┆     ┆         ┆            ┆       ┆ d_attac │
# │            ┆            ┆            ┆            ┆     ┆         ┆            ┆       ┆ ker_wit │
# │            ┆            ┆            ┆            ┆     ┆         ┆            ┆       ┆ hatt... │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┤
# │ 99.5367    ┆ originserv ┆ proxy      ┆ http       ┆ ... ┆ origins ┆ 518440     ┆ 3     ┆ cloud_p │
# │            ┆ er         ┆            ┆            ┆     ┆ erver   ┆            ┆       ┆ roxy_an │
# │            ┆            ┆            ┆            ┆     ┆         ┆            ┆       ┆ d_attac │
# │            ┆            ┆            ┆            ┆     ┆         ┆            ┆       ┆ ker_wit │
# │            ┆            ┆            ┆            ┆     ┆         ┆            ┆       ┆ hatt... │
# └────────────┴────────────┴────────────┴────────────┴─────┴─────────┴────────────┴───────┴─────────┘

# %%
from pprint import pprint
print(len(rdf))
pprint(list(zip(rdf.columns, rdf.dtypes)))
# Out:
# 27994110
# [('message_timestamp', <class 'polars.datatypes.Float64'>),
#  ('message_source', <class 'polars.datatypes.Utf8'>),
#  ('message_destination', <class 'polars.datatypes.Utf8'>),
#  ('message_protocol', <class 'polars.datatypes.Utf8'>),
#  ('message_size', <class 'polars.datatypes.Int64'>),
#  ('coap_type', <class 'polars.datatypes.Utf8'>),
#  ('coap_retransmitted', <class 'polars.datatypes.Boolean'>),
#  ('coap_code', <class 'polars.datatypes.Utf8'>),
#  ('coap_message_id', <class 'polars.datatypes.Int64'>),
#  ('coap_token', <class 'polars.datatypes.Utf8'>),
#  ('coap_proxy_uri', <class 'polars.datatypes.Utf8'>),
#  ('http_request', <class 'polars.datatypes.Boolean'>),
#  ('http_request_method', <class 'polars.datatypes.Utf8'>),
#  ('http_request_full_uri', <class 'polars.datatypes.Utf8'>),
#  ('http_response_code', <class 'polars.datatypes.Int64'>),
#  ('http_response_code_desc', <class 'polars.datatypes.Utf8'>),
#  ('http_response_for_uri', <class 'polars.datatypes.Utf8'>),
#  ('node_type', <class 'polars.datatypes.Utf8'>),
#  ('message_marker', <class 'polars.datatypes.Int64'>),
#  ('trial', <class 'polars.datatypes.Int32'>),
#  ('exp_id', <class 'polars.datatypes.Utf8'>)]

# %%
# %%time

kwargs={"compression":"snappy"}
pdf = pd.read_parquet("/home/ubuntu/cloudgroupe2e_v4/results.parquet", engine="fastparquet", **kwargs)
pdf
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File <timed exec>:2, in <module>
#
# File ~/.local/lib/python3.8/site-packages/pandas/io/parquet.py:493, in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, **kwargs)
#     446 """
#     447 Load a parquet object from the file path, returning a DataFrame.
#     448
#    (...)
#     489 DataFrame
#     490 """
#     491 impl = get_engine(engine)
# --> 493 return impl.read(
#     494     path,
#     495     columns=columns,
#     496     storage_options=storage_options,
#     497     use_nullable_dtypes=use_nullable_dtypes,
#     498     **kwargs,
#     499 )
#
# File ~/.local/lib/python3.8/site-packages/pandas/io/parquet.py:347, in FastParquetImpl.read(self, path, columns, storage_options, **kwargs)
#     343     path = handles.handle
#     345 parquet_file = self.api.ParquetFile(path, **parquet_kwargs)
# --> 347 result = parquet_file.to_pandas(columns=columns, **kwargs)
#     349 if handles is not None:
#     350     handles.close()
#
# TypeError: to_pandas() got an unexpected keyword argument 'compression'
